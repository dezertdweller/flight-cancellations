# %% [markdown]
# consumer airfare report:
# https://data.transportation.gov/Aviation/Consumer-Airfare-Report-Table-2-Top-1-000-City-Pai/wqw2-rjgd/about_data
#
# on time monthly data:
# https://www.transtats.bts.gov/Fields.asp?gnoyr_VQ=FGK
#
# airline codes:
# https://www.bansard.com/sites/default/files/download_documents/Bansard-airlines-codes-IATA-ICAO.xlsx&ved=2ahUKEwj2zPThgpSIAxWLITQIHdmMGsEQFnoECAwQAQ&usg=AOvVaw1t6UbPkojIZrVMuOTDghg9

# %%
import sys
import os

# Get the project root directory
PROJECT_ROOT = os.path.abspath(os.path.join(os.pardir))

# Add the project root to sys.path
sys.path.append(PROJECT_ROOT)

# Now you can import the config module
from config.config import DATA_PATH

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from urllib.request import urlretrieve
import holidays
import re

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Import Flight Performance Data

# %%
import pandas as pd
import os

def read_and_combine_csv(base_path, data_folder):
    """
    Reads multiple CSV files from a specified directory and combines them into a single DataFrame.

    Args:
    base_path (str): The base directory path where data folders are stored.
    data_folder (str): The folder name containing the CSV files to read.

    Returns:
    DataFrame: A combined DataFrame containing data from all CSV files in the specified directory.
    """
    # Construct the full path to the folder containing CSV files
    folder_path = os.path.join(base_path, data_folder)
    
    # Initialize an empty list to store individual DataFrames
    dataframes_list = []
    
    # Iterate through each file in the directory
    for filename in os.listdir(folder_path):
        if filename.endswith('.csv'):
            file_path = os.path.join(folder_path, filename)
            df = pd.read_csv(file_path, low_memory=False)
            dataframes_list.append(df)
    
    # Concatenate all DataFrames in the list into one DataFrame
    combined_df = pd.concat(dataframes_list, ignore_index=True)
    
    return combined_df

# %%
# Assume DATA_PATH is already imported from your config
flight_data = '2023-performance-data'
df_2023 = read_and_combine_csv(DATA_PATH+'/raw', flight_data)

# Check the combined DataFrame
print(df_2023.head())
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2023        3      8           6          7  2023-08-06
# 1  2023        3      8           7          1  2023-08-07
# 2  2023        3      8           9          3  2023-08-09
# 3  2023        3      8          10          4  2023-08-10
# 4  2023        3      8          12          6  2023-08-12
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        NK                                      NK
# 1                        NK                                      NK
# 2                        NK                                      NK
# 3                        NK                                      NK
# 4                        NK                                      NK
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 0                     20416                          NK
# 1                     20416                          NK
# 2                     20416                          NK
# 3                     20416                          NK
# 4                     20416                          NK
#
#    Flight_Number_Marketing_Airline Originally_Scheduled_Code_Share_Airline  \
# 0                             2252                                     NaN
# 1                             2252                                     NaN
# 2                             2252                                     NaN
# 3                             2252                                     NaN
# 4                             2252                                     NaN
#
#    DOT_ID_Originally_Scheduled_Code_Share_Airline  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   IATA_Code_Originally_Scheduled_Code_Share_Airline  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Flight_Num_Originally_Scheduled_Code_Share_Airline Operating_Airline   \
# 0                                                NaN                  NK
# 1                                                NaN                  NK
# 2                                                NaN                  NK
# 3                                                NaN                  NK
# 4                                                NaN                  NK
#
#    DOT_ID_Operating_Airline IATA_Code_Operating_Airline Tail_Number  \
# 0                     20416                          NK      N978NK
# 1                     20416                          NK      N974NK
# 2                     20416                          NK      N519NK
# 3                     20416                          NK      N532NK
# 4                     20416                          NK      N529NK
#
#    Flight_Number_Operating_Airline  OriginAirportID  OriginAirportSeqID  \
# 0                             2252            12889             1288904
# 1                             2252            12889             1288904
# 2                             2252            12889             1288904
# 3                             2252            12889             1288904
# 4                             2252            12889             1288904
#
#    OriginCityMarketID Origin OriginCityName OriginState  OriginStateFips  \
# 0               32211    LAS  Las Vegas, NV          NV               32
# 1               32211    LAS  Las Vegas, NV          NV               32
# 2               32211    LAS  Las Vegas, NV          NV               32
# 3               32211    LAS  Las Vegas, NV          NV               32
# 4               32211    LAS  Las Vegas, NV          NV               32
#
#   OriginStateName  OriginWac  DestAirportID  DestAirportSeqID  \
# 0          Nevada         85          11057           1105703
# 1          Nevada         85          11057           1105703
# 2          Nevada         85          11057           1105703
# 3          Nevada         85          11057           1105703
# 4          Nevada         85          11057           1105703
#
#    DestCityMarketID Dest   DestCityName DestState  DestStateFips  \
# 0             31057  CLT  Charlotte, NC        NC             37
# 1             31057  CLT  Charlotte, NC        NC             37
# 2             31057  CLT  Charlotte, NC        NC             37
# 3             31057  CLT  Charlotte, NC        NC             37
# 4             31057  CLT  Charlotte, NC        NC             37
#
#     DestStateName  DestWac  CRSDepTime  DepTime  DepDelay  DepDelayMinutes  \
# 0  North Carolina       36        2359      NaN       NaN              NaN
# 1  North Carolina       36        2359    115.0      76.0             76.0
# 2  North Carolina       36        2310   2259.0     -11.0              0.0
# 3  North Carolina       36        2310   2302.0      -8.0              0.0
# 4  North Carolina       36        2310   2314.0       4.0              4.0
#
#    DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  WheelsOn  \
# 0       NaN                   NaN  2300-2359      NaN        NaN       NaN
# 1       1.0                   5.0  2300-2359     19.0      134.0     822.0
# 2       0.0                  -1.0  2300-2359     14.0     2313.0     605.0
# 3       0.0                  -1.0  2300-2359     12.0     2314.0     551.0
# 4       0.0                   0.0  2300-2359     18.0     2332.0     618.0
#
#    TaxiIn  CRSArrTime  ArrTime  ArrDelay  ArrDelayMinutes  ArrDel15  \
# 0     NaN         722      NaN       NaN              NaN       NaN
# 1     9.0         722    831.0      69.0             69.0       1.0
# 2    10.0         628    615.0     -13.0              0.0       0.0
# 3     7.0         628    558.0     -30.0              0.0       0.0
# 4     6.0         628    624.0      -4.0              0.0       0.0
#
#    ArrivalDelayGroups ArrTimeBlk  Cancelled CancellationCode  Diverted  \
# 0                 NaN  0700-0759        1.0                B       0.0
# 1                 4.0  0700-0759        0.0              NaN       0.0
# 2                -1.0  0600-0659        0.0              NaN       0.0
# 3                -2.0  0600-0659        0.0              NaN       0.0
# 4                -1.0  0600-0659        0.0              NaN       0.0
#
#    CRSElapsedTime  ActualElapsedTime  AirTime  Flights  Distance  \
# 0           263.0                NaN      NaN      1.0    1916.0
# 1           263.0              256.0    228.0      1.0    1916.0
# 2           258.0              256.0    232.0      1.0    1916.0
# 3           258.0              236.0    217.0      1.0    1916.0
# 4           258.0              250.0    226.0      1.0    1916.0
#
#    DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0              8           NaN           NaN       NaN            NaN
# 1              8           3.0           0.0       1.0            0.0
# 2              8           NaN           NaN       NaN            NaN
# 3              8           NaN           NaN       NaN            NaN
# 4              8           NaN           NaN       NaN            NaN
#
#    LateAircraftDelay  FirstDepTime  TotalAddGTime  LongestAddGTime  \
# 0                NaN           NaN            NaN              NaN
# 1               65.0           NaN            NaN              NaN
# 2                NaN           NaN            NaN              NaN
# 3                NaN           NaN            NaN              NaN
# 4                NaN           NaN            NaN              NaN
#
#    DivAirportLandings  DivReachedDest  DivActualElapsedTime  DivArrDelay  \
# 0                 0.0             NaN                   NaN          NaN
# 1                 0.0             NaN                   NaN          NaN
# 2                 0.0             NaN                   NaN          NaN
# 3                 0.0             NaN                   NaN          NaN
# 4                 0.0             NaN                   NaN          NaN
#
#    DivDistance Div1Airport  Div1AirportID  Div1AirportSeqID  Div1WheelsOn  \
# 0          NaN         NaN            NaN               NaN           NaN
# 1          NaN         NaN            NaN               NaN           NaN
# 2          NaN         NaN            NaN               NaN           NaN
# 3          NaN         NaN            NaN               NaN           NaN
# 4          NaN         NaN            NaN               NaN           NaN
#
#    Div1TotalGTime  Div1LongestGTime  Div1WheelsOff Div1TailNum Div2Airport  \
# 0             NaN               NaN            NaN         NaN         NaN
# 1             NaN               NaN            NaN         NaN         NaN
# 2             NaN               NaN            NaN         NaN         NaN
# 3             NaN               NaN            NaN         NaN         NaN
# 4             NaN               NaN            NaN         NaN         NaN
#
#    Div2AirportID  Div2AirportSeqID  Div2WheelsOn  Div2TotalGTime  \
# 0            NaN               NaN           NaN             NaN
# 1            NaN               NaN           NaN             NaN
# 2            NaN               NaN           NaN             NaN
# 3            NaN               NaN           NaN             NaN
# 4            NaN               NaN           NaN             NaN
#
#    Div2LongestGTime  Div2WheelsOff Div2TailNum Div3Airport  Div3AirportID  \
# 0               NaN            NaN         NaN         NaN            NaN
# 1               NaN            NaN         NaN         NaN            NaN
# 2               NaN            NaN         NaN         NaN            NaN
# 3               NaN            NaN         NaN         NaN            NaN
# 4               NaN            NaN         NaN         NaN            NaN
#
#    Div3AirportSeqID  Div3WheelsOn  Div3TotalGTime  Div3LongestGTime  \
# 0               NaN           NaN             NaN               NaN
# 1               NaN           NaN             NaN               NaN
# 2               NaN           NaN             NaN               NaN
# 3               NaN           NaN             NaN               NaN
# 4               NaN           NaN             NaN               NaN
#
#    Div3WheelsOff Div3TailNum  Div4Airport  Div4AirportID  Div4AirportSeqID  \
# 0            NaN         NaN          NaN            NaN               NaN
# 1            NaN         NaN          NaN            NaN               NaN
# 2            NaN         NaN          NaN            NaN               NaN
# 3            NaN         NaN          NaN            NaN               NaN
# 4            NaN         NaN          NaN            NaN               NaN
#
#    Div4WheelsOn  Div4TotalGTime  Div4LongestGTime  Div4WheelsOff  Div4TailNum  \
# 0           NaN             NaN               NaN            NaN          NaN
# 1           NaN             NaN               NaN            NaN          NaN
# 2           NaN             NaN               NaN            NaN          NaN
# 3           NaN             NaN               NaN            NaN          NaN
# 4           NaN             NaN               NaN            NaN          NaN
#
#    Div5Airport  Div5AirportID  Div5AirportSeqID  Div5WheelsOn  Div5TotalGTime  \
# 0          NaN            NaN               NaN           NaN             NaN
# 1          NaN            NaN               NaN           NaN             NaN
# 2          NaN            NaN               NaN           NaN             NaN
# 3          NaN            NaN               NaN           NaN             NaN
# 4          NaN            NaN               NaN           NaN             NaN
#
#    Div5LongestGTime  Div5WheelsOff  Div5TailNum Duplicate  Unnamed: 119
# 0               NaN            NaN          NaN         N           NaN
# 1               NaN            NaN          NaN         N           NaN
# 2               NaN            NaN          NaN         N           NaN
# 3               NaN            NaN          NaN         N           NaN
# 4               NaN            NaN          NaN         N           NaN

# %%
df_codes = pd.read_csv(DATA_PATH + '/raw/L_AIRLINE_ID.csv')

# %% [markdown]
# ## Inspect Data Quality

# %%
df_2023.shape
# Out:
# (7278739, 120)

# %%
df_2023.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2023        3      8           6          7  2023-08-06
# 1  2023        3      8           7          1  2023-08-07
# 2  2023        3      8           9          3  2023-08-09
# 3  2023        3      8          10          4  2023-08-10
# 4  2023        3      8          12          6  2023-08-12
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        NK                                      NK
# 1                        NK                                      NK
# 2                        NK                                      NK
# 3                        NK                                      NK
# 4                        NK                                      NK
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 0                     20416                          NK
# 1                     20416                          NK
# 2                     20416                          NK
# 3                     20416                          NK
# 4                     20416                          NK
#
#    Flight_Number_Marketing_Airline Originally_Scheduled_Code_Share_Airline  \
# 0                             2252                                     NaN
# 1                             2252                                     NaN
# 2                             2252                                     NaN
# 3                             2252                                     NaN
# 4                             2252                                     NaN
#
#    DOT_ID_Originally_Scheduled_Code_Share_Airline  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   IATA_Code_Originally_Scheduled_Code_Share_Airline  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Flight_Num_Originally_Scheduled_Code_Share_Airline Operating_Airline   \
# 0                                                NaN                  NK
# 1                                                NaN                  NK
# 2                                                NaN                  NK
# 3                                                NaN                  NK
# 4                                                NaN                  NK
#
#    DOT_ID_Operating_Airline IATA_Code_Operating_Airline Tail_Number  \
# 0                     20416                          NK      N978NK
# 1                     20416                          NK      N974NK
# 2                     20416                          NK      N519NK
# 3                     20416                          NK      N532NK
# 4                     20416                          NK      N529NK
#
#    Flight_Number_Operating_Airline  OriginAirportID  OriginAirportSeqID  \
# 0                             2252            12889             1288904
# 1                             2252            12889             1288904
# 2                             2252            12889             1288904
# 3                             2252            12889             1288904
# 4                             2252            12889             1288904
#
#    OriginCityMarketID Origin OriginCityName OriginState  OriginStateFips  \
# 0               32211    LAS  Las Vegas, NV          NV               32
# 1               32211    LAS  Las Vegas, NV          NV               32
# 2               32211    LAS  Las Vegas, NV          NV               32
# 3               32211    LAS  Las Vegas, NV          NV               32
# 4               32211    LAS  Las Vegas, NV          NV               32
#
#   OriginStateName  OriginWac  DestAirportID  DestAirportSeqID  \
# 0          Nevada         85          11057           1105703
# 1          Nevada         85          11057           1105703
# 2          Nevada         85          11057           1105703
# 3          Nevada         85          11057           1105703
# 4          Nevada         85          11057           1105703
#
#    DestCityMarketID Dest   DestCityName DestState  DestStateFips  \
# 0             31057  CLT  Charlotte, NC        NC             37
# 1             31057  CLT  Charlotte, NC        NC             37
# 2             31057  CLT  Charlotte, NC        NC             37
# 3             31057  CLT  Charlotte, NC        NC             37
# 4             31057  CLT  Charlotte, NC        NC             37
#
#     DestStateName  DestWac  CRSDepTime  DepTime  DepDelay  DepDelayMinutes  \
# 0  North Carolina       36        2359      NaN       NaN              NaN
# 1  North Carolina       36        2359    115.0      76.0             76.0
# 2  North Carolina       36        2310   2259.0     -11.0              0.0
# 3  North Carolina       36        2310   2302.0      -8.0              0.0
# 4  North Carolina       36        2310   2314.0       4.0              4.0
#
#    DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  WheelsOn  \
# 0       NaN                   NaN  2300-2359      NaN        NaN       NaN
# 1       1.0                   5.0  2300-2359     19.0      134.0     822.0
# 2       0.0                  -1.0  2300-2359     14.0     2313.0     605.0
# 3       0.0                  -1.0  2300-2359     12.0     2314.0     551.0
# 4       0.0                   0.0  2300-2359     18.0     2332.0     618.0
#
#    TaxiIn  CRSArrTime  ArrTime  ArrDelay  ArrDelayMinutes  ArrDel15  \
# 0     NaN         722      NaN       NaN              NaN       NaN
# 1     9.0         722    831.0      69.0             69.0       1.0
# 2    10.0         628    615.0     -13.0              0.0       0.0
# 3     7.0         628    558.0     -30.0              0.0       0.0
# 4     6.0         628    624.0      -4.0              0.0       0.0
#
#    ArrivalDelayGroups ArrTimeBlk  Cancelled CancellationCode  Diverted  \
# 0                 NaN  0700-0759        1.0                B       0.0
# 1                 4.0  0700-0759        0.0              NaN       0.0
# 2                -1.0  0600-0659        0.0              NaN       0.0
# 3                -2.0  0600-0659        0.0              NaN       0.0
# 4                -1.0  0600-0659        0.0              NaN       0.0
#
#    CRSElapsedTime  ActualElapsedTime  AirTime  Flights  Distance  \
# 0           263.0                NaN      NaN      1.0    1916.0
# 1           263.0              256.0    228.0      1.0    1916.0
# 2           258.0              256.0    232.0      1.0    1916.0
# 3           258.0              236.0    217.0      1.0    1916.0
# 4           258.0              250.0    226.0      1.0    1916.0
#
#    DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0              8           NaN           NaN       NaN            NaN
# 1              8           3.0           0.0       1.0            0.0
# 2              8           NaN           NaN       NaN            NaN
# 3              8           NaN           NaN       NaN            NaN
# 4              8           NaN           NaN       NaN            NaN
#
#    LateAircraftDelay  FirstDepTime  TotalAddGTime  LongestAddGTime  \
# 0                NaN           NaN            NaN              NaN
# 1               65.0           NaN            NaN              NaN
# 2                NaN           NaN            NaN              NaN
# 3                NaN           NaN            NaN              NaN
# 4                NaN           NaN            NaN              NaN
#
#    DivAirportLandings  DivReachedDest  DivActualElapsedTime  DivArrDelay  \
# 0                 0.0             NaN                   NaN          NaN
# 1                 0.0             NaN                   NaN          NaN
# 2                 0.0             NaN                   NaN          NaN
# 3                 0.0             NaN                   NaN          NaN
# 4                 0.0             NaN                   NaN          NaN
#
#    DivDistance Div1Airport  Div1AirportID  Div1AirportSeqID  Div1WheelsOn  \
# 0          NaN         NaN            NaN               NaN           NaN
# 1          NaN         NaN            NaN               NaN           NaN
# 2          NaN         NaN            NaN               NaN           NaN
# 3          NaN         NaN            NaN               NaN           NaN
# 4          NaN         NaN            NaN               NaN           NaN
#
#    Div1TotalGTime  Div1LongestGTime  Div1WheelsOff Div1TailNum Div2Airport  \
# 0             NaN               NaN            NaN         NaN         NaN
# 1             NaN               NaN            NaN         NaN         NaN
# 2             NaN               NaN            NaN         NaN         NaN
# 3             NaN               NaN            NaN         NaN         NaN
# 4             NaN               NaN            NaN         NaN         NaN
#
#    Div2AirportID  Div2AirportSeqID  Div2WheelsOn  Div2TotalGTime  \
# 0            NaN               NaN           NaN             NaN
# 1            NaN               NaN           NaN             NaN
# 2            NaN               NaN           NaN             NaN
# 3            NaN               NaN           NaN             NaN
# 4            NaN               NaN           NaN             NaN
#
#    Div2LongestGTime  Div2WheelsOff Div2TailNum Div3Airport  Div3AirportID  \
# 0               NaN            NaN         NaN         NaN            NaN
# 1               NaN            NaN         NaN         NaN            NaN
# 2               NaN            NaN         NaN         NaN            NaN
# 3               NaN            NaN         NaN         NaN            NaN
# 4               NaN            NaN         NaN         NaN            NaN
#
#    Div3AirportSeqID  Div3WheelsOn  Div3TotalGTime  Div3LongestGTime  \
# 0               NaN           NaN             NaN               NaN
# 1               NaN           NaN             NaN               NaN
# 2               NaN           NaN             NaN               NaN
# 3               NaN           NaN             NaN               NaN
# 4               NaN           NaN             NaN               NaN
#
#    Div3WheelsOff Div3TailNum  Div4Airport  Div4AirportID  Div4AirportSeqID  \
# 0            NaN         NaN          NaN            NaN               NaN
# 1            NaN         NaN          NaN            NaN               NaN
# 2            NaN         NaN          NaN            NaN               NaN
# 3            NaN         NaN          NaN            NaN               NaN
# 4            NaN         NaN          NaN            NaN               NaN
#
#    Div4WheelsOn  Div4TotalGTime  Div4LongestGTime  Div4WheelsOff  Div4TailNum  \
# 0           NaN             NaN               NaN            NaN          NaN
# 1           NaN             NaN               NaN            NaN          NaN
# 2           NaN             NaN               NaN            NaN          NaN
# 3           NaN             NaN               NaN            NaN          NaN
# 4           NaN             NaN               NaN            NaN          NaN
#
#    Div5Airport  Div5AirportID  Div5AirportSeqID  Div5WheelsOn  Div5TotalGTime  \
# 0          NaN            NaN               NaN           NaN             NaN
# 1          NaN            NaN               NaN           NaN             NaN
# 2          NaN            NaN               NaN           NaN             NaN
# 3          NaN            NaN               NaN           NaN             NaN
# 4          NaN            NaN               NaN           NaN             NaN
#
#    Div5LongestGTime  Div5WheelsOff  Div5TailNum Duplicate  Unnamed: 119
# 0               NaN            NaN          NaN         N           NaN
# 1               NaN            NaN          NaN         N           NaN
# 2               NaN            NaN          NaN         N           NaN
# 3               NaN            NaN          NaN         N           NaN
# 4               NaN            NaN          NaN         N           NaN

# %%
df_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7278739 entries, 0 to 7278738
# Columns: 120 entries, Year to Unnamed: 119
# dtypes: float64(71), int64(22), object(27)
# memory usage: 6.5+ GB

# %%
df_2023.columns = df_2023.columns.str.strip()

# %% [markdown]
# ## Missing Values

# %%
null_vals = df_2023.isna().sum().reset_index()
null_vals.columns = ['column', 'num_missing']
null_vals['perc_missing'] = round(null_vals['num_missing'] / len(df_2023) *100, 3)
missing_over_50 = null_vals[null_vals['perc_missing'] > 50].sort_values('perc_missing', ascending=False)
print(missing_over_50.shape)
missing_over_50
# Out:
# (58, 3)
#                                                 column  num_missing  \
# 119                                       Unnamed: 119      7278739
# 106                                     Div4TotalGTime      7278739
# 94                                         Div3Airport      7278737
# 95                                       Div3AirportID      7278737
# 96                                    Div3AirportSeqID      7278737
# 97                                        Div3WheelsOn      7278737
# 98                                      Div3TotalGTime      7278737
# 99                                    Div3LongestGTime      7278737
# 100                                      Div3WheelsOff      7278738
# 101                                        Div3TailNum      7278738
# 102                                        Div4Airport      7278739
# 103                                      Div4AirportID      7278739
# 104                                   Div4AirportSeqID      7278739
# 105                                       Div4WheelsOn      7278739
# 107                                   Div4LongestGTime      7278739
# 108                                      Div4WheelsOff      7278739
# 109                                        Div4TailNum      7278739
# 110                                        Div5Airport      7278739
# 111                                      Div5AirportID      7278739
# 112                                   Div5AirportSeqID      7278739
# 113                                       Div5WheelsOn      7278739
# 114                                     Div5TotalGTime      7278739
# 115                                   Div5LongestGTime      7278739
# 116                                      Div5WheelsOff      7278739
# 117                                        Div5TailNum      7278739
# 93                                         Div2TailNum      7278653
# 92                                       Div2WheelsOff      7278653
# 91                                    Div2LongestGTime      7278562
# 90                                      Div2TotalGTime      7278562
# 89                                        Div2WheelsOn      7278562
# 88                                    Div2AirportSeqID      7278562
# 87                                       Div2AirportID      7278562
# 86                                         Div2Airport      7278562
# 12      DOT_ID_Originally_Scheduled_Code_Share_Airline      7277653
# 13   IATA_Code_Originally_Scheduled_Code_Share_Airline      7277653
# 14   Flight_Num_Originally_Scheduled_Code_Share_Air...      7277653
# 11             Originally_Scheduled_Code_Share_Airline      7277653
# 76                                         DivArrDelay      7262690
# 75                                DivActualElapsedTime      7262691
# 85                                         Div1TailNum      7262596
# 84                                       Div1WheelsOff      7262596
# 77                                         DivDistance      7260942
# 74                                      DivReachedDest      7260942
# 81                                        Div1WheelsOn      7260161
# 82                                      Div1TotalGTime      7260161
# 83                                    Div1LongestGTime      7260161
# 78                                         Div1Airport      7260160
# 79                                       Div1AirportID      7260160
# 80                                    Div1AirportSeqID      7260160
# 72                                     LongestAddGTime      7231279
# 70                                        FirstDepTime      7231277
# 71                                       TotalAddGTime      7231279
# 57                                    CancellationCode      7184842
# 69                                   LateAircraftDelay      5814201
# 68                                       SecurityDelay      5814201
# 67                                            NASDelay      5814201
# 66                                        WeatherDelay      5814201
# 65                                        CarrierDelay      5814201
#
#      perc_missing
# 119       100.000
# 106       100.000
# 94        100.000
# 95        100.000
# 96        100.000
# 97        100.000
# 98        100.000
# 99        100.000
# 100       100.000
# 101       100.000
# 102       100.000
# 103       100.000
# 104       100.000
# 105       100.000
# 107       100.000
# 108       100.000
# 109       100.000
# 110       100.000
# 111       100.000
# 112       100.000
# 113       100.000
# 114       100.000
# 115       100.000
# 116       100.000
# 117       100.000
# 93         99.999
# 92         99.999
# 91         99.998
# 90         99.998
# 89         99.998
# 88         99.998
# 87         99.998
# 86         99.998
# 12         99.985
# 13         99.985
# 14         99.985
# 11         99.985
# 76         99.780
# 75         99.780
# 85         99.778
# 84         99.778
# 77         99.755
# 74         99.755
# 81         99.745
# 82         99.745
# 83         99.745
# 78         99.745
# 79         99.745
# 80         99.745
# 72         99.348
# 70         99.348
# 71         99.348
# 57         98.710
# 69         79.879
# 68         79.879
# 67         79.879
# 66         79.879
# 65         79.879

# %% [markdown]
# Fifty-eight columns are missing over 50% of their values, 53 of which are missing over 90% of their values. Most of these columns are dealing with details about diverted flights. There is a column, `Diverted`, which captures whether or not a flight was diverted and it does not contain any missing values. At this point, it will be best to remove the columns with over 90% of their values missing.
#
# The different delay types (`LateAircraftDelay`, `SecurityDelay`, `NASDelay`, `WeatherDelay`, `CarrierDelay`) may come in handy as I would expect most flights do not experience delays. These different types of delays may inform some segmentation of delayed flights later on.

# %%
# drop columns with over 80% missing values
cols_to_drop = null_vals[null_vals['perc_missing'] >= 80]['column'].tolist()

df = df_2023.drop(columns=cols_to_drop)

# %%
missing_under_50 = null_vals[(null_vals['perc_missing'] <= 50) & (null_vals['perc_missing'] > 0)].sort_values('perc_missing', ascending=False)
print(missing_under_50.shape)
missing_under_50
# Out:
# (17, 3)
#                   column  num_missing  perc_missing
# 61               AirTime       111695         1.535
# 60     ActualElapsedTime       111695         1.535
# 54    ArrivalDelayGroups       111695         1.535
# 53              ArrDel15       111695         1.535
# 52       ArrDelayMinutes       111695         1.535
# 51              ArrDelay       111695         1.535
# 48                TaxiIn        95647         1.314
# 50               ArrTime        95646         1.314
# 47              WheelsOn        95647         1.314
# 46             WheelsOff        93119         1.279
# 45               TaxiOut        93119         1.279
# 43  DepartureDelayGroups        90160         1.239
# 42              DepDel15        90160         1.239
# 41       DepDelayMinutes        90160         1.239
# 40              DepDelay        90160         1.239
# 39               DepTime        90100         1.238
# 18           Tail_Number        19648         0.270

# %% [markdown]
# Seventeen columns have less than 2% of their values missing.
#
# Earlier I deleted rows with missing values because of the % being insignificant. However, some of these missing observations likely overlap with the 11,032 cancelled flights. Others are just missing informaiton for some reason. I found this out because when I wanted to see the counts of cancelled vs not cancelled flights, I only saw details for not cancelled flights.

# %% [markdown]
# It would make sense that cancelled flights would have missing information in other columns. I want to identify which flights were cancelled and how many there were.

# %%
df['Cancelled'].value_counts()
# Out:
# Cancelled
# 0.0    7184842
# 1.0      93897
# Name: count, dtype: int64

# %%
cancelled_flights = df['Cancelled'] == 1.0
print('Total number of cancelled flights: ', len(df[cancelled_flights]))
# Out:
# Total number of cancelled flights:  93897

# %%
not_cancelled = df[~cancelled_flights]
not_cancelled_missing = not_cancelled.isna().sum().reset_index()
not_cancelled_missing.columns = ['Column', 'Count_Missing']
not_cancelled_missing[not_cancelled_missing['Count_Missing'] > 0]
# Out:
#                 Column  Count_Missing
# 43            WheelsOn           1750
# 44              TaxiIn           1750
# 46             ArrTime           1749
# 47            ArrDelay          17798
# 48     ArrDelayMinutes          17798
# 49            ArrDel15          17798
# 50  ArrivalDelayGroups          17798
# 54      CRSElapsedTime              1
# 55   ActualElapsedTime          17798
# 56             AirTime          17798
# 60        CarrierDelay        5720304
# 61        WeatherDelay        5720304
# 62            NASDelay        5720304
# 63       SecurityDelay        5720304
# 64   LateAircraftDelay        5720304
# 65  DivAirportLandings              3

# %% [markdown]
# There were over 93,000 cancelled flights in 2023. However, some of the data is still missing information for several columns even after excluding the cancelled flights.
#
# I still maintain that the different delay types (`LateAircraftDelay`, `SecurityDelay`, `NASDelay`, `WeatherDelay`, `CarrierDelay`) may come in handy as I would expect most flights do not experience delays.
#
# However, I believe I should remove observations that are missing data in the other columns.

# %%
missing_critical_data = ((df['Cancelled'] == 0) & (df['ArrTime'].isna())) | ((df['Cancelled'] == 0) & (df['ArrDelayMinutes'].isna()))
print('Total non-cancelled flights with missing data: ', missing_critical_data.sum())
# Out:
# Total non-cancelled flights with missing data:  17798

# %%
# drop rows missing less than 3% of values
df = df[~missing_critical_data]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7260941 entries, 0 to 7278738
# Data columns (total 67 columns):
#  #   Column                                   Dtype
# ---  ------                                   -----
#  0   Year                                     int64
#  1   Quarter                                  int64
#  2   Month                                    int64
#  3   DayofMonth                               int64
#  4   DayOfWeek                                int64
#  5   FlightDate                               object
#  6   Marketing_Airline_Network                object
#  7   Operated_or_Branded_Code_Share_Partners  object
#  8   DOT_ID_Marketing_Airline                 int64
#  9   IATA_Code_Marketing_Airline              object
#  10  Flight_Number_Marketing_Airline          int64
#  11  Operating_Airline                        object
#  12  DOT_ID_Operating_Airline                 int64
#  13  IATA_Code_Operating_Airline              object
#  14  Tail_Number                              object
#  15  Flight_Number_Operating_Airline          int64
#  16  OriginAirportID                          int64
#  17  OriginAirportSeqID                       int64
#  18  OriginCityMarketID                       int64
#  19  Origin                                   object
#  20  OriginCityName                           object
#  21  OriginState                              object
#  22  OriginStateFips                          int64
#  23  OriginStateName                          object
#  24  OriginWac                                int64
#  25  DestAirportID                            int64
#  26  DestAirportSeqID                         int64
#  27  DestCityMarketID                         int64
#  28  Dest                                     object
#  29  DestCityName                             object
#  30  DestState                                object
#  31  DestStateFips                            int64
#  32  DestStateName                            object
#  33  DestWac                                  int64
#  34  CRSDepTime                               int64
#  35  DepTime                                  float64
#  36  DepDelay                                 float64
#  37  DepDelayMinutes                          float64
#  38  DepDel15                                 float64
#  39  DepartureDelayGroups                     float64
#  40  DepTimeBlk                               object
#  41  TaxiOut                                  float64
#  42  WheelsOff                                float64
#  43  WheelsOn                                 float64
#  44  TaxiIn                                   float64
#  45  CRSArrTime                               int64
#  46  ArrTime                                  float64
#  47  ArrDelay                                 float64
#  48  ArrDelayMinutes                          float64
#  49  ArrDel15                                 float64
#  50  ArrivalDelayGroups                       float64
#  51  ArrTimeBlk                               object
#  52  Cancelled                                float64
#  53  Diverted                                 float64
#  54  CRSElapsedTime                           float64
#  55  ActualElapsedTime                        float64
#  56  AirTime                                  float64
#  57  Flights                                  float64
#  58  Distance                                 float64
#  59  DistanceGroup                            int64
#  60  CarrierDelay                             float64
#  61  WeatherDelay                             float64
#  62  NASDelay                                 float64
#  63  SecurityDelay                            float64
#  64  LateAircraftDelay                        float64
#  65  DivAirportLandings                       float64
#  66  Duplicate                                object
# dtypes: float64(27), int64(22), object(18)
# memory usage: 3.7+ GB

# %% [markdown]
# ## Data Types

# %% [markdown]
# The `FlightDate` column will need to be converted to a datetime object. I'll be able to see if there are any inconsistencies with the range of dates. I expect only flight details for January 2023.

# %%
# convert FlightDate to datetime object
df['FlightDate'] = pd.to_datetime(df['FlightDate'], errors='coerce')
df['FlightDate'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 7260941 entries, 0 to 7278738
# Series name: FlightDate
# Non-Null Count    Dtype
# --------------    -----
# 7260941 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 110.8 MB

# %%
df['FlightDate'].describe()
# Out:
# count                          7260941
# mean     2023-07-03 18:25:02.977754112
# min                2023-01-01 00:00:00
# 25%                2023-04-05 00:00:00
# 50%                2023-07-05 00:00:00
# 75%                2023-10-02 00:00:00
# max                2023-12-31 00:00:00
# Name: FlightDate, dtype: object

# %% [markdown]
# The range of flight dates is as expected, ranging from January 1st to December 31st.

# %% [markdown]
# ## Redundant Columns with Flight Operations
#
# The first few rows of the dataframe seemed to have similar information for `Marketing_Airline_Network`, `Operated_or_Branded_Code_Share_Partners`, and `IATA_Code_Marketing_Airline`. There also appear to be identical data for the `Operating_Airline` and `IATA_Code_Operating_Airline` columns. I want to take a closer look at these columns.

# %%
df[['Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners', 'IATA_Code_Marketing_Airline', 'Operating_Airline', 'IATA_Code_Operating_Airline']]
# Out:
#         Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                              NK                                      NK
# 1                              NK                                      NK
# 2                              NK                                      NK
# 3                              NK                                      NK
# 4                              NK                                      NK
# ...                           ...                                     ...
# 7278734                        AA                            AA_CODESHARE
# 7278735                        AA                            AA_CODESHARE
# 7278736                        AA                            AA_CODESHARE
# 7278737                        AA                            AA_CODESHARE
# 7278738                        AA                            AA_CODESHARE
#
#         IATA_Code_Marketing_Airline Operating_Airline  \
# 0                                NK                NK
# 1                                NK                NK
# 2                                NK                NK
# 3                                NK                NK
# 4                                NK                NK
# ...                             ...               ...
# 7278734                          AA                OH
# 7278735                          AA                OH
# 7278736                          AA                OH
# 7278737                          AA                OH
# 7278738                          AA                OH
#
#         IATA_Code_Operating_Airline
# 0                                NK
# 1                                NK
# 2                                NK
# 3                                NK
# 4                                NK
# ...                             ...
# 7278734                          OH
# 7278735                          OH
# 7278736                          OH
# 7278737                          OH
# 7278738                          OH
#
# [7260941 rows x 5 columns]

# %% [markdown]
# After reading documentation, the Marketing Airline Network and/or IATA Code is not always unique as it can be assigned to different airlines over time. Also, these codes may not always be unique. The identify unique airline carriers, the `DOT_ID_Marketing_Airline` column should be used as this is unique to the airline carrier and is defined as one holding and reporting under the same DOT certificate regardless of its Code, Name, or holding company/corporation.
#
# The `Operated_or_Branded_Code_Share_Partners` column identifies whether the flight was operate by one of the airline's code share partners. A codeshare flight is an agreement between airlines to sell seats on each other’s flights. This gives the appearance of airlines flying to more destinations. By doing so, the airlines typically share the revenue on that ticket. The `DOT_ID_Operating_Airline` column should be used to identify which airline carrier is oeprating the flight.
#
# Creating a new column denoting whether a flight was a code share flight will potentially allow for segregating flights based on differing operations.

# %%
# Compare the two columns to find where they are different
code_share_flights = (df['Marketing_Airline_Network'] != df['Operated_or_Branded_Code_Share_Partners'])
print('The total number of code share flights: ', len(df[code_share_flights]))
print('The percent of flights that are code share flights: ', round(len(df[code_share_flights])/len(df) * 100, 2), '%')
# Out:
# The total number of code share flights:  2019136
# The percent of flights that are code share flights:  27.81 %

# %% [markdown]
# Over a quarter of all flights in 2023 were code share flights. This seems like a significant proportion.

# %%
df['Code_Share_Flight'] = code_share_flights
df['Code_Share_Flight'] = df['Code_Share_Flight'].astype(int)

# %%
df['Code_Share_Flight'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Code_Share_Flight, dtype: int64

# %% [markdown]
# I will drop the `Operated_or_Branded_Code_Share_Partners` column now that I have capture whether or not a flight was a code share flight.

# %%
ops_columns_to_drop = ['Operated_or_Branded_Code_Share_Partners']

# %%
# Compare the two columns to find where they are different
differences = df['Marketing_Airline_Network'] != df['IATA_Code_Marketing_Airline']

# Count the number of differences
count_differences = differences.sum()

print(f"Number of differences between the two columns: {count_differences}")
# Out:
# Number of differences between the two columns: 0

# %% [markdown]
# Since Marketing Airline Network Code and the IATA Code don't have any differences, keeping both columns is unnecessary. I will drop the `Marketing_Airline_Network`column.

# %%
ops_columns_to_drop.append('Marketing_Airline_Network')

# %%
# Compare the two columns to find where they are different
differences = df['Flight_Number_Marketing_Airline'] != df['Flight_Number_Operating_Airline']

# Count the number of differences
count_differences = differences.sum()

print(f"Number of differences between the two columns: {count_differences}")
# Out:
# Number of differences between the two columns: 575

# %% [markdown]
# The flight numbers are identical for nearly all observations except for 575 flights. I will only keep the `Flight_Number_Marketing_Airline` column.

# %%
ops_columns_to_drop.append('Flight_Number_Operating_Airline')

# %%
# Compare the two columns to find where they are different
differences = df['Operating_Airline'] != df['IATA_Code_Operating_Airline']

# Count the number of differences
count_differences = differences.sum()

print(f"Number of differences between the two columns: {count_differences}")
# Out:
# Number of differences between the two columns: 0

# %% [markdown]
# Since Operating Airline Code and the IATA Code don't have any differences, keeping both columns is unnecessary. I will drop the `Operating_Airline`column.

# %%
ops_columns_to_drop.append('Operating_Airline')

# %%
df = df.drop(columns=ops_columns_to_drop)

# %%
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate  \
# 0  2023        3      8           6          7 2023-08-06
# 1  2023        3      8           7          1 2023-08-07
# 2  2023        3      8           9          3 2023-08-09
# 3  2023        3      8          10          4 2023-08-10
# 4  2023        3      8          12          6 2023-08-12
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 0                     20416                          NK
# 1                     20416                          NK
# 2                     20416                          NK
# 3                     20416                          NK
# 4                     20416                          NK
#
#    Flight_Number_Marketing_Airline  DOT_ID_Operating_Airline  \
# 0                             2252                     20416
# 1                             2252                     20416
# 2                             2252                     20416
# 3                             2252                     20416
# 4                             2252                     20416
#
#   IATA_Code_Operating_Airline Tail_Number  OriginAirportID  \
# 0                          NK      N978NK            12889
# 1                          NK      N974NK            12889
# 2                          NK      N519NK            12889
# 3                          NK      N532NK            12889
# 4                          NK      N529NK            12889
#
#    OriginAirportSeqID  OriginCityMarketID Origin OriginCityName OriginState  \
# 0             1288904               32211    LAS  Las Vegas, NV          NV
# 1             1288904               32211    LAS  Las Vegas, NV          NV
# 2             1288904               32211    LAS  Las Vegas, NV          NV
# 3             1288904               32211    LAS  Las Vegas, NV          NV
# 4             1288904               32211    LAS  Las Vegas, NV          NV
#
#    OriginStateFips OriginStateName  OriginWac  DestAirportID  \
# 0               32          Nevada         85          11057
# 1               32          Nevada         85          11057
# 2               32          Nevada         85          11057
# 3               32          Nevada         85          11057
# 4               32          Nevada         85          11057
#
#    DestAirportSeqID  DestCityMarketID Dest   DestCityName DestState  \
# 0           1105703             31057  CLT  Charlotte, NC        NC
# 1           1105703             31057  CLT  Charlotte, NC        NC
# 2           1105703             31057  CLT  Charlotte, NC        NC
# 3           1105703             31057  CLT  Charlotte, NC        NC
# 4           1105703             31057  CLT  Charlotte, NC        NC
#
#    DestStateFips   DestStateName  DestWac  CRSDepTime  DepTime  DepDelay  \
# 0             37  North Carolina       36        2359      NaN       NaN
# 1             37  North Carolina       36        2359    115.0      76.0
# 2             37  North Carolina       36        2310   2259.0     -11.0
# 3             37  North Carolina       36        2310   2302.0      -8.0
# 4             37  North Carolina       36        2310   2314.0       4.0
#
#    DepDelayMinutes  DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  \
# 0              NaN       NaN                   NaN  2300-2359      NaN
# 1             76.0       1.0                   5.0  2300-2359     19.0
# 2              0.0       0.0                  -1.0  2300-2359     14.0
# 3              0.0       0.0                  -1.0  2300-2359     12.0
# 4              4.0       0.0                   0.0  2300-2359     18.0
#
#    WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrTime  ArrDelay  \
# 0        NaN       NaN     NaN         722      NaN       NaN
# 1      134.0     822.0     9.0         722    831.0      69.0
# 2     2313.0     605.0    10.0         628    615.0     -13.0
# 3     2314.0     551.0     7.0         628    558.0     -30.0
# 4     2332.0     618.0     6.0         628    624.0      -4.0
#
#    ArrDelayMinutes  ArrDel15  ArrivalDelayGroups ArrTimeBlk  Cancelled  \
# 0              NaN       NaN                 NaN  0700-0759        1.0
# 1             69.0       1.0                 4.0  0700-0759        0.0
# 2              0.0       0.0                -1.0  0600-0659        0.0
# 3              0.0       0.0                -2.0  0600-0659        0.0
# 4              0.0       0.0                -1.0  0600-0659        0.0
#
#    Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  Flights  Distance  \
# 0       0.0           263.0                NaN      NaN      1.0    1916.0
# 1       0.0           263.0              256.0    228.0      1.0    1916.0
# 2       0.0           258.0              256.0    232.0      1.0    1916.0
# 3       0.0           258.0              236.0    217.0      1.0    1916.0
# 4       0.0           258.0              250.0    226.0      1.0    1916.0
#
#    DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0              8           NaN           NaN       NaN            NaN
# 1              8           3.0           0.0       1.0            0.0
# 2              8           NaN           NaN       NaN            NaN
# 3              8           NaN           NaN       NaN            NaN
# 4              8           NaN           NaN       NaN            NaN
#
#    LateAircraftDelay  DivAirportLandings Duplicate  Code_Share_Flight
# 0                NaN                 0.0         N                  0
# 1               65.0                 0.0         N                  0
# 2                NaN                 0.0         N                  0
# 3                NaN                 0.0         N                  0
# 4                NaN                 0.0         N                  0

# %%
airport_details = df[['OriginAirportID', 'OriginAirportSeqID', 'OriginCityMarketID', 'Origin', 'OriginCityName', 'OriginState', 'OriginStateFips', 'OriginStateName']].drop_duplicates()
airport_details = airport_details.rename(columns={
    'OriginAirportID':'Airport_ID',
    'OriginAirportSeqID':'Airport_Seq_ID',
    'Origin_City_Market_ID':'City_Market_ID',
    'Origin':'Airport_Code',
    'OriginCityName':'City_Name',
    'OriginState':'State_Code',
    'OriginStateFips':'State_Fips', 
    'OriginStateName':'State_Name'
})

# %%
airport_details
# Out:
#          Airport_ID  Airport_Seq_ID  OriginCityMarketID Airport_Code  \
# 0             12889         1288904               32211          LAS
# 24            11697         1169706               32467          FLL
# 55            13204         1320402               31454          MCO
# 77            10397         1039707               30397          ATL
# 120           10423         1042302               30423          AUS
# ...             ...             ...                 ...          ...
# 3872263       11315         1131503               31315          DIK
# 3888468       13256         1325602               33256          MFE
# 4187478       13983         1398305               33983          OWB
# 4294964       13459         1345903               33459          MQT
# 5873195       14288         1428805               34288          PUB
#
#                             City_Name State_Code  State_Fips    State_Name
# 0                       Las Vegas, NV         NV          32        Nevada
# 24                Fort Lauderdale, FL         FL          12       Florida
# 55                        Orlando, FL         FL          12       Florida
# 77                        Atlanta, GA         GA          13       Georgia
# 120                        Austin, TX         TX          48         Texas
# ...                               ...        ...         ...           ...
# 3872263                 Dickinson, ND         ND          38  North Dakota
# 3888468  Mission/McAllen/Edinburg, TX         TX          48         Texas
# 4187478                 Owensboro, KY         KY          21      Kentucky
# 4294964                 Marquette, MI         MI          26      Michigan
# 5873195                    Pueblo, CO         CO           8      Colorado
#
# [368 rows x 8 columns]

# %% [markdown]
# ## Redundant Columns with Origin and Destination Details

# %% [markdown]
# `OriginAirportID` and `OriginAirportSeqID` both provide identification numbers used by the DOT to identify a unique airport. The additional numbers in the `OriginAirportSeqID` column provide information about the airport at a given point in time. Since both of these point to the same unique airport, we only need one of the columns. Similarly, `DestAirportID` and `DestAirportSeqID` provide information about the unique destination airport. We only need one of the columns. I will drop both columns with SeqID information.

# %%
location_details_to_drop = ['OriginAirportSeqID', 'DestAirportSeqID']

# %% [markdown]
# The `OriginCityName` and `DestCityName` include the state or country names after the comma. Since this information is already tracked in the `OriginState` column, we don't also need state informatino in the city column.

# %%
# Split the 'OriginCityName' into two columns but handle cases where there might not be a comma
df['Origin_City'] = df['OriginCityName'].str.split(',').str[0]
df['PotentialState'] = df['OriginCityName'].str.split(',').str[1]

# Fill NaNs in 'PotentialState' with an empty string or a placeholder if no comma was present
df['PotentialState'] = df['PotentialState'].fillna('')

# Trim any whitespace that might be around the state names
df['PotentialState'] = df['PotentialState'].str.strip()

# Proceed with your state comparison and adjustment
# This assumes you have an 'OriginState' column to compare with
df['CheckStateMatch'] = df['PotentialState'] == df['OriginState']
df['Origin_City'] = df.apply(lambda x: x['OriginCityName'] if not x['CheckStateMatch'] else x['Origin_City'], axis=1)

# %%
df[df['CheckStateMatch'] == False][['Origin', 'Origin_City', 'OriginState', 'PotentialState']].value_counts()
# Out:
# Origin  Origin_City     OriginState  PotentialState
# DCA     Washington, DC  VA           DC                143090
# IAD     Washington, DC  VA           DC                 75090
# CVG     Cincinnati, OH  KY           OH                 41702
# Name: count, dtype: int64

# %%
df['Origin_City'] = df['Origin_City'].str.replace(r'Cincinnati, OH', 'Hebron', regex=True)

# %%
df[df['CheckStateMatch'] == False][['Origin_City', 'OriginState']].value_counts()
# Out:
# Origin_City     OriginState
# Washington, DC  VA             218180
# Hebron          KY              41702
# Name: count, dtype: int64

# %%
# Split the 'OriginCityName' into two columns but handle cases where there might not be a comma
df['Destination_City'] = df['DestCityName'].str.split(',').str[0]
df['PotentialState_D'] = df['DestCityName'].str.split(',').str[1]

# Fill NaNs in 'PotentialState' with an empty string or a placeholder if no comma was present
df['PotentialState_D'] = df['PotentialState_D'].fillna('')

# Trim any whitespace that might be around the state names
df['PotentialState_D'] = df['PotentialState_D'].str.strip()

# Proceed with your state comparison and adjustment
# This assumes you have an 'OriginState' column to compare with
df['CheckStateMatch_D'] = df['PotentialState_D'] == df['DestState']
df['Destination_City'] = df.apply(lambda x: x['DestCityName'] if not x['CheckStateMatch_D'] else x['Destination_City'], axis=1)

# %%
df['Destination_City'].head()
# Out:
# 0    Charlotte
# 1    Charlotte
# 2    Charlotte
# 3    Charlotte
# 4    Charlotte
# Name: Destination_City, dtype: object

# %%
df[df['CheckStateMatch'] == False][['Destination_City', 'DestState']].value_counts()
df['Destination_City'] = df['Destination_City'].str.replace(r'Cincinnati, OH', 'Hebron', regex=True)
df[df['CheckStateMatch_D'] == False][['Destination_City', 'DestState']].value_counts()
# Out:
# Destination_City  DestState
# Washington, DC    VA           218077
# Hebron            KY            41735
# Name: count, dtype: int64

# %%
location_details_to_drop.extend(['OriginCityName', 'PotentialState', 'CheckStateMatch', 'DestCityName', 'PotentialState_D', 'CheckStateMatch_D'])

# %%
origin_states = df.groupby(['OriginState', 'OriginStateName', 'OriginStateFips', 'OriginWac']).size().reset_index()
origin_states.rename(columns={0:'Count'}, inplace=True)
origin_states.sort_values('OriginStateName').head()
# Out:
#   OriginState OriginStateName  OriginStateFips  OriginWac   Count
# 1          AL         Alabama                1         51   36418
# 0          AK          Alaska                2          1   42728
# 3          AZ         Arizona                4         81  205794
# 2          AR        Arkansas                5         71   28750
# 4          CA      California                6         91  747100

# %%
dest_states = df.groupby(['DestState', 'DestStateName', 'DestStateFips', 'DestWac']).size().reset_index()
dest_states.rename(columns={0:'Count'}, inplace=True)
states_df = origin_states.merge(dest_states, left_on=['OriginStateFips', 'OriginWac'], right_on=['DestStateFips', 'DestWac'], suffixes=('_origin', '_dest'), how='outer')
states_df
# Out:
#    OriginState                                 OriginStateName  \
# 0           AK                                          Alaska
# 1           AL                                         Alabama
# 2           AR                                        Arkansas
# 3           AZ                                         Arizona
# 4           CA                                      California
# 5           CO                                        Colorado
# 6           CT                                     Connecticut
# 7           FL                                         Florida
# 8           GA                                         Georgia
# 9           HI                                          Hawaii
# 10          IA                                            Iowa
# 11          ID                                           Idaho
# 12          IL                                        Illinois
# 13          IN                                         Indiana
# 14          KS                                          Kansas
# 15          KY                                        Kentucky
# 16          LA                                       Louisiana
# 17          MA                                   Massachusetts
# 18          MD                                        Maryland
# 19          ME                                           Maine
# 20          MI                                        Michigan
# 21          MN                                       Minnesota
# 22          MO                                        Missouri
# 23          MS                                     Mississippi
# 24          MT                                         Montana
# 25          NC                                  North Carolina
# 26          ND                                    North Dakota
# 27          NE                                        Nebraska
# 28          NH                                   New Hampshire
# 29          NJ                                      New Jersey
# 30          NM                                      New Mexico
# 31          NV                                          Nevada
# 32          NY                                        New York
# 33          OH                                            Ohio
# 34          OK                                        Oklahoma
# 35          OR                                          Oregon
# 36          PA                                    Pennsylvania
# 37          PR                                     Puerto Rico
# 38          RI                                    Rhode Island
# 39          SC                                  South Carolina
# 40          SD                                    South Dakota
# 41          TN                                       Tennessee
# 42          TT  U.S. Pacific Trust Territories and Possessions
# 43          TX                                           Texas
# 44          UT                                            Utah
# 45          VA                                        Virginia
# 46          VI                             U.S. Virgin Islands
# 47          VT                                         Vermont
# 48          WA                                      Washington
# 49          WI                                       Wisconsin
# 50          WV                                   West Virginia
# 51          WY                                         Wyoming
#
#     OriginStateFips  OriginWac  Count_origin DestState  \
# 0                 2          1         42728        AK
# 1                 1         51         36418        AL
# 2                 5         71         28750        AR
# 3                 4         81        205794        AZ
# 4                 6         91        747100        CA
# 5                 8         82        334351        CO
# 6                 9         11         22858        CT
# 7                12         33        612995        FL
# 8                13         34        363670        GA
# 9                15          2        132336        HI
# 10               19         61         25457        IA
# 11               16         83         32638        ID
# 12               17         41        395207        IL
# 13               18         42         60746        IN
# 14               20         62         14943        KS
# 15               21         52         76105        KY
# 16               22         72         71253        LA
# 17               25         13        146250        MA
# 18               24         35         97722        MD
# 19               23         12         17568        ME
# 20               26         43        163355        MI
# 21               27         63        129648        MN
# 22               29         64        126842        MO
# 23               28         53         15158        MS
# 24               30         84         29304        MT
# 25               37         36        326167        NC
# 26               38         66         17129        ND
# 27               31         65         27843        NE
# 28               33         14          7584        NH
# 29               34         21        155932        NJ
# 30               35         86         28429        NM
# 31               32         85        212112        NV
# 32               36         22        391475        NY
# 33               39         44        100019        OH
# 34               40         73         42862        OK
# 35               41         92         89762        OR
# 36               42         23        172302        PA
# 37               72          3         36436        PR
# 38               44         15         15920        RI
# 39               45         37         65997        SC
# 40               46         67         12577        SD
# 41               47         54        149293        TN
# 42               75          5          1273        TT
# 43               48         74        781149        TX
# 44               49         87        115734        UT
# 45               51         38        279547        VA
# 46               78          4          5719        VI
# 47               50         16          8762        VT
# 48               53         93        216635        WA
# 49               55         45         55001        WI
# 50               54         39          4957        WV
# 51               56         88         11129        WY
#
#                                      DestStateName  DestStateFips  DestWac  \
# 0                                           Alaska              2        1
# 1                                          Alabama              1       51
# 2                                         Arkansas              5       71
# 3                                          Arizona              4       81
# 4                                       California              6       91
# 5                                         Colorado              8       82
# 6                                      Connecticut              9       11
# 7                                          Florida             12       33
# 8                                          Georgia             13       34
# 9                                           Hawaii             15        2
# 10                                            Iowa             19       61
# 11                                           Idaho             16       83
# 12                                        Illinois             17       41
# 13                                         Indiana             18       42
# 14                                          Kansas             20       62
# 15                                        Kentucky             21       52
# 16                                       Louisiana             22       72
# 17                                   Massachusetts             25       13
# 18                                        Maryland             24       35
# 19                                           Maine             23       12
# 20                                        Michigan             26       43
# 21                                       Minnesota             27       63
# 22                                        Missouri             29       64
# 23                                     Mississippi             28       53
# 24                                         Montana             30       84
# 25                                  North Carolina             37       36
# 26                                    North Dakota             38       66
# 27                                        Nebraska             31       65
# 28                                   New Hampshire             33       14
# 29                                      New Jersey             34       21
# 30                                      New Mexico             35       86
# 31                                          Nevada             32       85
# 32                                        New York             36       22
# 33                                            Ohio             39       44
# 34                                        Oklahoma             40       73
# 35                                          Oregon             41       92
# 36                                    Pennsylvania             42       23
# 37                                     Puerto Rico             72        3
# 38                                    Rhode Island             44       15
# 39                                  South Carolina             45       37
# 40                                    South Dakota             46       67
# 41                                       Tennessee             47       54
# 42  U.S. Pacific Trust Territories and Possessions             75        5
# 43                                           Texas             48       74
# 44                                            Utah             49       87
# 45                                        Virginia             51       38
# 46                             U.S. Virgin Islands             78        4
# 47                                         Vermont             50       16
# 48                                      Washington             53       93
# 49                                       Wisconsin             55       45
# 50                                   West Virginia             54       39
# 51                                         Wyoming             56       88
#
#     Count_dest
# 0        42707
# 1        36443
# 2        28748
# 3       205985
# 4       747618
# 5       333737
# 6        22877
# 7       612351
# 8       363813
# 9       132270
# 10       25445
# 11       32628
# 12      395077
# 13       60820
# 14       14923
# 15       76138
# 16       71256
# 17      146302
# 18       97760
# 19       17560
# 20      163426
# 21      129762
# 22      126964
# 23       15142
# 24       29274
# 25      326343
# 26       17094
# 27       27862
# 28        7579
# 29      155825
# 30       28457
# 31      212207
# 32      391219
# 33      100092
# 34       42873
# 35       89780
# 36      172459
# 37       36528
# 38       15943
# 39       66046
# 40       12560
# 41      149336
# 42        1270
# 43      780829
# 44      115877
# 45      279377
# 46        5776
# 47        8756
# 48      216742
# 49       55019
# 50        4935
# 51       11131

# %% [markdown]
# There don't appear to be any data entry issues with state abbreviations, state names or their FIPS codes. I will remove the FIPS and State Names columns and only keep the abbreviations. The FIPS and State Names will be preserved in a dictionary for use later if needed.

# %%
states_dict = {row['OriginState']: (row['OriginStateName'], row['OriginStateFips'], row['OriginWac'])
               for index, row in origin_states.iterrows()}
states_dict
# Out:
# {'AK': ('Alaska', 2, 1),
#  'AL': ('Alabama', 1, 51),
#  'AR': ('Arkansas', 5, 71),
#  'AZ': ('Arizona', 4, 81),
#  'CA': ('California', 6, 91),
#  'CO': ('Colorado', 8, 82),
#  'CT': ('Connecticut', 9, 11),
#  'FL': ('Florida', 12, 33),
#  'GA': ('Georgia', 13, 34),
#  'HI': ('Hawaii', 15, 2),
#  'IA': ('Iowa', 19, 61),
#  'ID': ('Idaho', 16, 83),
#  'IL': ('Illinois', 17, 41),
#  'IN': ('Indiana', 18, 42),
#  'KS': ('Kansas', 20, 62),
#  'KY': ('Kentucky', 21, 52),
#  'LA': ('Louisiana', 22, 72),
#  'MA': ('Massachusetts', 25, 13),
#  'MD': ('Maryland', 24, 35),
#  'ME': ('Maine', 23, 12),
#  'MI': ('Michigan', 26, 43),
#  'MN': ('Minnesota', 27, 63),
#  'MO': ('Missouri', 29, 64),
#  'MS': ('Mississippi', 28, 53),
#  'MT': ('Montana', 30, 84),
#  'NC': ('North Carolina', 37, 36),
#  'ND': ('North Dakota', 38, 66),
#  'NE': ('Nebraska', 31, 65),
#  'NH': ('New Hampshire', 33, 14),
#  'NJ': ('New Jersey', 34, 21),
#  'NM': ('New Mexico', 35, 86),
#  'NV': ('Nevada', 32, 85),
#  'NY': ('New York', 36, 22),
#  'OH': ('Ohio', 39, 44),
#  'OK': ('Oklahoma', 40, 73),
#  'OR': ('Oregon', 41, 92),
#  'PA': ('Pennsylvania', 42, 23),
#  'PR': ('Puerto Rico', 72, 3),
#  'RI': ('Rhode Island', 44, 15),
#  'SC': ('South Carolina', 45, 37),
#  'SD': ('South Dakota', 46, 67),
#  'TN': ('Tennessee', 47, 54),
#  'TT': ('U.S. Pacific Trust Territories and Possessions', 75, 5),
#  'TX': ('Texas', 48, 74),
#  'UT': ('Utah', 49, 87),
#  'VA': ('Virginia', 51, 38),
#  'VI': ('U.S. Virgin Islands', 78, 4),
#  'VT': ('Vermont', 50, 16),
#  'WA': ('Washington', 53, 93),
#  'WI': ('Wisconsin', 55, 45),
#  'WV': ('West Virginia', 54, 39),
#  'WY': ('Wyoming', 56, 88)}

# %%
location_details_to_drop.extend(['OriginStateName', 'OriginStateFips', 'OriginWac', 'DestStateName', 'DestStateFips', 'DestWac'])
df = df.drop(columns=location_details_to_drop)

# %% [markdown]
# ## Cleaning Departure and Arrival Performance Data
#
# I will be able to apply data cleaning steps to the Depature-related columns. I will then need to separate out the cancelled flights to apply the changes to the Arrival-related columns. Cancelled flights are missing information about arrivals, so I need to preserve these NaN values for now.

# %%
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate  \
# 0  2023        3      8           6          7 2023-08-06
# 1  2023        3      8           7          1 2023-08-07
# 2  2023        3      8           9          3 2023-08-09
# 3  2023        3      8          10          4 2023-08-10
# 4  2023        3      8          12          6 2023-08-12
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 0                     20416                          NK
# 1                     20416                          NK
# 2                     20416                          NK
# 3                     20416                          NK
# 4                     20416                          NK
#
#    Flight_Number_Marketing_Airline  DOT_ID_Operating_Airline  \
# 0                             2252                     20416
# 1                             2252                     20416
# 2                             2252                     20416
# 3                             2252                     20416
# 4                             2252                     20416
#
#   IATA_Code_Operating_Airline Tail_Number  OriginAirportID  \
# 0                          NK      N978NK            12889
# 1                          NK      N974NK            12889
# 2                          NK      N519NK            12889
# 3                          NK      N532NK            12889
# 4                          NK      N529NK            12889
#
#    OriginCityMarketID Origin OriginState  DestAirportID  DestCityMarketID  \
# 0               32211    LAS          NV          11057             31057
# 1               32211    LAS          NV          11057             31057
# 2               32211    LAS          NV          11057             31057
# 3               32211    LAS          NV          11057             31057
# 4               32211    LAS          NV          11057             31057
#
#   Dest DestState  CRSDepTime  DepTime  DepDelay  DepDelayMinutes  DepDel15  \
# 0  CLT        NC        2359      NaN       NaN              NaN       NaN
# 1  CLT        NC        2359    115.0      76.0             76.0       1.0
# 2  CLT        NC        2310   2259.0     -11.0              0.0       0.0
# 3  CLT        NC        2310   2302.0      -8.0              0.0       0.0
# 4  CLT        NC        2310   2314.0       4.0              4.0       0.0
#
#    DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  WheelsOn  TaxiIn  \
# 0                   NaN  2300-2359      NaN        NaN       NaN     NaN
# 1                   5.0  2300-2359     19.0      134.0     822.0     9.0
# 2                  -1.0  2300-2359     14.0     2313.0     605.0    10.0
# 3                  -1.0  2300-2359     12.0     2314.0     551.0     7.0
# 4                   0.0  2300-2359     18.0     2332.0     618.0     6.0
#
#    CRSArrTime  ArrTime  ArrDelay  ArrDelayMinutes  ArrDel15  \
# 0         722      NaN       NaN              NaN       NaN
# 1         722    831.0      69.0             69.0       1.0
# 2         628    615.0     -13.0              0.0       0.0
# 3         628    558.0     -30.0              0.0       0.0
# 4         628    624.0      -4.0              0.0       0.0
#
#    ArrivalDelayGroups ArrTimeBlk  Cancelled  Diverted  CRSElapsedTime  \
# 0                 NaN  0700-0759        1.0       0.0           263.0
# 1                 4.0  0700-0759        0.0       0.0           263.0
# 2                -1.0  0600-0659        0.0       0.0           258.0
# 3                -2.0  0600-0659        0.0       0.0           258.0
# 4                -1.0  0600-0659        0.0       0.0           258.0
#
#    ActualElapsedTime  AirTime  Flights  Distance  DistanceGroup  CarrierDelay  \
# 0                NaN      NaN      1.0    1916.0              8           NaN
# 1              256.0    228.0      1.0    1916.0              8           3.0
# 2              256.0    232.0      1.0    1916.0              8           NaN
# 3              236.0    217.0      1.0    1916.0              8           NaN
# 4              250.0    226.0      1.0    1916.0              8           NaN
#
#    WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay  \
# 0           NaN       NaN            NaN                NaN
# 1           0.0       1.0            0.0               65.0
# 2           NaN       NaN            NaN                NaN
# 3           NaN       NaN            NaN                NaN
# 4           NaN       NaN            NaN                NaN
#
#    DivAirportLandings Duplicate  Code_Share_Flight Origin_City  \
# 0                 0.0         N                  0   Las Vegas
# 1                 0.0         N                  0   Las Vegas
# 2                 0.0         N                  0   Las Vegas
# 3                 0.0         N                  0   Las Vegas
# 4                 0.0         N                  0   Las Vegas
#
#   Destination_City
# 0        Charlotte
# 1        Charlotte
# 2        Charlotte
# 3        Charlotte
# 4        Charlotte

# %%
df['CRSDepTime'].min()
# Out:
# 1

# %%
df['CRSArrTime'].max()
# Out:
# 2400

# %% [markdown]
# Several time columns are currently represented as integers and floats instead of time objects.

# %%
"""def convert_to_time(df, col):

    # conver time columns to integers, then strings and fill left spaces with 0
    df[col] = df[col].astype(int).astype(str).str.zfill(4)
    
    # insert a colon to create a time string format
    df[col] = df[col].str[:2] + ':' + df[col].str[2:]
    
    # Replace "24:00" with "00:00" to avoid conversion errors
    df[col] = df[col].replace('24:00', '00:00')

    # convert string to datetime time object
    df[col] = pd.to_datetime(df[col], format='%H:%M').dt.time

df_not_cancelled = df[~cancelled_flights].copy()

df_cancelled = df[cancelled_flights].copy()

# convert departure and arrival columns for not cancelled flights
columns_to_convert = ['CRSDepTime', 'DepTime', 'WheelsOff', 'WheelsOn', 'CRSArrTime', 'ArrTime']

for col in columns_to_convert:
    convert_to_time(df_not_cancelled, col)

# convert scheduled departure and arrival columns
columns_to_convert = ['CRSDepTime', 'CRSArrTime']

for col in columns_to_convert:
    convert_to_time(df_cancelled, col)    

# convert columns into integers since they represent boolean details
df_not_cancelled[['Cancelled', 'Diverted', 'DepDel15', 'ArrDel15']] = df_not_cancelled[['Cancelled', 'Diverted', 'DepDel15', 'ArrDel15']].astype(int)
# convert columns into integers since they represent boolean details
df_cancelled[['Cancelled', 'Diverted']] = df_cancelled[['Cancelled', 'Diverted']].astype(int)

# merge
df_merged = pd.concat([df_not_cancelled, df_cancelled])
df_merged"""
# Out:
# 'def convert_to_time(df, col):\n\n    # conver time columns to integers, then strings and fill left spaces with 0\n    df[col] = df[col].astype(int).astype(str).str.zfill(4)\n    \n    # insert a colon to create a time string format\n    df[col] = df[col].str[:2] + \':\' + df[col].str[2:]\n    \n    # Replace "24:00" with "00:00" to avoid conversion errors\n    df[col] = df[col].replace(\'24:00\', \'00:00\')\n\n    # convert string to datetime time object\n    df[col] = pd.to_datetime(df[col], format=\'%H:%M\').dt.time\n\ndf_not_cancelled = df[~cancelled_flights].copy()\n\ndf_cancelled = df[cancelled_flights].copy()\n\n# convert departure and arrival columns for not cancelled flights\ncolumns_to_convert = [\'CRSDepTime\', \'DepTime\', \'WheelsOff\', \'WheelsOn\', \'CRSArrTime\', \'ArrTime\']\n\nfor col in columns_to_convert:\n    convert_to_time(df_not_cancelled, col)\n\n# convert scheduled departure and arrival columns\ncolumns_to_convert = [\'CRSDepTime\', \'CRSArrTime\']\n\nfor col in columns_to_convert:\n    convert_to_time(df_cancelled, col)    \n\n# convert columns into integers since they represent boolean details\ndf_not_cancelled[[\'Cancelled\', \'Diverted\', \'DepDel15\', \'ArrDel15\']] = df_not_cancelled[[\'Cancelled\', \'Diverted\', \'DepDel15\', \'ArrDel15\']].astype(int)\n# convert columns into integers since they represent boolean details\ndf_cancelled[[\'Cancelled\', \'Diverted\']] = df_cancelled[[\'Cancelled\', \'Diverted\']].astype(int)\n\n# merge\ndf_merged = pd.concat([df_not_cancelled, df_cancelled])\ndf_merged'

# %% [markdown]
# The above code has been refactored to deal with flights that depart but return and are cancelled. I added an if / else clause in the `convert_to_time` function to handle the null values during the conversion.

# %%
"""def convert_to_time(df, col):
    # Apply the conversion only to non-NaN values
    df[col] = df[col].apply(lambda x: str(int(x)).zfill(4) if pd.notna(x) else x)
    
    # Insert a colon to create a time string format
    df[col] = df[col].apply(lambda x: x[:2] + ':' + x[2:] if pd.notna(x) else x)
    
    # Replace "24:00" with "00:00" to avoid conversion errors
    df[col] = df[col].replace('24:00', '00:00')
    
    # Convert string to datetime time object, but skip NaN values
    df[col] = pd.to_datetime(df[col], format='%H:%M', errors='coerce').dt.time


# convert scheduled departure and arrival columns
columns_to_convert = ['CRSDepTime', 'DepTime', 'WheelsOff', 'WheelsOn', 'CRSArrTime', 'ArrTime']

for col in columns_to_convert:
    convert_to_time(df, col)"""
# Out:
# 'def convert_to_time(df, col):\n    # Apply the conversion only to non-NaN values\n    df[col] = df[col].apply(lambda x: str(int(x)).zfill(4) if pd.notna(x) else x)\n    \n    # Insert a colon to create a time string format\n    df[col] = df[col].apply(lambda x: x[:2] + \':\' + x[2:] if pd.notna(x) else x)\n    \n    # Replace "24:00" with "00:00" to avoid conversion errors\n    df[col] = df[col].replace(\'24:00\', \'00:00\')\n    \n    # Convert string to datetime time object, but skip NaN values\n    df[col] = pd.to_datetime(df[col], format=\'%H:%M\', errors=\'coerce\').dt.time\n\n\n# convert scheduled departure and arrival columns\ncolumns_to_convert = [\'CRSDepTime\', \'DepTime\', \'WheelsOff\', \'WheelsOn\', \'CRSArrTime\', \'ArrTime\']\n\nfor col in columns_to_convert:\n    convert_to_time(df, col)'

# %%
cols_to_convert = ['Cancelled', 'Diverted']

for col in cols_to_convert:
    df[col] = df[col].apply(lambda x: int(x) if pd.notna(x) else x)

# %% [markdown]
# For the `DepDelay` vs `DepDelayMinutes` and `ArrDelay` vs `ArrDelayMinutes` columns, the only difference is that in the Minutes columns, early departures or arrivals are set to 0 instead of a negative number. This is redundant information so we can remove these columns.

# %%
# delete redundant columns
df_merged = df.drop(columns=['DepDelayMinutes', 'ArrDelayMinutes'])

# %%
df_merged['DepDelay'].describe().apply(lambda x: round(x, 2))
# Out:
# count    7170781.00
# mean          12.16
# std           55.71
# min          -99.00
# 25%           -6.00
# 50%           -2.00
# 75%            9.00
# max         5764.00
# Name: DepDelay, dtype: float64

# %% [markdown]
# The CSRDepTime, DepTime, CSRArrTime and ArrTime are all in the local times for their respective airports. I will need to convert all date and time information to UTC in order to later merge with weather data. First, I want to convert the columns I mentioned to datetime columns by merging the time columns with FlightDate. I will then need to adjust rows that have next day arrivals (or several days later due to prolonged delays).

# %%
df_merged.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate  \
# 0  2023        3      8           6          7 2023-08-06
# 1  2023        3      8           7          1 2023-08-07
# 2  2023        3      8           9          3 2023-08-09
# 3  2023        3      8          10          4 2023-08-10
# 4  2023        3      8          12          6 2023-08-12
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 0                     20416                          NK
# 1                     20416                          NK
# 2                     20416                          NK
# 3                     20416                          NK
# 4                     20416                          NK
#
#    Flight_Number_Marketing_Airline  DOT_ID_Operating_Airline  \
# 0                             2252                     20416
# 1                             2252                     20416
# 2                             2252                     20416
# 3                             2252                     20416
# 4                             2252                     20416
#
#   IATA_Code_Operating_Airline Tail_Number  OriginAirportID  \
# 0                          NK      N978NK            12889
# 1                          NK      N974NK            12889
# 2                          NK      N519NK            12889
# 3                          NK      N532NK            12889
# 4                          NK      N529NK            12889
#
#    OriginCityMarketID Origin OriginState  DestAirportID  DestCityMarketID  \
# 0               32211    LAS          NV          11057             31057
# 1               32211    LAS          NV          11057             31057
# 2               32211    LAS          NV          11057             31057
# 3               32211    LAS          NV          11057             31057
# 4               32211    LAS          NV          11057             31057
#
#   Dest DestState  CRSDepTime  DepTime  DepDelay  DepDel15  \
# 0  CLT        NC        2359      NaN       NaN       NaN
# 1  CLT        NC        2359    115.0      76.0       1.0
# 2  CLT        NC        2310   2259.0     -11.0       0.0
# 3  CLT        NC        2310   2302.0      -8.0       0.0
# 4  CLT        NC        2310   2314.0       4.0       0.0
#
#    DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  WheelsOn  TaxiIn  \
# 0                   NaN  2300-2359      NaN        NaN       NaN     NaN
# 1                   5.0  2300-2359     19.0      134.0     822.0     9.0
# 2                  -1.0  2300-2359     14.0     2313.0     605.0    10.0
# 3                  -1.0  2300-2359     12.0     2314.0     551.0     7.0
# 4                   0.0  2300-2359     18.0     2332.0     618.0     6.0
#
#    CRSArrTime  ArrTime  ArrDelay  ArrDel15  ArrivalDelayGroups ArrTimeBlk  \
# 0         722      NaN       NaN       NaN                 NaN  0700-0759
# 1         722    831.0      69.0       1.0                 4.0  0700-0759
# 2         628    615.0     -13.0       0.0                -1.0  0600-0659
# 3         628    558.0     -30.0       0.0                -2.0  0600-0659
# 4         628    624.0      -4.0       0.0                -1.0  0600-0659
#
#    Cancelled  Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  Flights  \
# 0          1         0           263.0                NaN      NaN      1.0
# 1          0         0           263.0              256.0    228.0      1.0
# 2          0         0           258.0              256.0    232.0      1.0
# 3          0         0           258.0              236.0    217.0      1.0
# 4          0         0           258.0              250.0    226.0      1.0
#
#    Distance  DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  \
# 0    1916.0              8           NaN           NaN       NaN
# 1    1916.0              8           3.0           0.0       1.0
# 2    1916.0              8           NaN           NaN       NaN
# 3    1916.0              8           NaN           NaN       NaN
# 4    1916.0              8           NaN           NaN       NaN
#
#    SecurityDelay  LateAircraftDelay  DivAirportLandings Duplicate  \
# 0            NaN                NaN                 0.0         N
# 1            0.0               65.0                 0.0         N
# 2            NaN                NaN                 0.0         N
# 3            NaN                NaN                 0.0         N
# 4            NaN                NaN                 0.0         N
#
#    Code_Share_Flight Origin_City Destination_City
# 0                  0   Las Vegas        Charlotte
# 1                  0   Las Vegas        Charlotte
# 2                  0   Las Vegas        Charlotte
# 3                  0   Las Vegas        Charlotte
# 4                  0   Las Vegas        Charlotte

# %%
df_merged[['CRSDepTime', 'DepTime', 'DepDelay', 'CRSArrTime', 'ArrTime', 'ArrDelay']].isna().sum()
# Out:
# CRSDepTime        0
# DepTime       90100
# DepDelay      90160
# CRSArrTime        0
# ArrTime       93897
# ArrDelay      93897
# dtype: int64

# %%
df_merged[['CRSDepTime', 'DepTime', 'DepDelay', 'CRSArrTime', 'ArrTime', 'ArrDelay']].describe().apply(lambda x: round(x, 2))
# Out:
#        CRSDepTime     DepTime    DepDelay  CRSArrTime     ArrTime    ArrDelay
# count  7260941.00  7170841.00  7170781.00  7260941.00  7167044.00  7167044.00
# mean      1332.12     1334.32       12.16     1486.99     1457.96        6.63
# std        493.84      508.97       55.71      522.36      546.11       57.57
# min          1.00        1.00      -99.00        1.00        1.00     -119.00
# 25%        911.00      913.00       -6.00     1100.00     1043.00      -15.00
# 50%       1324.00     1326.00       -2.00     1515.00     1500.00       -6.00
# 75%       1740.00     1748.00        9.00     1923.00     1916.00        9.00
# max       2359.00     2400.00     5764.00     2400.00     2400.00     5780.00

# %% [markdown]
# #### ***Why is there a difference between the number of flights missing departure data vs arrival data?***

# %%
dep_missing = df_merged['DepTime'].isna()
df_merged[dep_missing].groupby('Cancelled')['DepTime'].size()
# Out:
# Cancelled
# 1    90100
# Name: DepTime, dtype: int64

# %%
arr_missing = df_merged['ArrTime'].isna()
df_merged[arr_missing].groupby('Cancelled')['ArrTime'].size()
# Out:
# Cancelled
# 1    93897
# Name: ArrTime, dtype: int64

# %%
# find the difference between missing ArrTime data and DepTime data
arr_dep_diff = df_merged['ArrTime'].isna().sum() - df_merged['DepTime'].isna().sum()
arr_dep_diff
# Out:
# 3797

# %%
missing_critical_data = ((df_merged['ArrTime'].isna()) & (df_merged['DepTime'].notna()))

df_merged[missing_critical_data]['Cancelled'].value_counts()
# Out:
# Cancelled
# 1    3797
# Name: count, dtype: int64

# %% [markdown]
# All the rows misisng `DepTime` are cancelled flights. Similarly all the rows missing `ArrTime` are cancelled flights. There are 3,797 rows that have `DepTime` data and are missing `ArrTime` data, and all of these flights were cancelled flights. It is likely that these flights were going to take off, left the gate, but did not actually get in the air and were subsequently cancelled, therefore they would have depature data but not arrival data. I'll replace the `DepTime` for these rows with np.nan values since they are all cancelled flights.

# %%
def create_scheduled_actual_datetime(df, date_col, scheduled_dep_time_col, scheduled_arr_time_col, dep_delay_col, arr_delay_col):
    
    # Replace '2400' with '0000' to represent midnight
    df[scheduled_dep_time_col] = df[scheduled_dep_time_col].replace(2400, 0)
    df[scheduled_arr_time_col] = df[scheduled_arr_time_col].replace(2400, 0)

    # Combine FlightDate with CSRDepTime and CSRArrTime to create datetime objects for scheduled departures and arrivals
    df['scheduled_departure_datetime'] = pd.to_datetime(df[date_col].astype(str) + ' ' + df[scheduled_dep_time_col].astype(str).str.zfill(4), format='%Y-%m-%d %H%M', utc=False)
    df['scheduled_arrival_datetime'] = pd.to_datetime(df[date_col].astype(str) + ' ' + df[scheduled_arr_time_col].astype(str).str.zfill(4), format='%Y-%m-%d %H%M', utc=False)

    df.loc[df['scheduled_arrival_datetime'] < df['scheduled_departure_datetime'], 'scheduled_arrival_datetime'] += pd.Timedelta(days=1)

    # Replace actual departure times with NaN for canceled flights with DepTime but no ArrTime
    df.loc[(df['ArrTime'].isna()) & (df['DepTime'].notna()) & (df['Cancelled'] == 1), 'DepTime'] = np.nan
    
    # Only process rows where DepDelay and ArrDelay are not missing (skip canceled flights or incomplete records)
    df_completed_flights = df.dropna(subset=[dep_delay_col, arr_delay_col]).copy()

    # Adjust for delays in actual departure and arrival times (accounting for multi-day delays)
    df_completed_flights['actual_departure_datetime'] = df_completed_flights['scheduled_departure_datetime'] + pd.to_timedelta(df_completed_flights[dep_delay_col], unit='m')
    df_completed_flights['actual_arrival_datetime'] = df_completed_flights['scheduled_arrival_datetime'] + pd.to_timedelta(df_completed_flights[arr_delay_col], unit='m')

    # Add the actual datetime columns to the original dataframe
    df['actual_departure_datetime'] = df_completed_flights['actual_departure_datetime']
    df['actual_arrival_datetime'] = df_completed_flights['actual_arrival_datetime']
    
    return df

# %%
df_dt_fixed = create_scheduled_actual_datetime(df_merged, 'FlightDate', 'CRSDepTime', 'CRSArrTime', 'DepDelay', 'ArrDelay')

# %%
df_dt_fixed[['FlightDate', 'CRSDepTime', 'scheduled_departure_datetime', 'CRSArrTime', 'scheduled_arrival_datetime', 'DepDelay', 'ArrDelay', 'DepTime', 'actual_departure_datetime', 'ArrTime', 'actual_arrival_datetime']].head(20)
# Out:
#    FlightDate  CRSDepTime scheduled_departure_datetime  CRSArrTime  \
# 0  2023-08-06        2359          2023-08-06 23:59:00         722
# 1  2023-08-07        2359          2023-08-07 23:59:00         722
# 2  2023-08-09        2310          2023-08-09 23:10:00         628
# 3  2023-08-10        2310          2023-08-10 23:10:00         628
# 4  2023-08-12        2310          2023-08-12 23:10:00         628
# 5  2023-08-13        2310          2023-08-13 23:10:00         628
# 6  2023-08-14        2310          2023-08-14 23:10:00         628
# 7  2023-08-15        2310          2023-08-15 23:10:00         628
# 8  2023-08-16        2310          2023-08-16 23:10:00         628
# 9  2023-08-17        2310          2023-08-17 23:10:00         628
# 10 2023-08-18        2310          2023-08-18 23:10:00         628
# 11 2023-08-19        2310          2023-08-19 23:10:00         628
# 12 2023-08-20        2310          2023-08-20 23:10:00         628
# 13 2023-08-21        2310          2023-08-21 23:10:00         628
# 14 2023-08-22        2310          2023-08-22 23:10:00         628
# 15 2023-08-23        2310          2023-08-23 23:10:00         628
# 16 2023-08-24        2310          2023-08-24 23:10:00         628
# 17 2023-08-25        2310          2023-08-25 23:10:00         628
# 18 2023-08-26        2310          2023-08-26 23:10:00         628
# 19 2023-08-27        2310          2023-08-27 23:10:00         628
#
#    scheduled_arrival_datetime  DepDelay  ArrDelay  DepTime  \
# 0         2023-08-07 07:22:00       NaN       NaN      NaN
# 1         2023-08-08 07:22:00      76.0      69.0    115.0
# 2         2023-08-10 06:28:00     -11.0     -13.0   2259.0
# 3         2023-08-11 06:28:00      -8.0     -30.0   2302.0
# 4         2023-08-13 06:28:00       4.0      -4.0   2314.0
# 5         2023-08-14 06:28:00      53.0      72.0      3.0
# 6         2023-08-15 06:28:00      -4.0       0.0   2306.0
# 7         2023-08-16 06:28:00       2.0       4.0   2312.0
# 8         2023-08-17 06:28:00       6.0       8.0   2316.0
# 9         2023-08-18 06:28:00       5.0      19.0   2315.0
# 10        2023-08-19 06:28:00     185.0     188.0    215.0
# 11        2023-08-20 06:28:00      47.0      39.0   2357.0
# 12        2023-08-21 06:28:00       9.0      24.0   2319.0
# 13        2023-08-22 06:28:00      -9.0      18.0   2301.0
# 14        2023-08-23 06:28:00      13.0      17.0   2323.0
# 15        2023-08-24 06:28:00       6.0      17.0   2316.0
# 16        2023-08-25 06:28:00      -8.0      21.0   2302.0
# 17        2023-08-26 06:28:00       9.0      25.0   2319.0
# 18        2023-08-27 06:28:00      -9.0     -15.0   2301.0
# 19        2023-08-28 06:28:00      -7.0      10.0   2303.0
#
#    actual_departure_datetime  ArrTime actual_arrival_datetime
# 0                        NaT      NaN                     NaT
# 1        2023-08-08 01:15:00    831.0     2023-08-08 08:31:00
# 2        2023-08-09 22:59:00    615.0     2023-08-10 06:15:00
# 3        2023-08-10 23:02:00    558.0     2023-08-11 05:58:00
# 4        2023-08-12 23:14:00    624.0     2023-08-13 06:24:00
# 5        2023-08-14 00:03:00    740.0     2023-08-14 07:40:00
# 6        2023-08-14 23:06:00    628.0     2023-08-15 06:28:00
# 7        2023-08-15 23:12:00    632.0     2023-08-16 06:32:00
# 8        2023-08-16 23:16:00    636.0     2023-08-17 06:36:00
# 9        2023-08-17 23:15:00    647.0     2023-08-18 06:47:00
# 10       2023-08-19 02:15:00    936.0     2023-08-19 09:36:00
# 11       2023-08-19 23:57:00    707.0     2023-08-20 07:07:00
# 12       2023-08-20 23:19:00    652.0     2023-08-21 06:52:00
# 13       2023-08-21 23:01:00    646.0     2023-08-22 06:46:00
# 14       2023-08-22 23:23:00    645.0     2023-08-23 06:45:00
# 15       2023-08-23 23:16:00    645.0     2023-08-24 06:45:00
# 16       2023-08-24 23:02:00    649.0     2023-08-25 06:49:00
# 17       2023-08-25 23:19:00    653.0     2023-08-26 06:53:00
# 18       2023-08-26 23:01:00    613.0     2023-08-27 06:13:00
# 19       2023-08-27 23:03:00    638.0     2023-08-28 06:38:00

# %%
"""def cross_validate_datetime(df, date_col, dep_time_col, arr_time_col, cancelled_col):
    errors = []

    # Replace '2400' with '0000' to represent midnight
    df[dep_time_col] = df[dep_time_col].replace(2400, 0)
    df[arr_time_col] = df[arr_time_col].replace(2400, 0)

    # Only convert DepTime and ArrTime for non-canceled flights
    df_valid_times = df[df[cancelled_col] == 0].copy()

    # Convert DepTime and ArrTime to integers and then to datetime
    df_valid_times[dep_time_col] = df_valid_times[dep_time_col].dropna().astype(int)
    df_valid_times[arr_time_col] = df_valid_times[arr_time_col].dropna().astype(int)

    df_valid_times['DepTime_converted'] = pd.to_datetime(
        df_valid_times[date_col].astype(str) + ' ' + df_valid_times[dep_time_col].astype(str).str.zfill(4),
        format='%Y-%m-%d %H%M', errors='coerce'
    )
    df_valid_times['ArrTime_converted'] = pd.to_datetime(
        df_valid_times[date_col].astype(str) + ' ' + df_valid_times[arr_time_col].astype(str).str.zfill(4),
        format='%Y-%m-%d %H%M', errors='coerce'
    )
    # Adjust for next-day departures (positive DepDelay and DepTime earlier than CRSDepTime)
    df_valid_times.loc[
        (df_valid_times['DepDelay'] > 0) & 
        (df_valid_times['DepTime_converted'] < df_valid_times['scheduled_departure_datetime']), 
        'DepTime_converted'
    ] += pd.Timedelta(days=1)

    # Adjust for next-day arrivals (similar to the original function)
    df_valid_times.loc[df_valid_times['ArrTime_converted'] < df_valid_times['DepTime_converted'], 'ArrTime_converted'] += pd.Timedelta(days=1)

     # Validate: DepTime should equal actual_departure_datetime, accounting for NaN vs NaT
    incorrect_departure = df_valid_times[
        (~(df_valid_times['DepTime_converted'].isna() & df_valid_times['actual_departure_datetime'].isna())) & 
        (df_valid_times['DepTime_converted'] != df_valid_times['actual_departure_datetime'])
    ]
    if not incorrect_departure.empty:
        errors.append(f"Found {len(incorrect_departure)} rows where DepTime does not match actual_departure_datetime.")

    # Validate: ArrTime should equal actual_arrival_datetime, accounting for NaN vs NaT
    incorrect_arrival = df_valid_times[
        (~(df_valid_times['ArrTime_converted'].isna() & df_valid_times['actual_arrival_datetime'].isna())) & 
        (df_valid_times['ArrTime_converted'] != df_valid_times['actual_arrival_datetime'])
    ]
    if not incorrect_arrival.empty:
        errors.append(f"Found {len(incorrect_arrival)} rows where ArrTime does not match actual_arrival_datetime.")

    
    # Clean up temporary columns
    #df_valid_times.drop(columns=['DepTime_converted', 'ArrTime_converted'], inplace=True)

    df['DepTime_converted'] = df_valid_times['DepTime_converted']
    df['ArrTime_converted'] = df_valid_times['ArrTime_converted']
     
    if errors:
        return errors
    else:
        return "All validations passed."""
# Out:
# 'def cross_validate_datetime(df, date_col, dep_time_col, arr_time_col, cancelled_col):\n    errors = []\n\n    # Replace \'2400\' with \'0000\' to represent midnight\n    df[dep_time_col] = df[dep_time_col].replace(2400, 0)\n    df[arr_time_col] = df[arr_time_col].replace(2400, 0)\n\n    # Only convert DepTime and ArrTime for non-canceled flights\n    df_valid_times = df[df[cancelled_col] == 0].copy()\n\n    # Convert DepTime and ArrTime to integers and then to datetime\n    df_valid_times[dep_time_col] = df_valid_times[dep_time_col].dropna().astype(int)\n    df_valid_times[arr_time_col] = df_valid_times[arr_time_col].dropna().astype(int)\n\n    df_valid_times[\'DepTime_converted\'] = pd.to_datetime(\n        df_valid_times[date_col].astype(str) + \' \' + df_valid_times[dep_time_col].astype(str).str.zfill(4),\n        format=\'%Y-%m-%d %H%M\', errors=\'coerce\'\n    )\n    df_valid_times[\'ArrTime_converted\'] = pd.to_datetime(\n        df_valid_times[date_col].astype(str) + \' \' + df_valid_times[arr_time_col].astype(str).str.zfill(4),\n        format=\'%Y-%m-%d %H%M\', errors=\'coerce\'\n    )\n    # Adjust for next-day departures (positive DepDelay and DepTime earlier than CRSDepTime)\n    df_valid_times.loc[\n        (df_valid_times[\'DepDelay\'] > 0) & \n        (df_valid_times[\'DepTime_converted\'] < df_valid_times[\'scheduled_departure_datetime\']), \n        \'DepTime_converted\'\n    ] += pd.Timedelta(days=1)\n\n    # Adjust for next-day arrivals (similar to the original function)\n    df_valid_times.loc[df_valid_times[\'ArrTime_converted\'] < df_valid_times[\'DepTime_converted\'], \'ArrTime_converted\'] += pd.Timedelta(days=1)\n\n     # Validate: DepTime should equal actual_departure_datetime, accounting for NaN vs NaT\n    incorrect_departure = df_valid_times[\n        (~(df_valid_times[\'DepTime_converted\'].isna() & df_valid_times[\'actual_departure_datetime\'].isna())) & \n        (df_valid_times[\'DepTime_converted\'] != df_valid_times[\'actual_departure_datetime\'])\n    ]\n    if not incorrect_departure.empty:\n        errors.append(f"Found {len(incorrect_departure)} rows where DepTime does not match actual_departure_datetime.")\n\n    # Validate: ArrTime should equal actual_arrival_datetime, accounting for NaN vs NaT\n    incorrect_arrival = df_valid_times[\n        (~(df_valid_times[\'ArrTime_converted\'].isna() & df_valid_times[\'actual_arrival_datetime\'].isna())) & \n        (df_valid_times[\'ArrTime_converted\'] != df_valid_times[\'actual_arrival_datetime\'])\n    ]\n    if not incorrect_arrival.empty:\n        errors.append(f"Found {len(incorrect_arrival)} rows where ArrTime does not match actual_arrival_datetime.")\n\n    \n    # Clean up temporary columns\n    #df_valid_times.drop(columns=[\'DepTime_converted\', \'ArrTime_converted\'], inplace=True)\n\n    df[\'DepTime_converted\'] = df_valid_times[\'DepTime_converted\']\n    df[\'ArrTime_converted\'] = df_valid_times[\'ArrTime_converted\']\n     \n    if errors:\n        return errors\n    else:\n        return "All validations passed.'

# %%
# Split the 'DepTimeBlk' into two columns to see if all blocks are 59 minutes long or are there some that are longer and shorter
df_dt_fixed['DeptTimeBlk_Start'] = df_dt_fixed['DepTimeBlk'].str.split('-').str[0].astype(int)
df_dt_fixed['DeptTimeBlk_End'] = df_dt_fixed['DepTimeBlk'].str.split('-').str[1].astype(int)

# Split the 'ArrTimeBlk' into two columns to see if all blocks are 59 minutes long or are there some that are longer and shorter
df_dt_fixed['ArrTimeBlk_Start'] = df_dt_fixed['ArrTimeBlk'].str.split('-').str[0].astype(int)
df_dt_fixed['ArrTimeBlk_End'] = df_dt_fixed['ArrTimeBlk'].str.split('-').str[1].astype(int)

# %%
df_dt_fixed['ArrivalBlock_Total'] = df_dt_fixed['ArrTimeBlk_End'] - df_dt_fixed['ArrTimeBlk_Start']
df_dt_fixed['DepartureBlock_Total'] = df_dt_fixed['DeptTimeBlk_End'] - df_dt_fixed['DeptTimeBlk_Start']

# %%
df_dt_fixed[['DepartureBlock_Total', 'ArrivalBlock_Total']].describe().apply(lambda x: x.apply('{0:.2f}'.format))
# Out:
#       DepartureBlock_Total ArrivalBlock_Total
# count           7260941.00         7260941.00
# mean                 74.18              72.08
# std                  85.69              79.72
# min                  59.00              59.00
# 25%                  59.00              59.00
# 50%                  59.00              59.00
# 75%                  59.00              59.00
# max                 558.00             558.00

# %% [markdown]
# I'm curious to know why some flights have 558 minutes for their scheduled block. Let's take a look.

# %%
df_dt_fixed.sort_values('DepartureBlock_Total', ascending=False).head(10)
# Out:
#          Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate  \
# 4564220  2023        2      5          28          7 2023-05-28
# 1631850  2023        3      7          25          2 2023-07-25
# 1631812  2023        3      7          25          2 2023-07-25
# 2971774  2023        2      6           9          5 2023-06-09
# 1631821  2023        3      7          25          2 2023-07-25
# 1631825  2023        3      7          25          2 2023-07-25
# 2971759  2023        2      6           9          5 2023-06-09
# 2971756  2023        2      6           9          5 2023-06-09
# 1631846  2023        3      7          25          2 2023-07-25
# 2971743  2023        2      6           9          5 2023-06-09
#
#          DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 4564220                     19790                          DL
# 1631850                     19393                          WN
# 1631812                     19393                          WN
# 2971774                     19393                          WN
# 1631821                     19393                          WN
# 1631825                     19393                          WN
# 2971759                     19393                          WN
# 2971756                     19393                          WN
# 1631846                     19393                          WN
# 2971743                     19393                          WN
#
#          Flight_Number_Marketing_Airline  DOT_ID_Operating_Airline  \
# 4564220                             1116                     19790
# 1631850                             3486                     19393
# 1631812                             3781                     19393
# 2971774                             1653                     19393
# 1631821                             3773                     19393
# 1631825                             1865                     19393
# 2971759                             1126                     19393
# 2971756                             3352                     19393
# 1631846                             3667                     19393
# 2971743                             1615                     19393
#
#         IATA_Code_Operating_Airline Tail_Number  OriginAirportID  \
# 4564220                          DL      N681DA            15304
# 1631850                          WN      N8511K            13232
# 1631812                          WN      N8643A            13232
# 2971774                          WN      N8560Z            13198
# 1631821                          WN      N7841A            13232
# 1631825                          WN      N408WN            13232
# 2971759                          WN      N8853Q            13198
# 2971756                          WN      N400WN            13198
# 1631846                          WN      N244WN            13232
# 2971743                          WN      N8550Q            13158
#
#          OriginCityMarketID Origin OriginState  DestAirportID  \
# 4564220               33195    TPA          FL          10397
# 1631850               30977    MDW          IL          13796
# 1631812               30977    MDW          IL          12953
# 2971774               33198    MCI          MO          12191
# 1631821               30977    MDW          IL          13198
# 1631825               30977    MDW          IL          13204
# 2971759               33198    MCI          MO          11259
# 2971756               33198    MCI          MO          10821
# 1631846               30977    MDW          IL          13495
# 2971743               33158    MAF          TX          12191
#
#          DestCityMarketID Dest DestState  CRSDepTime  DepTime  DepDelay  \
# 4564220             30397  ATL        GA         520    513.0      -7.0
# 1631850             32457  OAK        CA         525    528.0       3.0
# 1631812             31703  LGA        NY         520    517.0      -3.0
# 2971774             31453  HOU        TX         520    524.0       4.0
# 1631821             33198  MCI        MO         550    544.0      -6.0
# 1631825             31454  MCO        FL         530    551.0      21.0
# 2971759             30194  DAL        TX         540    540.0       0.0
# 2971756             30852  BWI        MD         530    533.0       3.0
# 1631846             33495  MSY        LA         545    539.0      -6.0
# 2971743             31453  HOU        TX         530      NaN      -7.0
#
#          DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  \
# 4564220       0.0                  -1.0  0001-0559     12.0      525.0
# 1631850       0.0                   0.0  0001-0559      9.0      537.0
# 1631812       0.0                  -1.0  0001-0559     10.0      527.0
# 2971774       0.0                   0.0  0001-0559     13.0      537.0
# 1631821       0.0                  -1.0  0001-0559      9.0      553.0
# 1631825       1.0                   1.0  0001-0559      8.0      559.0
# 2971759       0.0                   0.0  0001-0559     15.0      555.0
# 2971756       0.0                   0.0  0001-0559     12.0      545.0
# 1631846       0.0                  -1.0  0001-0559     10.0      549.0
# 2971743       0.0                  -1.0  0001-0559      NaN        NaN
#
#          WheelsOn  TaxiIn  CRSArrTime  ArrTime  ArrDelay  ArrDel15  \
# 4564220     626.0     5.0         650    631.0     -19.0       0.0
# 1631850     730.0     7.0         750    737.0     -13.0       0.0
# 1631812     803.0     7.0         825    810.0     -15.0       0.0
# 2971774     708.0     6.0         720    714.0      -6.0       0.0
# 1631821     650.0     4.0         710    654.0     -16.0       0.0
# 1631825     902.0     7.0         900    909.0       9.0       0.0
# 2971759     659.0     4.0         710    703.0      -7.0       0.0
# 2971756     854.0     2.0         850    856.0       6.0       0.0
# 1631846     733.0     4.0         800    737.0     -23.0       0.0
# 2971743       NaN     NaN         655      NaN       NaN       NaN
#
#          ArrivalDelayGroups ArrTimeBlk  Cancelled  Diverted  CRSElapsedTime  \
# 4564220                -2.0  0600-0659          0         0            90.0
# 1631850                -1.0  0700-0759          0         0           265.0
# 1631812                -1.0  0800-0859          0         0           125.0
# 2971774                -1.0  0700-0759          0         0           120.0
# 1631821                -2.0  0700-0759          0         0            80.0
# 1631825                 0.0  0900-0959          0         0           150.0
# 2971759                -1.0  0700-0759          0         0            90.0
# 2971756                 0.0  0800-0859          0         0           140.0
# 1631846                -2.0  0800-0859          0         0           135.0
# 2971743                 NaN  0600-0659          1         0            85.0
#
#          ActualElapsedTime  AirTime  Flights  Distance  DistanceGroup  \
# 4564220               78.0     61.0      1.0     406.0              2
# 1631850              249.0    233.0      1.0    1844.0              8
# 1631812              113.0     96.0      1.0     725.0              3
# 2971774              110.0     91.0      1.0     666.0              3
# 1631821               70.0     57.0      1.0     405.0              2
# 1631825              138.0    123.0      1.0     990.0              4
# 2971759               83.0     64.0      1.0     461.0              2
# 2971756              143.0    129.0      1.0     967.0              4
# 1631846              118.0    104.0      1.0     825.0              4
# 2971743                NaN      NaN      1.0     441.0              2
#
#          CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 4564220           NaN           NaN       NaN            NaN
# 1631850           NaN           NaN       NaN            NaN
# 1631812           NaN           NaN       NaN            NaN
# 2971774           NaN           NaN       NaN            NaN
# 1631821           NaN           NaN       NaN            NaN
# 1631825           NaN           NaN       NaN            NaN
# 2971759           NaN           NaN       NaN            NaN
# 2971756           NaN           NaN       NaN            NaN
# 1631846           NaN           NaN       NaN            NaN
# 2971743           NaN           NaN       NaN            NaN
#
#          LateAircraftDelay  DivAirportLandings Duplicate  Code_Share_Flight  \
# 4564220                NaN                 0.0         N                  0
# 1631850                NaN                 0.0         N                  0
# 1631812                NaN                 0.0         N                  0
# 2971774                NaN                 0.0         N                  0
# 1631821                NaN                 0.0         N                  0
# 1631825                NaN                 0.0         N                  0
# 2971759                NaN                 0.0         N                  0
# 2971756                NaN                 0.0         N                  0
# 1631846                NaN                 0.0         N                  0
# 2971743                NaN                 0.0         N                  0
#
#             Origin_City Destination_City scheduled_departure_datetime  \
# 4564220           Tampa          Atlanta          2023-05-28 05:20:00
# 1631850         Chicago          Oakland          2023-07-25 05:25:00
# 1631812         Chicago         New York          2023-07-25 05:20:00
# 2971774     Kansas City          Houston          2023-06-09 05:20:00
# 1631821         Chicago      Kansas City          2023-07-25 05:50:00
# 1631825         Chicago          Orlando          2023-07-25 05:30:00
# 2971759     Kansas City           Dallas          2023-06-09 05:40:00
# 2971756     Kansas City        Baltimore          2023-06-09 05:30:00
# 1631846         Chicago      New Orleans          2023-07-25 05:45:00
# 2971743  Midland/Odessa          Houston          2023-06-09 05:30:00
#
#         scheduled_arrival_datetime actual_departure_datetime  \
# 4564220        2023-05-28 06:50:00       2023-05-28 05:13:00
# 1631850        2023-07-25 07:50:00       2023-07-25 05:28:00
# 1631812        2023-07-25 08:25:00       2023-07-25 05:17:00
# 2971774        2023-06-09 07:20:00       2023-06-09 05:24:00
# 1631821        2023-07-25 07:10:00       2023-07-25 05:44:00
# 1631825        2023-07-25 09:00:00       2023-07-25 05:51:00
# 2971759        2023-06-09 07:10:00       2023-06-09 05:40:00
# 2971756        2023-06-09 08:50:00       2023-06-09 05:33:00
# 1631846        2023-07-25 08:00:00       2023-07-25 05:39:00
# 2971743        2023-06-09 06:55:00                       NaT
#
#         actual_arrival_datetime  DeptTimeBlk_Start  DeptTimeBlk_End  \
# 4564220     2023-05-28 06:31:00                  1              559
# 1631850     2023-07-25 07:37:00                  1              559
# 1631812     2023-07-25 08:10:00                  1              559
# 2971774     2023-06-09 07:14:00                  1              559
# 1631821     2023-07-25 06:54:00                  1              559
# 1631825     2023-07-25 09:09:00                  1              559
# 2971759     2023-06-09 07:03:00                  1              559
# 2971756     2023-06-09 08:56:00                  1              559
# 1631846     2023-07-25 07:37:00                  1              559
# 2971743                     NaT                  1              559
#
#          ArrTimeBlk_Start  ArrTimeBlk_End  ArrivalBlock_Total  \
# 4564220               600             659                  59
# 1631850               700             759                  59
# 1631812               800             859                  59
# 2971774               700             759                  59
# 1631821               700             759                  59
# 1631825               900             959                  59
# 2971759               700             759                  59
# 2971756               800             859                  59
# 1631846               800             859                  59
# 2971743               600             659                  59
#
#          DepartureBlock_Total
# 4564220                   558
# 1631850                   558
# 1631812                   558
# 2971774                   558
# 1631821                   558
# 1631825                   558
# 2971759                   558
# 2971756                   558
# 1631846                   558
# 2971743                   558

# %%
from datetime import time

after_midnight_flights = df_dt_fixed[df_dt_fixed['scheduled_departure_datetime'].dt.time > time(0, 0)]
after_midnight_flights.sort_values('scheduled_departure_datetime').head()
# Out:
#          Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate  \
# 5798101  2023        1      1           1          7 2023-01-01
# 5634850  2023        1      1           1          7 2023-01-01
# 5823363  2023        1      1           1          7 2023-01-01
# 5719531  2023        1      1           1          7 2023-01-01
# 5610819  2023        1      1           1          7 2023-01-01
#
#          DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 5798101                     19930                          AS
# 5634850                     20436                          F9
# 5823363                     20409                          B6
# 5719531                     19805                          AA
# 5610819                     19790                          DL
#
#          Flight_Number_Marketing_Airline  DOT_ID_Operating_Airline  \
# 5798101                              150                     19930
# 5634850                             1524                     20436
# 5823363                              956                     20409
# 5719531                              500                     19805
# 5610819                             1099                     19790
#
#         IATA_Code_Operating_Airline Tail_Number  OriginAirportID  \
# 5798101                          AS      N588AS            10299
# 5634850                          F9      N381FR            14771
# 5823363                          B6      N594JB            11292
# 5719531                          AA      N457AM            11292
# 5610819                          DL      N381DZ            12892
#
#          OriginCityMarketID Origin OriginState  DestAirportID  \
# 5798101               30299    ANC          AK          12892
# 5634850               32457    SFO          CA          10397
# 5823363               30325    DEN          CO          12953
# 5719531               30325    DEN          CO          13303
# 5610819               32575    LAX          CA          13487
#
#          DestCityMarketID Dest DestState  CRSDepTime  DepTime  DepDelay  \
# 5798101             32575  LAX        CA           5   2357.0      -8.0
# 5634850             30397  ATL        GA           9    130.0      81.0
# 5823363             31703  LGA        NY          20     18.0      -2.0
# 5719531             32467  MIA        FL          20     18.0      -2.0
# 5610819             31650  MSP        MN          20     13.0      -7.0
#
#          DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  \
# 5798101       0.0                  -1.0  0001-0559     12.0        9.0
# 5634850       1.0                   5.0  0001-0559     12.0      142.0
# 5823363       0.0                  -1.0  0001-0559     11.0       29.0
# 5719531       0.0                  -1.0  0001-0559     12.0       30.0
# 5610819       0.0                  -1.0  0001-0559     11.0       24.0
#
#          WheelsOn  TaxiIn  CRSArrTime  ArrTime  ArrDelay  ArrDel15  \
# 5798101     557.0    17.0         620    614.0      -6.0       0.0
# 5634850     843.0    15.0         749    858.0      69.0       1.0
# 5823363     527.0     7.0         558    534.0     -24.0       0.0
# 5719531     540.0     4.0         607    544.0     -23.0       0.0
# 5610819     515.0     9.0         603    524.0     -39.0       0.0
#
#          ArrivalDelayGroups ArrTimeBlk  Cancelled  Diverted  CRSElapsedTime  \
# 5798101                -1.0  0600-0659          0         0           315.0
# 5634850                 4.0  0700-0759          0         0           280.0
# 5823363                -2.0  0001-0559          0         0           218.0
# 5719531                -2.0  0600-0659          0         0           227.0
# 5610819                -2.0  0600-0659          0         0           223.0
#
#          ActualElapsedTime  AirTime  Flights  Distance  DistanceGroup  \
# 5798101              317.0    288.0      1.0    2345.0             10
# 5634850              268.0    241.0      1.0    2139.0              9
# 5823363              196.0    178.0      1.0    1620.0              7
# 5719531              206.0    190.0      1.0    1709.0              7
# 5610819              191.0    171.0      1.0    1535.0              7
#
#          CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 5798101           NaN           NaN       NaN            NaN
# 5634850          49.0           0.0       0.0            0.0
# 5823363           NaN           NaN       NaN            NaN
# 5719531           NaN           NaN       NaN            NaN
# 5610819           NaN           NaN       NaN            NaN
#
#          LateAircraftDelay  DivAirportLandings Duplicate  Code_Share_Flight  \
# 5798101                NaN                 0.0         N                  0
# 5634850               20.0                 0.0         N                  0
# 5823363                NaN                 0.0         N                  0
# 5719531                NaN                 0.0         N                  0
# 5610819                NaN                 0.0         N                  0
#
#            Origin_City Destination_City scheduled_departure_datetime  \
# 5798101      Anchorage      Los Angeles          2023-01-01 00:05:00
# 5634850  San Francisco          Atlanta          2023-01-01 00:09:00
# 5823363         Denver         New York          2023-01-01 00:20:00
# 5719531         Denver            Miami          2023-01-01 00:20:00
# 5610819    Los Angeles      Minneapolis          2023-01-01 00:20:00
#
#         scheduled_arrival_datetime actual_departure_datetime  \
# 5798101        2023-01-01 06:20:00       2022-12-31 23:57:00
# 5634850        2023-01-01 07:49:00       2023-01-01 01:30:00
# 5823363        2023-01-01 05:58:00       2023-01-01 00:18:00
# 5719531        2023-01-01 06:07:00       2023-01-01 00:18:00
# 5610819        2023-01-01 06:03:00       2023-01-01 00:13:00
#
#         actual_arrival_datetime  DeptTimeBlk_Start  DeptTimeBlk_End  \
# 5798101     2023-01-01 06:14:00                  1              559
# 5634850     2023-01-01 08:58:00                  1              559
# 5823363     2023-01-01 05:34:00                  1              559
# 5719531     2023-01-01 05:44:00                  1              559
# 5610819     2023-01-01 05:24:00                  1              559
#
#          ArrTimeBlk_Start  ArrTimeBlk_End  ArrivalBlock_Total  \
# 5798101               600             659                  59
# 5634850               700             759                  59
# 5823363                 1             559                 558
# 5719531               600             659                  59
# 5610819               600             659                  59
#
#          DepartureBlock_Total
# 5798101                   558
# 5634850                   558
# 5823363                   558
# 5719531                   558
# 5610819                   558

# %% [markdown]
# Flights that depart or arrive after midnight and before 6AM have 558 minutes blocked for their departure/arrival time. All other flights only have 59 minutes for their scheduled block. This is likely due to allow for logistics and scheduling for airport operations for these overnight/really early flights. It may be helpful to categorize flights as overnight departure or overnight arrival events compared to all other flights.

# %%
overnight_departures = (df_dt_fixed['DepartureBlock_Total'] > 60)
overnight_arrivals = (df_dt_fixed['ArrivalBlock_Total'] > 60)

# %%
df_dt_fixed['Overnight_Depature'] = overnight_departures.astype(int)
df_dt_fixed['Overnight_Arrival'] = overnight_arrivals.astype(int)

# %%
df_dt_fixed.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate  \
# 0  2023        3      8           6          7 2023-08-06
# 1  2023        3      8           7          1 2023-08-07
# 2  2023        3      8           9          3 2023-08-09
# 3  2023        3      8          10          4 2023-08-10
# 4  2023        3      8          12          6 2023-08-12
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 0                     20416                          NK
# 1                     20416                          NK
# 2                     20416                          NK
# 3                     20416                          NK
# 4                     20416                          NK
#
#    Flight_Number_Marketing_Airline  DOT_ID_Operating_Airline  \
# 0                             2252                     20416
# 1                             2252                     20416
# 2                             2252                     20416
# 3                             2252                     20416
# 4                             2252                     20416
#
#   IATA_Code_Operating_Airline Tail_Number  OriginAirportID  \
# 0                          NK      N978NK            12889
# 1                          NK      N974NK            12889
# 2                          NK      N519NK            12889
# 3                          NK      N532NK            12889
# 4                          NK      N529NK            12889
#
#    OriginCityMarketID Origin OriginState  DestAirportID  DestCityMarketID  \
# 0               32211    LAS          NV          11057             31057
# 1               32211    LAS          NV          11057             31057
# 2               32211    LAS          NV          11057             31057
# 3               32211    LAS          NV          11057             31057
# 4               32211    LAS          NV          11057             31057
#
#   Dest DestState  CRSDepTime  DepTime  DepDelay  DepDel15  \
# 0  CLT        NC        2359      NaN       NaN       NaN
# 1  CLT        NC        2359    115.0      76.0       1.0
# 2  CLT        NC        2310   2259.0     -11.0       0.0
# 3  CLT        NC        2310   2302.0      -8.0       0.0
# 4  CLT        NC        2310   2314.0       4.0       0.0
#
#    DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  WheelsOn  TaxiIn  \
# 0                   NaN  2300-2359      NaN        NaN       NaN     NaN
# 1                   5.0  2300-2359     19.0      134.0     822.0     9.0
# 2                  -1.0  2300-2359     14.0     2313.0     605.0    10.0
# 3                  -1.0  2300-2359     12.0     2314.0     551.0     7.0
# 4                   0.0  2300-2359     18.0     2332.0     618.0     6.0
#
#    CRSArrTime  ArrTime  ArrDelay  ArrDel15  ArrivalDelayGroups ArrTimeBlk  \
# 0         722      NaN       NaN       NaN                 NaN  0700-0759
# 1         722    831.0      69.0       1.0                 4.0  0700-0759
# 2         628    615.0     -13.0       0.0                -1.0  0600-0659
# 3         628    558.0     -30.0       0.0                -2.0  0600-0659
# 4         628    624.0      -4.0       0.0                -1.0  0600-0659
#
#    Cancelled  Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  Flights  \
# 0          1         0           263.0                NaN      NaN      1.0
# 1          0         0           263.0              256.0    228.0      1.0
# 2          0         0           258.0              256.0    232.0      1.0
# 3          0         0           258.0              236.0    217.0      1.0
# 4          0         0           258.0              250.0    226.0      1.0
#
#    Distance  DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  \
# 0    1916.0              8           NaN           NaN       NaN
# 1    1916.0              8           3.0           0.0       1.0
# 2    1916.0              8           NaN           NaN       NaN
# 3    1916.0              8           NaN           NaN       NaN
# 4    1916.0              8           NaN           NaN       NaN
#
#    SecurityDelay  LateAircraftDelay  DivAirportLandings Duplicate  \
# 0            NaN                NaN                 0.0         N
# 1            0.0               65.0                 0.0         N
# 2            NaN                NaN                 0.0         N
# 3            NaN                NaN                 0.0         N
# 4            NaN                NaN                 0.0         N
#
#    Code_Share_Flight Origin_City Destination_City  \
# 0                  0   Las Vegas        Charlotte
# 1                  0   Las Vegas        Charlotte
# 2                  0   Las Vegas        Charlotte
# 3                  0   Las Vegas        Charlotte
# 4                  0   Las Vegas        Charlotte
#
#   scheduled_departure_datetime scheduled_arrival_datetime  \
# 0          2023-08-06 23:59:00        2023-08-07 07:22:00
# 1          2023-08-07 23:59:00        2023-08-08 07:22:00
# 2          2023-08-09 23:10:00        2023-08-10 06:28:00
# 3          2023-08-10 23:10:00        2023-08-11 06:28:00
# 4          2023-08-12 23:10:00        2023-08-13 06:28:00
#
#   actual_departure_datetime actual_arrival_datetime  DeptTimeBlk_Start  \
# 0                       NaT                     NaT               2300
# 1       2023-08-08 01:15:00     2023-08-08 08:31:00               2300
# 2       2023-08-09 22:59:00     2023-08-10 06:15:00               2300
# 3       2023-08-10 23:02:00     2023-08-11 05:58:00               2300
# 4       2023-08-12 23:14:00     2023-08-13 06:24:00               2300
#
#    DeptTimeBlk_End  ArrTimeBlk_Start  ArrTimeBlk_End  ArrivalBlock_Total  \
# 0             2359               700             759                  59
# 1             2359               700             759                  59
# 2             2359               600             659                  59
# 3             2359               600             659                  59
# 4             2359               600             659                  59
#
#    DepartureBlock_Total  Overnight_Depature  Overnight_Arrival
# 0                    59                   0                  0
# 1                    59                   0                  0
# 2                    59                   0                  0
# 3                    59                   0                  0
# 4                    59                   0                  0

# %%
flight_perf_to_drop = ['FlightDate', 'CRSDepTime', 'DepTime', 'WheelsOff', 'WheelsOn', 'CRSArrTime', 'ArrTime',
                       'DepTimeBlk', 'ArrTimeBlk', 'DeptTimeBlk_Start', 'DeptTimeBlk_End', 'ArrTimeBlk_Start', 'ArrTimeBlk_End', 'ArrivalBlock_Total', 'DepartureBlock_Total']
flights_reduced = df_dt_fixed.drop(columns=flight_perf_to_drop)

# %%
flights_reduced.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  DOT_ID_Marketing_Airline  \
# 0  2023        3      8           6          7                     20416
# 1  2023        3      8           7          1                     20416
# 2  2023        3      8           9          3                     20416
# 3  2023        3      8          10          4                     20416
# 4  2023        3      8          12          6                     20416
#
#   IATA_Code_Marketing_Airline  Flight_Number_Marketing_Airline  \
# 0                          NK                             2252
# 1                          NK                             2252
# 2                          NK                             2252
# 3                          NK                             2252
# 4                          NK                             2252
#
#    DOT_ID_Operating_Airline IATA_Code_Operating_Airline Tail_Number  \
# 0                     20416                          NK      N978NK
# 1                     20416                          NK      N974NK
# 2                     20416                          NK      N519NK
# 3                     20416                          NK      N532NK
# 4                     20416                          NK      N529NK
#
#    OriginAirportID  OriginCityMarketID Origin OriginState  DestAirportID  \
# 0            12889               32211    LAS          NV          11057
# 1            12889               32211    LAS          NV          11057
# 2            12889               32211    LAS          NV          11057
# 3            12889               32211    LAS          NV          11057
# 4            12889               32211    LAS          NV          11057
#
#    DestCityMarketID Dest DestState  DepDelay  DepDel15  DepartureDelayGroups  \
# 0             31057  CLT        NC       NaN       NaN                   NaN
# 1             31057  CLT        NC      76.0       1.0                   5.0
# 2             31057  CLT        NC     -11.0       0.0                  -1.0
# 3             31057  CLT        NC      -8.0       0.0                  -1.0
# 4             31057  CLT        NC       4.0       0.0                   0.0
#
#    TaxiOut  TaxiIn  ArrDelay  ArrDel15  ArrivalDelayGroups  Cancelled  \
# 0      NaN     NaN       NaN       NaN                 NaN          1
# 1     19.0     9.0      69.0       1.0                 4.0          0
# 2     14.0    10.0     -13.0       0.0                -1.0          0
# 3     12.0     7.0     -30.0       0.0                -2.0          0
# 4     18.0     6.0      -4.0       0.0                -1.0          0
#
#    Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  Flights  Distance  \
# 0         0           263.0                NaN      NaN      1.0    1916.0
# 1         0           263.0              256.0    228.0      1.0    1916.0
# 2         0           258.0              256.0    232.0      1.0    1916.0
# 3         0           258.0              236.0    217.0      1.0    1916.0
# 4         0           258.0              250.0    226.0      1.0    1916.0
#
#    DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0              8           NaN           NaN       NaN            NaN
# 1              8           3.0           0.0       1.0            0.0
# 2              8           NaN           NaN       NaN            NaN
# 3              8           NaN           NaN       NaN            NaN
# 4              8           NaN           NaN       NaN            NaN
#
#    LateAircraftDelay  DivAirportLandings Duplicate  Code_Share_Flight  \
# 0                NaN                 0.0         N                  0
# 1               65.0                 0.0         N                  0
# 2                NaN                 0.0         N                  0
# 3                NaN                 0.0         N                  0
# 4                NaN                 0.0         N                  0
#
#   Origin_City Destination_City scheduled_departure_datetime  \
# 0   Las Vegas        Charlotte          2023-08-06 23:59:00
# 1   Las Vegas        Charlotte          2023-08-07 23:59:00
# 2   Las Vegas        Charlotte          2023-08-09 23:10:00
# 3   Las Vegas        Charlotte          2023-08-10 23:10:00
# 4   Las Vegas        Charlotte          2023-08-12 23:10:00
#
#   scheduled_arrival_datetime actual_departure_datetime  \
# 0        2023-08-07 07:22:00                       NaT
# 1        2023-08-08 07:22:00       2023-08-08 01:15:00
# 2        2023-08-10 06:28:00       2023-08-09 22:59:00
# 3        2023-08-11 06:28:00       2023-08-10 23:02:00
# 4        2023-08-13 06:28:00       2023-08-12 23:14:00
#
#   actual_arrival_datetime  Overnight_Depature  Overnight_Arrival
# 0                     NaT                   0                  0
# 1     2023-08-08 08:31:00                   0                  0
# 2     2023-08-10 06:15:00                   0                  0
# 3     2023-08-11 05:58:00                   0                  0
# 4     2023-08-13 06:24:00                   0                  0

# %% [markdown]
# Ok all of the time columns have been converted. Now all the times and dates are in local times for each airport. I will need to add timezone information after getting the timezones for each airport.

# %% [markdown]
# ## Check for duplicates

# %%
flights_reduced.duplicated().sum()
# Out:
# 0

# %%
flights_reduced['Duplicate'].value_counts()
# Out:
# Duplicate
# N    7260941
# Name: count, dtype: int64

# %%
flights_reduced = flights_reduced.drop(columns='Duplicate')

# %% [markdown]
# ## Check column values

# %%
flights_reduced['Flights'].value_counts()
# Out:
# Flights
# 1.0    7260941
# Name: count, dtype: int64

# %% [markdown]
# The `Flights` column only contains the same value across all rows and is therefore not providing any new information.

# %%
flights_reduced.drop(columns='Flights', inplace=True)

# %%
# check unique values for day of
np.sort(flights_reduced['DayOfWeek'].unique())
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %% [markdown]
# There are only 7 unique values for day of week, as I would expect. According to the data dictionary, 1 = Monday and 7 = Sunday. They reserve 9 for unknown day of week, however, there are no occurences of an unknown day of week in this dataset.

# %%
flights_reduced.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  DOT_ID_Marketing_Airline  \
# 0  2023        3      8           6          7                     20416
# 1  2023        3      8           7          1                     20416
# 2  2023        3      8           9          3                     20416
# 3  2023        3      8          10          4                     20416
# 4  2023        3      8          12          6                     20416
#
#   IATA_Code_Marketing_Airline  Flight_Number_Marketing_Airline  \
# 0                          NK                             2252
# 1                          NK                             2252
# 2                          NK                             2252
# 3                          NK                             2252
# 4                          NK                             2252
#
#    DOT_ID_Operating_Airline IATA_Code_Operating_Airline Tail_Number  \
# 0                     20416                          NK      N978NK
# 1                     20416                          NK      N974NK
# 2                     20416                          NK      N519NK
# 3                     20416                          NK      N532NK
# 4                     20416                          NK      N529NK
#
#    OriginAirportID  OriginCityMarketID Origin OriginState  DestAirportID  \
# 0            12889               32211    LAS          NV          11057
# 1            12889               32211    LAS          NV          11057
# 2            12889               32211    LAS          NV          11057
# 3            12889               32211    LAS          NV          11057
# 4            12889               32211    LAS          NV          11057
#
#    DestCityMarketID Dest DestState  DepDelay  DepDel15  DepartureDelayGroups  \
# 0             31057  CLT        NC       NaN       NaN                   NaN
# 1             31057  CLT        NC      76.0       1.0                   5.0
# 2             31057  CLT        NC     -11.0       0.0                  -1.0
# 3             31057  CLT        NC      -8.0       0.0                  -1.0
# 4             31057  CLT        NC       4.0       0.0                   0.0
#
#    TaxiOut  TaxiIn  ArrDelay  ArrDel15  ArrivalDelayGroups  Cancelled  \
# 0      NaN     NaN       NaN       NaN                 NaN          1
# 1     19.0     9.0      69.0       1.0                 4.0          0
# 2     14.0    10.0     -13.0       0.0                -1.0          0
# 3     12.0     7.0     -30.0       0.0                -2.0          0
# 4     18.0     6.0      -4.0       0.0                -1.0          0
#
#    Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  Distance  \
# 0         0           263.0                NaN      NaN    1916.0
# 1         0           263.0              256.0    228.0    1916.0
# 2         0           258.0              256.0    232.0    1916.0
# 3         0           258.0              236.0    217.0    1916.0
# 4         0           258.0              250.0    226.0    1916.0
#
#    DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0              8           NaN           NaN       NaN            NaN
# 1              8           3.0           0.0       1.0            0.0
# 2              8           NaN           NaN       NaN            NaN
# 3              8           NaN           NaN       NaN            NaN
# 4              8           NaN           NaN       NaN            NaN
#
#    LateAircraftDelay  DivAirportLandings  Code_Share_Flight Origin_City  \
# 0                NaN                 0.0                  0   Las Vegas
# 1               65.0                 0.0                  0   Las Vegas
# 2                NaN                 0.0                  0   Las Vegas
# 3                NaN                 0.0                  0   Las Vegas
# 4                NaN                 0.0                  0   Las Vegas
#
#   Destination_City scheduled_departure_datetime scheduled_arrival_datetime  \
# 0        Charlotte          2023-08-06 23:59:00        2023-08-07 07:22:00
# 1        Charlotte          2023-08-07 23:59:00        2023-08-08 07:22:00
# 2        Charlotte          2023-08-09 23:10:00        2023-08-10 06:28:00
# 3        Charlotte          2023-08-10 23:10:00        2023-08-11 06:28:00
# 4        Charlotte          2023-08-12 23:10:00        2023-08-13 06:28:00
#
#   actual_departure_datetime actual_arrival_datetime  Overnight_Depature  \
# 0                       NaT                     NaT                   0
# 1       2023-08-08 01:15:00     2023-08-08 08:31:00                   0
# 2       2023-08-09 22:59:00     2023-08-10 06:15:00                   0
# 3       2023-08-10 23:02:00     2023-08-11 05:58:00                   0
# 4       2023-08-12 23:14:00     2023-08-13 06:24:00                   0
#
#    Overnight_Arrival
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %% [markdown]
# # Review IATA Codes Data
#
# I'll inpsect the IATA Codes dataset and fill in the Marketing and Operating Airline codes with the airline names for readability.

# %%
df_codes.head()
# Out:
#     Code                      Description
# 0  19031   Mackey International Inc.: MAC
# 1  19032  Munz Northern Airlines Inc.: XY
# 2  19033       Cochise Airlines Inc.: COC
# 3  19034   Golden Gate Airlines Inc.: GSA
# 4  19035               Aeromech Inc.: RZZ

# %%
df_codes.shape
# Out:
# (1737, 2)

# %%
df_codes['Airline_Name'] = df_codes['Description'].str.split(':').str[0].str.strip()
df_codes['IATA_Code'] = df_codes['Description'].str.split(':').str[1].str.strip()

# %%
df_codes.head()
# Out:
#     Code                      Description                 Airline_Name  \
# 0  19031   Mackey International Inc.: MAC    Mackey International Inc.
# 1  19032  Munz Northern Airlines Inc.: XY  Munz Northern Airlines Inc.
# 2  19033       Cochise Airlines Inc.: COC        Cochise Airlines Inc.
# 3  19034   Golden Gate Airlines Inc.: GSA    Golden Gate Airlines Inc.
# 4  19035               Aeromech Inc.: RZZ                Aeromech Inc.
#
#   IATA_Code
# 0       MAC
# 1        XY
# 2       COC
# 3       GSA
# 4       RZZ

# %%
duplicate_iata = df_codes[df_codes['IATA_Code'].duplicated(keep=False)]
sorted_duplicates = duplicate_iata.sort_values(by='IATA_Code')
sorted_duplicates
# Out:
# Empty DataFrame
# Columns: [Code, Description, Airline_Name, IATA_Code]
# Index: []

# %% [markdown]
# ## Replace IATA Codes in flights df with airline names

# %%
# create dictionary of codes and airlines
iata_dict = df_codes.set_index('IATA_Code')['Airline_Name'].to_dict()
iata_dict
# Out:
# {'MAC': 'Mackey International Inc.',
#  'XY': 'Munz Northern Airlines Inc.',
#  'COC': 'Cochise Airlines Inc.',
#  'GSA': 'Golden Gate Airlines Inc.',
#  'RZZ': 'Aeromech Inc.',
#  'GLW': 'Golden West Airlines Co.',
#  'PRN': 'Puerto Rico Intl Airlines',
#  'STZ': 'Air America Inc.',
#  'SWT': 'Swift Aire Lines Inc.',
#  'TSF': 'American Central Airlines',
#  'VEZ': 'Valdez Airlines',
#  'WEB': 'Southeast Alaska Airlines',
#  'AAR': 'Altair Airlines Inc.',
#  'CHI': 'Chitina Air Service',
#  'MRC': 'Marco Island Airways Inc.',
#  'OHZ': 'Caribbean Air Services Inc.',
#  'PRO': 'Sundance Airlines',
#  'SAI': 'Seair Alaska Airlines Inc.',
#  'SLZ': 'Southeast Airlines Inc.',
#  'AAZ': 'Alaska Aeronautical Indust.',
#  'IMP': 'Imperial Airlines Inc.',
#  'TWA': 'Trans Western Airlines Utah',
#  'WRT': 'Wright Airlines Inc.',
#  'COL': 'Presidential Express',
#  'MVA': 'Mississippi Valley Airlines',
#  'CHL': 'Channel Flying Inc.',
#  'JCZ': 'Rocky Mountain Airways Inc.',
#  'MIS': 'Midstate Airlines Inc.',
#  'STG': 'Sedalia Marshall Boonvl Stg',
#  'CKI': 'Inlet Airlines',
#  'CMD': 'Command Airways Inc.',
#  'EMA': 'Emerald Airlines',
#  'ORI': 'Orion Air Inc.',
#  'RAN': 'Pan Am Express',
#  'AJ': 'Air Micronesia Inc.',
#  'SKI': 'Sunbird Inc.',
#  'WWI': 'Wings West Airlines',
#  'AND': 'Southcentral Air Inc.',
#  'ACG': 'Air Cargo Express Inc.',
#  'AAA': 'Associated Aviation Act.',
#  'AAB (1)': 'Antilles Air Boats Inc.',
#  'AAE': 'AAA Airlines',
#  'AAL': 'Argosy Air Lines Inc.',
#  'ABH': 'Air Bahia',
#  'ABI': 'Airbama Incorporated',
#  'ABO': 'Aeronaves Boringuena Inc.',
#  'ACA': 'Alaska Central Airways Inc.',
#  'ACH': 'Island Airlines Hawaii Inc.',
#  'ACI': 'AAA-Action Air Carrier Inc.',
#  'ACO': 'Air Cargo Enterprises Inc.',
#  'ACP': 'Air Chaparral Inc.',
#  'ACS': 'Alamo Commuter Airlines',
#  'ACT': 'Air Central Inc. (1)',
#  'ACK': 'Air Central Inc.',
#  'AEC': 'Astec Air East Inc.',
#  'AFA': 'American Flag Airlines Inc.',
#  'AGA': 'Air Cargo America Inc.',
#  'AIA': 'All Island Air',
#  'AIE': 'Air Express Inc.',
#  'AIM': 'Air Mont. Inc.',
#  'AIN': 'Air Indiana',
#  'ALE': 'Air-Lift Associates Inc.',
#  'ALI': 'Brandt Air',
#  'ALL': 'All Seasons Air Pacific',
#  'AMA': 'North American Airlines Inc.',
#  'AMI': 'American Inter-Island Inc.',
#  'ANB': 'Air Nebraska Inc.',
#  'ANM': 'Airways Of New Mexico Inc.',
#  'ANO': 'Metro Air Northeast Vermont',
#  'ANT': 'Air North/Nenana',
#  'AOI': 'Trans New York',
#  'API': 'Arizona Pacific Inc.',
#  'APL': 'Appalachian Flying Service',
#  'APY': 'Air Polynesia Inc.',
#  'ARI': 'Arizona Aero Corp.',
#  'ARN': 'Arnold Aviation',
#  'ARO': 'Air Oregon',
#  'ARR': 'Arrowhead Airways Inc.',
#  'ASD': 'Amistad Airlines',
#  'ASI': 'Alpine Air Services Inc.',
#  'ASP': 'Asap Air Inc.',
#  'AST': 'Astro Airways',
#  'ATN': 'Air Atlantic Airlines Inc.',
#  'ATO': 'Pacific National Airways',
#  'ATS': 'Atlantis Airlines Inc.',
#  'ATT': 'Aerotransit Inc.',
#  'ATX': 'Air Carolina',
#  'AVA': 'Air Vectors Airways',
#  'AVI': 'Aero Virgin Islands Corp.',
#  'AVS': 'Aviation Services',
#  'AVZ': 'Southern Jersey Airways',
#  'BAC': 'Business Aircraft Corp.',
#  'BAH': 'Brennan & Hargreaves Inc.',
#  'BAK': 'Bankair Inc.',
#  'BAR': 'Bard-Air Corp.',
#  'BCA': 'Baja Cortez Airlines',
#  'BEN': 'Bennington Aviation Inc.',
#  'BEY': 'Beyer Aviation',
#  'BHK': 'Blackhawk Airways Inc.',
#  'BHO': 'Bighorn Airways Inc.',
#  'BIR': 'Birchwood Air Service',
#  'BMT': 'Bremerton Aviation Inc.',
#  'BOA': 'Boise Air Service',
#  'BRO': 'Brower Airways Inc.',
#  'BUR': 'Burlington Airways Inc.',
#  'CAC': 'Coleman Air Transport',
#  'CAI': 'Crawford Aviation Inc.',
#  'CAM': 'C & M Airlines',
#  'CAP': 'Metro Air Northeast N Y',
#  'CAT': 'Catalina Airlines Inc.',
#  'CAV': 'Air Virginia',
#  'CBA': 'Carriba Air Inc.',
#  'CEN': 'Cen-Tex Airlines Inc.',
#  'CET': 'Century Airlines (Cal)',
#  'CHD': 'Chandler Flyer',
#  'CHE': 'Charter Airlines',
#  'CHF': 'Hammonds Commuter Air Serv.',
#  'CHO': 'Choi Aviation Inc.',
#  'CHS': 'Christman Air System',
#  'CIS': 'Cal Sierra Airlines',
#  'CNN': 'Centennial Airlines',
#  'COB': 'Cotton Belt Aviation Inc.',
#  'COK': 'Coker Aviation Inc.',
#  'COM': 'Commutair',
#  'COR': 'Coral Air Inc.',
#  'COS': 'Cosmopolitan Comm. Airline',
#  'COT': 'Southeastern Commuter',
#  'COU': 'Courtesy Air Service Inc.',
#  'CPA': 'Capitol Air Lines',
#  'CPC': 'Coastal Plains Commuter Inc.',
#  'CRA': 'Commuter Airlines',
#  'CRN': 'Crown Aviaiton Inc.',
#  'CRO': 'Crown Airways Inc.',
#  'CRT': 'Crested Butte Air Service',
#  'CSK': 'Catskill Airways Inc.',
#  'CTA': 'Century Airlines',
#  'CTH': 'Cothron Aviation',
#  'CVA': 'Catalina-Vegas Airlines',
#  'DAN': 'Danbury Airlines',
#  'DEA': 'Downeast Airlines Inc.',
#  'DEC': 'Decatur Aviation',
#  'DHL': 'DHL Airlines Inc.',
#  'DIC': 'Dickman Aviation Services',
#  'DPA': 'Desert Pacific Airways',
#  'DPI': 'Desert Pacific Airlines Inc.',
#  'DST': 'Desert Airlines',
#  'EAI': 'Executive Aviation Inc.',
#  'EAS': 'Eastern Caribbean Airways',
#  'ECI': 'Eastern Carolina Aviation',
#  'EDE': 'Ede Aire',
#  'EFA': 'Executive Four Winds',
#  'EGL': 'Eagle Commuter Airlines Inc.',
#  'EHA': 'East Hampton Aire Inc.',
#  'EIA': 'East. Indiana Aviation Sale',
#  'EKA': 'Air Pacific Inc.',
#  'ERI': 'Erie Airways Inc.',
#  'ERO': 'Empire Aero Service',
#  'EVA': 'Evanston Aviation',
#  'FAR': 'Federal Armored Service Inc.',
#  'FBI': 'Young Flying Service',
#  'FCA': 'Southern Airlines Inc.',
#  'FDA': 'Florida Airlines Inc.',
#  'FDM': 'Freedom Airlines Inc.',
#  'FLM': 'Flamenco Airways Inc.',
#  'FOR': 'Ford-Aire Inc.',
#  'FOS': 'Foster Aviation',
#  'FVA': 'Skycraft Inc.',
#  'FWA': 'Far West Airlines',
#  'GAS': 'General Aviation Inc.',
#  'GAV': 'Gromer Aviation Inc.',
#  'GBA': 'Central States Airline',
#  'GCA (1)': 'Golden Carriage Aire',
#  'GCS': 'Midway Commuter',
#  'GHA': 'Green Hills Aviation Ltd.',
#  'GMA': 'Green Mountain Airlines Ltd.',
#  'GOF': 'Copper State Airlines',
#  'GRO': 'Isle Royale Seaplane Serv.',
#  'GSL': 'Golden South Airlines Inc.',
#  'GUL': 'Gull Air Inc.',
#  'GUN': 'Gunnel Aviation Inc.',
#  'GWE': 'Ross Aviation Inc.',
#  'HEU': 'Heussler Air Service Corp',
#  'HFS': 'Hensley Flying Service Inc.',
#  'HMZ': 'Long Island Airlines',
#  'HOL': 'Holiday Airlines Inc.',
#  'HOR': 'Iowa Airlines',
#  'HPZ': 'Pacific Coast Airlines',
#  'HRA': 'Trans-National Airlines Haw',
#  'HSZ': 'Scenic Airlines Inc.',
#  'HUB': 'Skystream Airlines',
#  'HWK': 'Hawking Corporation',
#  'HYA': 'Hyannis Aviation',
#  'ICF': 'Iowa City Flying Service',
#  'III': 'Idee Industries Inc.',
#  'INA': 'Inland Empire Airlines Inc.',
#  'IND': 'Indiana Airways Inc. (Pa)',
#  'IPI': 'Indo-Pacific International',
#  'ISL': 'Island Airlines',
#  'JAM': 'Sunbelt Airlines Inc.',
#  'JCM': 'Air Chico',
#  'JER': 'Jer-Don Air',
#  'KAI': 'Knight Airlines Inc.',
#  'KEE': 'Key Airlines',
#  'KWZ': 'Crown Air',
#  'KXZ': 'Chaparral Airlines Inc.',
#  'LAN': 'Lancer Aviation Inc.',
#  'LAW': 'Lawrence Aviation',
#  'LHA': 'Havasu Airlines',
#  'LLA': 'Lakeland Aviation',
#  'LOS': 'Aero Commuter',
#  'LVA': 'Las Vegas Airlines',
#  'MAG': 'Magum Airlines',
#  'MAI': 'The Maui Commuter',
#  'MAR': "Marshall's Air Inc.",
#  'MAX': 'Maxair Inc.',
#  'MCO': 'Mid Continental Airlines In',
#  'MDU': 'Metro Airlines',
#  'MET': 'Metroplex Airlines',
#  'MIY': 'Midway Aviation Inc.',
#  'MLL': 'Miller Air Transportersinc',
#  'MMH': 'Ocean Airways Inc.',
#  'MNZ': 'Cumberland Airlines',
#  'MRR': 'Merrimack Aviation Inc.',
#  'MST': 'Midwest Aviation',
#  'MTA': 'Arkansas Traveler Airline',
#  'MTR': 'Metroflight Airlines',
#  'NAC': 'National Air Commuter Inc.',
#  'NEB': 'New Born Wings Inc.',
#  'NEC': 'Nor East Commuter Airlines',
#  'NEV': 'Nevada Airlines',
#  'NGL': 'Northern Eagle Airways Inc.',
#  'NHA': 'Newair Flight Inc.',
#  'NJA': 'N. J. Merrimack Airlines',
#  'NPT': 'E. J. A. Newport Inc.',
#  'NTH': 'Northaire',
#  'NUM': 'Lake State Airways',
#  'NYH': 'New York Helicopter Corp.',
#  'OAK': 'Harbor Airlines Inc.',
#  'OCR': 'Ocean Reef Airways Inc.',
#  'OFF': 'Offshore Logistics',
#  'OHA': 'Omaha Aviation',
#  'OIZ': 'Corporate Air Inc.',
#  'OMK': 'Omak Aviation Airlines',
#  'OMN': 'Omni Pacific Airline',
#  'OOZ': 'Sun Aire Lines',
#  'OWS': 'Air Kentucky Air Lines',
#  'PAI': 'Permian Airways Inc.',
#  'PBA': 'Provincetown Boston',
#  'PCA': 'Piasa Commuter Airlines',
#  'PDA': 'Trans Southern Airways',
#  'PEA': 'Pearson Aircraft',
#  'PER': 'Air Pennsylvania',
#  'PET': 'Petro Aviation Corp.',
#  'PHL': 'Phillips Airlines',
#  'PHX': 'Phoenix Airlines',
#  'PIA': 'Pacific Island Airways',
#  'PLA': 'Planes Inc.',
#  'PLZ': 'Polar Airways Inc.',
#  'PMA': 'Pacific Missionary Aviation',
#  'PNR': 'Pioneer Airways',
#  'POC': 'Pocono Airlines Inc.',
#  'POM': 'Pompano Airways',
#  'PON': 'Ponderosa Aviation Inc.',
#  'PRA': 'Princeton Aviation Corp',
#  'PRR': 'Pro Air Services',
#  'PVA': 'Precision Valley Aviation',
#  'QOZ': 'Bar Harbor Airways',
#  'RAL': 'Royal-Air Ltd.',
#  'REA': 'Realwest Airlines',
#  'RED': 'Aerosun International Airlines Inc.',
#  'RHA': 'Royal Hawaiian Airways Inc.',
#  'RIC': 'Richardson Aviation',
#  'RID': 'Indiana Airways Inc. (Reid',
#  'RIO': 'Rio Airways Inc.',
#  'RIV': 'Riverside Air Service',
#  'RJS': 'Michigan Airways Inc.',
#  'ROE': 'Roederer Aviation Inc.',
#  'ROY': 'Royal American Airways Inc.',
#  'RWG': 'Air Rovers Inc.',
#  'SAJ': 'Sajen Air Inc.',
#  'SAM': 'Samoan Airlines Inc.',
#  'SAS': 'Air Cortez International',
#  'SAX': 'Air Americana',
#  'SBA': 'Saber Aviation Inc.',
#  'SBN': 'Suburban Airlines',
#  'SCO': 'Seaco Airlines Inc.',
#  'SCT': 'Skyline Airlines',
#  'SCY': 'South Coast Airways',
#  'SEM': 'Semo Aviation Inc.',
#  'SFI': 'Stahmannfarms Inc.',
#  'SFO': 'Sfo Helicopter Airlines Inc.',
#  'SFS': 'Sierra Flite Service Inc.',
#  'SHS': 'Shasta Air Inc.',
#  'SHV': 'Shavano Air Inc.',
#  'SIA': 'Silver State Airlines',
#  'SJA': 'San Juan Airlines Inc.',
#  'SKL': 'Bas Airlines',
#  'SKM': 'Scheduled Skyways',
#  'SMC': 'Stopher Mechanical Inc.',
#  'SNC': 'Gelco Courier Services Inc.',
#  'SNE': 'Shawnee Airlines',
#  'SOA': 'Mall Airways Inc.',
#  'SOL': 'Soonair Lines Inc.',
#  'SPF': 'Springfield Air Service',
#  'SRL': 'Sterling Air Service',
#  'SSP': 'Southern Seaplane',
#  'SSS': 'Sierra Express Inc.',
#  'SST': 'Seaplane Shuttle Transport',
#  'STF': 'Trans East International',
#  'STR': 'Star Aviation Corporation',
#  'SUI': 'Sun International Airways',
#  'SUT': 'Sunbelt',
#  'SVL': 'Sun Valley Airlines',
#  'SWA': 'Sunwest Airlines',
#  'TAC': 'Air Colorado',
#  'TAL': 'Tejas Airlines Inc.',
#  'TAS': 'Yosemite Airlines Inc.',
#  'TCA': 'Trans Catalina Airlines',
#  'TCE': 'Oceanair Line',
#  'TCI': 'Trans California Airlines',
#  'TCL': 'Trans-Central Airlines Inc.',
#  'TCO': 'Trans-Colorado Airlines',
#  'TEN': 'Tennessee Airways Inc.',
#  'TER': 'Terre Haute Air Commuter',
#  'THO': 'Thorson Aviation',
#  'TIA': 'Trans Air Inc.',
#  'TIS': 'Skyfreight',
#  'TMA': 'Trans Mo Airlines',
#  'TNS': 'Transtate Aviation',
#  'TRP': 'Trans Pennsylvania Airlines',
#  'TSI': 'Trans Sierra Airlines Inc.',
#  'TUL': 'Tulsair Beechcraft Inc.',
#  'TYE': 'Temsco Airlines',
#  'UAI': 'Universal Airways Inc.',
#  'USA': 'Air U.S.',
#  'VAG': 'Vagabond Aviation Inc.',
#  'VER': 'Britt Airlines Inc.',
#  'VIG': 'Viking Express',
#  'VIN': 'Vale International Airlines',
#  'VLY': 'Valley Airlines',
#  'WAC': 'Air East Airlines',
#  'WCA': "Walker's International",
#  'WCI': 'Mountainwest Airlines',
#  'WES': 'Western Star Airlines Inc.',
#  'WET': 'Western Charter Inc.',
#  'WFS': 'Wheeler Airlines',
#  'WIA': 'Wisc Air',
#  'WIL': "Will's Air",
#  'WNG': 'Wings Airways',
#  'ZFZ': 'Mcphillips Flying Service',
#  'ZIA': 'Air New Mexico',
#  'ZMZ': 'Winnipesaukee Aviation Inc.',
#  'ZYZ': 'Skyway Aviation Inc.',
#  'PSA': 'P.S. Air Freight Inc.',
#  'RV (1)': 'Reeve Aleutian Airways Inc.',
#  'NW': 'Northwest Airlines Inc.',
#  'WC': 'Wien Air Alaska Inc.',
#  'FTI': 'Southern Airways',
#  'QH': 'Air Florida Inc.',
#  'OC': 'Air California Inc.',
#  'PS (1)': 'Pacific Southwest Airlines',
#  'RIQ': 'Rich International Airways',
#  'WN': 'Southwest Airlines Co.',
#  'VL': 'Mid-South Aviation Inc.',
#  'RCA': 'Mid-South Aviation Inc. (1)',
#  'QG': 'Sky West Aviation Inc.',
#  'RC (1)': 'Republic Airlines Inc.',
#  'DAU': 'Dauphin Island Airways',
#  'NY': 'New York Air Inc.',
#  'GIQ': 'Global International Airways Corp.',
#  'CJ': 'Colgan Airways Inc.',
#  'UNQ': 'Overseas National Airways',
#  'PTQ (1)': 'Flight International',
#  'ACD': 'Academy Airlines',
#  'ACL': 'Check-Air Inc.',
#  'ACW': 'Transwest Air Express',
#  'AIG': 'Airgo Inc.',
#  'AMT': 'American Air Transport',
#  'BOI': 'Bo-S-Aire Airlines Inc.',
#  'CMB': 'Combs Airways Inc.',
#  'DUZ': 'Summit Airlines Inc.',
#  'EEZ': 'Eagle Aviation Inc.',
#  'FAA': 'Falwell Aviation Inc.',
#  'FAC': 'Falcon Airways Inc.',
#  'PHR': 'Pinehurst Airlines Inc.',
#  'ROS': 'Great Western Airlines Inc.',
#  'RRT': 'Air Freight Express',
#  'SSA': 'S. S. Airways Inc.',
#  'XAA': 'Aero Union Corp',
#  'XAC': 'Air Express International Airlines',
#  'XAJ': 'Central American International',
#  'XAT': 'Michigan Peninsula Airways',
#  'XBF': 'WTC Airlines',
#  'XBH': 'Profit Airlines Inc.',
#  'XBI': 'CF Air Freight',
#  'XBJ': 'International Air Service',
#  'XBQ': 'Aeronaves De Puerto Rico',
#  'XBR': 'Allstates Air Cargo Inc.',
#  'XAQ': 'Cam Air International Inc.',
#  'XAZ': 'Purolator Sky Courier Inc.',
#  'XBP': 'Circle Airfreight Corp.',
#  'XBT': 'Pacific Alaska Airlines Inc.',
#  'XBX': 'Icb International Airlines',
#  'XAM': 'Cohlmia Aviation',
#  'XAE': 'Amerford Airways Inc.',
#  'XAF': 'Astro-Wing Airlines Inc.',
#  'XAG': 'Ball Brothers Inc.',
#  'XAI': 'Burlington Northern Inc.',
#  'XAK': 'Century Airlines Inc.',
#  'XAO': 'Dallas Flight Center',
#  'XAR': 'Jet Way Inc.',
#  'XAS': 'Klondike Air Inc.',
#  'XAY': 'Pat Air',
#  'XBM': 'Phh Air Inc.',
#  'XAU': 'Flight Line Inc.',
#  'CGL': 'Viking International Airlines Inc.',
#  'CL': 'Capitol International Inc.',
#  'AEQ': 'Air Caravane Inc.',
#  'AGQ': 'Argo S. A.',
#  'AIQ': 'Norontair',
#  'ALQ (1)': 'Alberta Northern Airlines',
#  'AO': 'Aviacion Y Comercio S.A.',
#  'BLQ': 'Air Bvi Limited',
#  'BXQ': 'Spantax S. A.',
#  'DA': 'Dan Air Services',
#  'DM': 'Maersk Air I/S',
#  'DOQ': 'Aerolineas Dominicanas S A',
#  'DQQ': 'Caribwest Airways Ltd.',
#  'EBQ': 'Execaire Aviation Ltd.',
#  'ERQ': 'Aero Trades (Western) Ltd.',
#  'FAQ': 'Fast Air Carrier Ltd. (1)',
#  'HIQ': 'Business Flights Ltd.',
#  'HRQ': 'Tar Airlines',
#  'HVQ': 'Transavia Holland B. V.',
#  'ICQ': 'Iscargo Hf',
#  'IKQ': 'Tradewinds Airways Ltd.',
#  'IN': 'Aerlinte Eireann Teoranta',
#  'IR': 'Iran National Airlines Corp',
#  'IXQ': 'Inair',
#  'JXQ': 'Allarco Developments Ltd.',
#  'KKQ': 'Transmeridian Air Cargo Ltd.',
#  'KWQ': 'Kelowna Flightcraft Air Cha',
#  'LIQ': 'Liat (1974) Limited',
#  'MAQ': 'Millardair Limited',
#  'MGQ': 'Montana Austria Flugetrieb',
#  'MZ': 'P.N. Merpati Nusantara Air.',
#  'NFQ': 'North Cariboo Flying Serv.',
#  'NKQ': 'Norcanair',
#  'NN': 'Northward Airlines Ltd.',
#  'NSQ': 'North Coast Air Services',
#  'NTQ': 'National Aviation Consult.',
#  'NUQ': 'Air Niugini',
#  'ONQ': 'Nunasi-Central Airlines Ltd.',
#  'OWQ': 'Ontario Worldair Limited',
#  'PD (1)': 'Pem-Air Limited',
#  'PV': 'Eastern Provincial Airways',
#  'PW': 'Pacific Western Airlines',
#  'QB': 'Inter-Quebec (Intair)',
#  'RB': 'Syrian Arab Airlines',
#  'RSQ': 'Aerotransportes Entre Rios',
#  'RY': 'Redcoat Air Cargo Limited',
#  'SJQ': 'Skycharter (Malton) Ltd.',
#  'SSQ': 'Superior Airways Limited',
#  'ST': 'Belize Airways Limited',
#  'STQ': 'Skycraft Air Transport Inc.',
#  'TLQ': 'Trans-Mediterranean Airways',
#  'TXQ': 'British Caribbean Airways',
#  'UMQ': 'Air Manila Inc.',
#  'VOQ': 'Avalon Aviation Ltd.',
#  'WDQ': 'Wardair Canada Inc.',
#  'WGQ': 'Gateway Aviation Limited',
#  'WM': 'Windward Islands Airways',
#  'XBV': 'Nal Inc.',
#  'YBQ': 'Yellow Bird Air',
#  'AE': 'Air Europe Limited',
#  'ND': 'Intair',
#  'JU (1)': 'Yugoslav Airlines',
#  'UT': 'Union De Transports Aeriens',
#  'HJ': 'Air Haiti S. A.',
#  'SH': 'Servicio Aereo De Honduras',
#  'NBQ': 'Sterling Airways A/S',
#  'SZQ': 'Aerolineas El Salvador S A',
#  'BOQ': 'Transp. Aereos Bolivianos',
#  'ADQ': 'Aeronaves Del Peru',
#  'DO': 'Compania Dominicana De Avia',
#  'WT': 'Nigeria Airways Ltd.',
#  'PZ': 'Lineas Aereas Paraguayas',
#  'GE': 'Lufthansa Cargo Airlines',
#  'VA (1)': 'Venezuelan International Airways',
#  'ED': 'Andes',
#  'CF': 'Compan. De Aviacion Faucett',
#  'GU (1)': 'Aviateca',
#  'CP (1)': 'Canadian Airlines International Ltd.',
#  'GY': 'Guyana Airways Corporation',
#  'ESQ': 'Seagreen Air Transport',
#  'ON': 'Air Nauru',
#  'PL': 'Aero Peru',
#  'BBQ': 'Balair Ag',
#  'SN (1)': 'Sabena Belgian World Air.',
#  'RK': 'Air Afrique',
#  'AC': 'Air Canada',
#  'AF': 'Compagnie Natl Air France',
#  'AI': 'National Aviation Company of India Limited d/b/a Air India',
#  'AM': 'Aeromexico',
#  'AR': 'Aerolineas Argentinas',
#  'AT': 'Royal Air Maroc',
#  'AV': 'Aerovias Nacl De Colombia',
#  'AY': 'Finnair Oy',
#  'AZ': 'Italia Transporto Aereo S.P.A DBA ITA S.P.A',
#  'BA': 'British Airways Plc',
#  'BD': 'British Midland Airways Ltd.',
#  'BW': 'Caribbean Airlines Limited',
#  'CA': 'Air China',
#  'CI': 'China Airlines Ltd.',
#  'CV': 'Cargolux Airlines International S.A',
#  'FI': 'Icelandair',
#  'IB': 'Iberia Air Lines Of Spain',
#  'JL': 'Japan Air Lines Co. Ltd.',
#  'JM': 'Air Jamaica Limited',
#  'KE': 'Korean Air Lines Co. Ltd.',
#  'KL': 'Klm Royal Dutch Airlines',
#  'LA': 'Lan-Chile Airlines',
#  'LB': 'Lloyd Aereo Boliviano S. A.',
#  'LH': 'Lufthansa German Airlines',
#  'LO': 'Polskie Linie Lotnicze',
#  'LR': 'Lacsa',
#  'LT': 'Luftransport-Unternehmen',
#  'LY': 'El Al Israel Airlines Ltd.',
#  'MX (1)': 'Compania Mexicana De Aviaci',
#  'NWQ': 'N. W. Territorial Airways',
#  'OA': 'Olympic Airways',
#  'PH': 'Polynesian Airlines Ltd.',
#  'PK': 'Pakistan International Airlines',
#  'PR': 'Philippine Airlines Inc.',
#  'PY': 'Surinam Airways Limited',
#  'QF': 'Qantas Airways Ltd.',
#  'RG': 'Varig S. A.',
#  'RJ': 'Alia-(The) Royal Jordanian',
#  'RO': 'Tarom Romanian Air Transpor',
#  'SA': 'South African Airways',
#  'SK': 'Scandinavian Airlines Sys.',
#  'SQ': 'Singapore Airlines Ltd.',
#  'SU': 'Aeroflot Russian Airlines',
#  'TA': 'Taca International Airlines',
#  'TG': 'Thai Airways International Ltd.',
#  'TP': 'TAP-TAP Air Portugal',
#  'UP': 'Bahamasair Holding Limited',
#  'MC': 'Transtar Airlines Corp.',
#  'HLQ': 'Heavylift Cargo Airlines Lt',
#  'UC': 'Ladeco',
#  'ALT': 'Altus Airlines',
#  'ANC': 'Atlantic Air',
#  'BAA': 'Aero International Airlines',
#  'DIR': 'Northern Star',
#  'SKT': 'Skytrain',
#  'TGO': 'Trans Air Cargo Inc.',
#  'THQ': 'T-Bird Air Inc.',
#  'ROA': 'Royal West Airways Inc.',
#  'AED': 'Air East Of Delaware Inc.',
#  'ALX': 'Atlanta Express',
#  'AOR': 'Air New Orleans',
#  'AVR': 'Air Vermont Inc.',
#  'DOL': 'Dolphin Airways Inc.',
#  'DVO': 'Devoe Airlines',
#  'KIN': 'Golden Pacific Airlines',
#  'NFA': 'National Florida Airlines',
#  'SLO': 'Slocum Air Inc.',
#  'STA': 'State Airlines Inc.',
#  'TRO': 'Air Molakai',
#  'WIR': 'Williams Air Inc.',
#  'WSU': 'Mission Air',
#  'HX (1)': 'Guy-America Airways Inc.',
#  'VB (1)': 'Pacific Express',
#  'QS (1)': 'Northeastern International Airways',
#  'HAR': 'Friendship Air Alaska',
#  'MIN': 'Minuteman Aviation Inc.',
#  'VIS': 'Virgin Islands Seaplane',
#  'FT': 'Flying Tiger Line Inc.',
#  'OD (1)': 'Aerocondor',
#  'OD': 'Emerald Airlines Inc.',
#  'NRN': 'Northern Airlines Inc.',
#  '6P': 'Pacific East Air Inc.',
#  'TJ': 'Jet Charter Service Inc.',
#  'EOQ': 'Aeroservicios Ecuatorianos',
#  'RAQ': 'Arista International Airlines Inc.',
#  'KU': 'Kuwait Airways Corp.',
#  'BAY': 'Burlington Aeroplane Co.',
#  'DSA': 'Desert Sun Airlines',
#  'LAS': 'Lake Union Air Service',
#  'QTQ': 'Aer Turas Teoranta',
#  'AFQ': 'Aero B Venezuela C.A.',
#  'GX': 'Air Ontario Limited',
#  'EI': 'Aer Lingus Plc',
#  'SV': 'Saudi Arabian Airlines Corp',
#  'XAB': 'Air Polynesia d/b/a DHL Cargo',
#  'XBZ': 'Air Natl Aircraft Sal & Ser',
#  'CIQ': 'A/S Conair',
#  'ANI': 'Dash Air Corporation',
#  'ARA': 'Air Resorts Airlines',
#  'MUA': "Manu'a Air Transport",
#  'PCL': 'Pacific Cal Air',
#  'SER': 'Service Aviation Inc.',
#  'TTM': 'The Time Machine',
#  'CMQ': 'Servicio De Carga Aerea Sa',
#  'HAQ (1)': 'Hapag Lloyd Flug.',
#  'CB': 'Air One Inc.',
#  'ME': 'Middle East Airlines S.A.L.',
#  'AFS': 'Arcata Flying Service',
#  'GRD': 'Grand Canyon Airlines',
#  'KOD': 'Kodiak Airways Inc.',
#  'MAE': 'Mid-Atlantic Exp. Airlines',
#  'NCA': 'National Commuter Airlines',
#  'SAC': 'Sundorph Aeronautical Corp.',
#  'WAR': 'Waring Air',
#  'EP': 'All Star Airlines Inc.',
#  'AXQ': 'Aeron International Airlines Inc.',
#  'JIQ': 'Jet Fleet Intl. Airlines',
#  'HER': 'Markair Express',
#  'LSZ': 'Alaska Island Air Inc.',
#  'AAT': 'Air Sunshine Inc.',
#  'EAT': 'Eastman Airways Inc.',
#  'SPH': 'Spirit Helicopter',
#  'AHQ': 'Air National',
#  'EXC (1)': 'Executive Charter',
#  'SNA': 'Aviation Associates',
#  'ARM': 'Airmarc Airlines Inc.',
#  'PAT': 'Panorama Air Tours',
#  'TKQ': 'Trans-Air-Link Corporation',
#  'AAI': 'Audi Air Inc.',
#  'GAQ': 'Galaxy Airlines Inc.',
#  'IDQ': 'Intl Air Service Co. Ltd.',
#  'TR (1)': 'Transbrasil S.A.',
#  'XCA': 'Hawkins And Powers Aviation',
#  'XBC': 'Jet East Inc.',
#  'ARS': 'Air Sedona',
#  'CRE': 'Caribbean Express Inc.',
#  'TFZ': 'Tri-State Airlines Inc.',
#  'FH': 'Frontier Horizon Inc.',
#  'AWQ': 'Aermediterranea S.P.A.',
#  'BF (1)': 'Markair Inc.',
#  'VK': 'Air Tungaru Corporation',
#  'RES': 'Resort Airlines Inc.',
#  'AAV': 'Alpine Air',
#  'AME': 'Americair Inc.',
#  'ARP': 'Airspur Helicopters Inc.',
#  'SKS': 'Silver Kris Services Ltd.',
#  'BFQ': 'Buffalo Airways Inc.',
#  'AQ': 'Aloha Airlines Inc.',
#  'APS': 'Air Spirit Inc.',
#  'EME': 'Metro Express',
#  'FRT': 'Frontier Commuter',
#  'VS': 'Virgin Atlantic Airways',
#  'MKQ': 'Airmark Corporation',
#  'INQ': 'Independent Air Inc.',
#  'TPQ': 'Aerial Transit Company',
#  'WFT': 'Westflight Aviation',
#  'QX': 'Horizon Air',
#  '2M': 'Midway Express Airlines',
#  'SDQ': 'St. Lucia Airways Limited',
#  'HA': 'Hawaiian Airlines Inc.',
#  'XDA': 'Pacific Air Express Inc.',
#  'RIA': 'Trump Air',
#  'NPA': 'North Pacific Airlines Inc.',
#  'FLR': 'Flirite Inc.',
#  'TAT': 'Talarik Creek Air Taxi',
#  'RAY': 'Royale Airlines Inc.',
#  'WWQ': 'Worldways Canada Ltd.',
#  'AQQ': 'Air Charter (Safa)',
#  'MB': 'Samoa Airlines Inc.',
#  'APH': 'Alpha Air',
#  'JTA': 'Jetaire Airlines Inc.',
#  'KB': 'Haiti Air',
#  'HSV': 'Harbor Air Service',
#  'CO': 'Continental Air Lines Inc.',
#  'IRQ': 'Interstate Airlines Inc.',
#  'CLD': 'Hawaii Pacific Helicopters',
#  'EA': 'Eastern Air Lines Inc.',
#  'CSM': 'Chisum Flying Service',
#  'AMR': 'AvAir',
#  'AAP': 'Armstrong Air Service Inc.',
#  'EGA': 'Eagle Airline',
#  'BEA': 'Business Express Airlines',
#  'ACN': 'Alliance Airlines',
#  'ASR': 'Astor Air',
#  'BAT': 'West Penn Commuter',
#  'BRK': 'Barken International',
#  'CMR': 'Commuter Airlines (Ca)',
#  'CRH': 'Cresent Medivac',
#  'CTL': 'Coastal Air Transport',
#  'EEX': 'Exec Express',
#  'LAA': 'La Skycab Airline',
#  'NAT': 'National Air',
#  'OMI': 'Omniflight Airways',
#  'SEP': 'Southern Express Airways',
#  'TUR': 'Turner Aire',
#  'WSK': 'AAR Western Skyways',
#  'FW': 'Skybus Inc.',
#  'CUQ': 'Caicos Caribbean Airways',
#  'BDE': 'Jet Express',
#  '4R': 'Regent Air Corporation',
#  'WTA': 'Westates Airlines',
#  'AON': 'Action Airlines',
#  'CAF': 'California Seaboard',
#  'ENT': 'Enterprise Airlines Inc.',
#  'IEX': 'Island Air Express',
#  'MAA': 'Maui Airlines',
#  'MEX': 'Metro Express 11',
#  'OTT': 'Otter Air',
#  'PRM': 'Prime Air Inc.',
#  'SAL': "Sallee's Aviation",
#  'WGL': 'Wrangell Air Service',
#  'ZY': 'Atlantic Gulf Airlines',
#  'PKQ': 'Skyworld Airlines Inc.',
#  'XV': 'Presidential Airways Inc.',
#  'DC': 'Caribbean Air Cargo Co Ltd.',
#  'GA': 'P.T. Garuda Indonesian Arwy',
#  'MS': 'Egyptair',
#  'BYA': 'Bay Air',
#  'FFQ': 'Five Star Airlines',
#  'KFS': 'King Flying Service',
#  'LEQ': 'Le Point Air',
#  'BRW': 'Barrow Air',
#  'BIA': 'Big Island Air',
#  'CCA': 'Cityhop',
#  'GPA': 'GP Express Airlines',
#  'IOW': 'Iowa Airways',
#  'MWA': 'Mountain West Airlines',
#  'RSC': 'Resort Commuter',
#  'TXA': 'Texas National Airlines',
#  'AHC': 'Air Hawaii',
#  'XK': 'Aerotal',
#  'ALS': 'Air L.A.',
#  'AEO': 'Aero Coach',
#  'ALK': 'Air Link Airways',
#  'BFG': 'Million Air',
#  'HEL': 'Helitrans',
#  'LAH': 'La Helicopter',
#  'OMH': 'Omniflight Helicopters',
#  'RVA': 'Reeves Air',
#  'CM': 'Compania Panamena (Copa)',
#  'ZAQ': 'Zas Airline Of Egypt',
#  'POL': 'Polar International',
#  'XDC': 'Hemisphere Air Charter',
#  'AIT': 'Airways International',
#  'CGA': 'Chicago Airlines',
#  'YM': 'Royal West Airlines',
#  'XYZ': 'Airpac Inc.',
#  'VE': 'Aerovias Venezolanas-Avensa',
#  'CX': 'Cathay Pacific Airways Ltd.',
#  'GAL': 'Galena Air Service',
#  'STW': 'Stateswest Airlines',
#  'EXR': 'Executive Transport',
#  'PRP': 'Propheter Aviation',
#  'WAI': 'Wise Airlines Inc.',
#  'HNS': 'Haines Airways',
#  'FDQ': 'Great American Airways',
#  'FD': 'Air Puerto Rico Airlines',
#  'VP': 'Viacao Aerea Sao Paulo',
#  'DL': 'Delta Air Lines Inc.',
#  'NH': 'All Nippon Airways Co.',
#  'XDD': 'International Parcel Express Inc.',
#  'AZQ': 'Anglo Airlines Ltd.',
#  'MDC': 'Midcontinent Airlines',
#  'MH': 'Malaysian Airline System',
#  'PMT': 'Pilgrim Aviation & Airlines',
#  'ZO': 'Florida Express Inc.',
#  'OPQ': 'Orion Air',
#  'NAQ': 'Nationair',
#  'APE': 'Air Cape',
#  'LCT': 'Lake Coastal',
#  'MTV': 'Mst Aviation',
#  '7F': 'First Air',
#  'VR': 'Transportes Aereos De Cabo',
#  'AA': 'American Airlines Inc.',
#  'WAQ': 'Air Charter Systems (Acs)',
#  'HET': 'Helitac Aviation',
#  'BM': 'Belize Air International Ltd.',
#  'VY': 'Highland Express Airways',
#  'MPA': 'Mid Pacific Airlines Inc.',
#  'ATQ (1)': 'Aero Tranportes Panamenos',
#  'LBQ': 'Millon Air Inc.',
#  'ARB': 'Air Caribe International',
#  'ASU': 'Air South (1)',
#  'ASH': 'Air South',
#  'BAN': 'Bangor International Air',
#  'CCO': 'Chester County Aviation',
#  'ECR': 'East Coast Airways',
#  'HEP': 'Hub Express',
#  'THA': 'Tropical Helicopter Airways',
#  'TK': 'Turk Hava Yollari A.O.',
#  'PI': 'Piedmont Aviation Inc.',
#  'XDE': 'Air Train Inc.',
#  'HFQ': 'Haiti Air Freight Intl',
#  'KET': 'Ketchikan Air Service',
#  'XDF': 'Salair Inc.',
#  'NAP': 'Npa Inc.',
#  'GM': 'Air America',
#  'KI': 'Time Air Ltd.',
#  'KZ': 'Nippon Cargo Airlines',
#  'SEG': 'Seagull Air Service',
#  'NAS': 'Nasville Eagle',
#  'ALU': 'Aleutian Air',
#  'CUS': 'Custom Air Service',
#  'GSC': 'GCS Air Service',
#  'GST': 'Golden State Airlines',
#  'SPG': 'Springdale Air',
#  'SPR': 'Sportsman Flying Service',
#  'EH': 'Saeta Airlines',
#  'MUQ': 'Aerolineas Mundo',
#  'GG (1)': 'Tropical Airways Inc.',
#  'GG (2)': 'Grenada Airways Ltd.',
#  'MPC': 'Mid Pacific Air Corp.',
#  'EET': 'Exec Express II',
#  'TAQ': 'Taquan Air Service',
#  'CTR': 'Chartair',
#  'LAR': 'Laredo Air',
#  'QWE': 'Qwest Commuter',
#  'TAF': 'Tri Air Freight',
#  'WRA': 'Wra Inc.',
#  'Q2': 'Zambia Airways Corp.',
#  'SR': 'Swissair Transport Co. Ltd.',
#  'ARD': 'Airlift International',
#  'PCR': 'Pacair',
#  'BCQ': 'Bradley Air Services Ltd.',
#  'CYQ': 'Corse Air International',
#  'IA': 'Iraqi Airways',
#  'ZB': 'Monarch Airlines',
#  'VAQ': 'Vacationair',
#  'LUQ': 'Lineas Aereas La-Tur Sa',
#  'HOQ': 'Holidair Airways',
#  'AOQ (1)': 'Aerovias S.A.',
#  'APQ': 'Alas De Transporte International',
#  'TV (1)': 'Transamerica Airlines Inc.',
#  'TV': 'Haiti Trans Air',
#  'CWQ': 'Canadian Aviation Express',
#  'JD (1)': 'Japan Air System Co. Ltd.',
#  'MEA': 'Manhattan Express',
#  'BY': 'Britannia Airways Ltd.',
#  'AEF': 'Aero Freight',
#  'PNM': 'Panama Aviation',
#  'WLH': 'Welch Aviation',
#  'OS': 'Austrian Airlines',
#  '8C': 'Air Transport International',
#  'JR': 'Aero California',
#  'HRG': 'Heritage Airlines',
#  'XDH': 'Kitty Hawk Air Cargo',
#  'EXA': 'Columbia Pacific Airlines (1)',
#  'CLB': 'Columbia Pacific Airlines',
#  'CSL': 'Central States Air Lines',
#  'MHK': 'Mohawk Airlines',
#  'SYM': 'Skymaster',
#  'NVQ': 'Novair International Airways Ltd.',
#  'TSQ': 'TPI International Airways',
#  'UTQ': 'Universal Airlines Inc.',
#  'IPQ': 'Aruba Cargo',
#  'LCQ': 'Latcr',
#  'TDQ (1)': 'Transcarga',
#  'TDQ': 'Venexcargo',
#  'EJQ': 'Aeroejecutivos C.A.',
#  'PUQ': 'Aeropuma',
#  'ACQ': 'Aeronautica De Cancun',
#  'ARQ (1)': 'Aerovias Colombianas Arca',
#  'ZUQ': 'Zuliana De Aviacion',
#  'ITQ': 'Interamericana De Aviacion',
#  'UD': 'Fast Air Carrier Ltd.',
#  'MYQ': 'Lineas Aereas Mayas (Lamsa)',
#  'TNQ': 'Emery Worldwide Airlines',
#  'KA': 'Hong Kong Dragonair',
#  'CW': 'Air Marshall Islands Inc.',
#  'BUQ (1)': 'Blue Bell Inc.',
#  'BUQ': 'Wrangler Aviation Inc.',
#  'CQI': 'Conquest Airline Corp.',
#  'ATH': 'Air Southeast',
#  'CLF': 'California Air Shuttle',
#  'NCE': 'Northcoast Executive',
#  'SCN': 'Scott Aviation',
#  'TXE': 'Trans Air (Hawaii)',
#  'BEQ': 'Air Belgium',
#  'LNQ': 'Aerolineas Latinas',
#  'FQ': 'Air Aruba',
#  'KX': 'Cayman Airways Limited',
#  '4H': 'Belize Trans Air',
#  'LRQ': 'Air Liberte',
#  'SAH': 'Sea Air Shuttle',
#  'PU': 'Primeras Lineas Uruguays For International',
#  '5X': 'United Parcel Service',
#  'GAT': 'Gulf Air Taxi',
#  'ADR': 'Adirondack Airlines',
#  'CRP': 'Corporate Air',
#  'DIA': 'Drummond Island Air',
#  'GFC': 'Gulf Flite Center',
#  'LAP': 'Lapsa',
#  'LEX': "L'Express",
#  'TVL': 'Travelair',
#  'VAS': 'Valley Air Services',
#  'ASQ': 'Aerosur (1)',
#  'GW (1)': 'Central American Airlines',
#  'CHT': 'Charter One',
#  'AS': 'Alaska Airlines Inc.',
#  '2R': 'Regal Air',
#  '7P': 'Apa International Air S.A.',
#  'NZ': 'Air New Zealand',
#  'SE (1)': 'Das Air Cargo',
#  'SRA': 'Star Aviation',
#  'TRR': 'Territorial Airlines',
#  'LKN': 'Loken Aviation',
#  'DWN': 'Dawn Air',
#  'FYB': 'Flying Boat',
#  'CVQ': 'Caraven S.A.',
#  'EFQ': 'Trans Europ. Airways France',
#  'GCQ (1)': 'General Air Cargo',
#  'ALD': 'Allied Airlines',
#  'AVG': 'Airvantage',
#  'CGO': 'Chicago Air Taxi',
#  'GWA': 'Great Western Aviation',
#  'PRD': 'Paradise Island Airlines',
#  'RDW': 'Redwing Airways',
#  'NG': 'Lauda Air Luftfahrt Ag',
#  '9R': 'Flagship Express Services',
#  'BE': 'Braniff International Airlines Inc.',
#  'KW': 'Carnival Air Lines Inc.',
#  'QT': 'Transportes Aereos Mercantiles Panamericanos S.A',
#  'JZ': 'Japan Air Charter Co. Ltd.',
#  'ZL': 'Affretair',
#  'VC': 'Servicios Avensa',
#  'MU (1)': 'Mcclain Airlines Inc.',
#  'MU': 'China Eastern Airlines',
#  'DUL': 'Dulles Express',
#  'SYB': 'Skybus Express Airlines',
#  'TS': 'Air Transat',
#  'XAH': 'Hawaii Pacific Air',
#  'WL (1)': 'World Air Network',
#  'IPS': 'Island Express',
#  'RMH': 'Rocky Mountain Helicopters',
#  'SNV': 'Sierra Nevada Airways',
#  'TWE': 'Trans World Express',
#  'AZP': 'Arizona Pacific Airways',
#  'XPQ': 'International Cargo Xpress',
#  'NER': 'Northeast Express Regional (1)',
#  'NEX': 'Northeast Express Regional',
#  'HCQ': 'Av Atlantic',
#  'RTQ': 'Aerotour Dominicano Cxa',
#  'ROQ': 'Aero Uruguay (1)',
#  'URQ': 'Aero Uruguay',
#  '4N': 'Air North',
#  'UA': 'United Air Lines Inc.',
#  'AHA': 'Air Alpha',
#  'AIY': 'Alliance Air',
#  'FLA': 'Florida Air',
#  'PAQ': 'Patriot Airlines Inc.',
#  'TB (1)': 'USAir Shuttle',
#  'ZN': 'Key Airlines Inc.',
#  'FB': 'Translift Airways Limited',
#  'KTQ': 'Turks Air Ltd.',
#  'BHQ': 'Turks Air Ltd. (1)',
#  'ADV': 'Advantage Airlines',
#  'AWA': 'Air West Airlines',
#  'KEA': 'Keene Airways',
#  'SOE': 'Sky One Express',
#  'HP (Merged with US Airways 9/05.Stopped reporting 10/07.)': 'America West Airlines Inc.',
#  'ZS': 'Hispaniola Airways',
#  'AKQ': 'Airmark Airlines Inc.',
#  'QQ': 'Reno Air Inc.',
#  'VX (1)': 'Aces Airlines',
#  '6Y': 'Nicaraguense De Aviacion Sa',
#  'SI (1)': 'Jet America Airlines Inc.',
#  'SI': 'Sierra Pacific Airlines',
#  'SOP': 'South Pacific Island Airway',
#  'HK': 'Time Air Sweden Ab',
#  'TGQ': 'Tranps Aereos Guatemaltecos',
#  'KN': 'Morris Air Corporation',
#  'LZ': 'Balkan Bulgarian Airlines',
#  'BR (1)': 'Cal Air International Ltd.',
#  'BR': 'Eva Airways Corporation',
#  'CPQ': 'Capitol Air Express Inc.',
#  '5Y': 'Atlas Air Inc.',
#  'RMV': 'Ram Aviation',
#  'ECL': 'Eclipse Airlines',
#  'CLQ': 'Aero Transcolombiana',
#  'ASN': 'Air Casino',
#  'EXP': 'Express Airlines II',
#  'RDR': 'Rader Aviation',
#  'ECQ': 'Trans American Charter',
#  'EXQ': 'Export Air Del Peru S.A.',
#  'LGQ': 'Lineas Aereas Allegro',
#  'CS': 'Continental Micronesia',
#  'V5': 'J.D.Valenciana De Aviation',
#  '5J (1)': 'Private Jet Expeditions',
#  'V9': 'Eagle Airlines',
#  'ECA': 'Eagle Airlines (1)',
#  'LZQ': 'Leisure International Airways Ltd.',
#  'MA': 'Malev Hungarian Airlines',
#  'SMQ': 'Serv. Aerolineas Mexicanas',
#  'LSQ': 'Lineas Aereas Suramerican',
#  'OMQ': 'Quassar De Mexico',
#  'OB': 'Oasis International Airlines S.A.',
#  'G3 (1)': 'Aerochago S.A.',
#  'GD': 'Transp. Aereos Ejecutivos',
#  'UYQ': 'Aerolineas Uruguayas S.A.',
#  'PE (1)': 'People Express Airlines Inc.',
#  ...}

# %%
flights_iata = flights_reduced

# %%
flights_iata['Airline_Mkt'] = flights_iata['IATA_Code_Marketing_Airline'].map(iata_dict)
flights_iata['Airline_Ops'] = flights_iata['IATA_Code_Operating_Airline'].map(iata_dict)

# %%
flights_iata[['Airline_Mkt']].isna().sum()
# Out:
# Airline_Mkt    0
# dtype: int64

# %%
flights_iata[['Airline_Ops']].isna().sum()
# Out:
# Airline_Ops    0
# dtype: int64

# %% [markdown]
# ## Merge IATA Code data to flight performance data

# %%
# drop IATA codes because we have a dictionary with these details if needed
flights_iata_clean = flights_iata.drop(columns=['IATA_Code_Marketing_Airline', 'IATA_Code_Operating_Airline'])

# %%
flights_iata_clean.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  DOT_ID_Marketing_Airline  \
# 0  2023        3      8           6          7                     20416
# 1  2023        3      8           7          1                     20416
# 2  2023        3      8           9          3                     20416
# 3  2023        3      8          10          4                     20416
# 4  2023        3      8          12          6                     20416
#
#    Flight_Number_Marketing_Airline  DOT_ID_Operating_Airline Tail_Number  \
# 0                             2252                     20416      N978NK
# 1                             2252                     20416      N974NK
# 2                             2252                     20416      N519NK
# 3                             2252                     20416      N532NK
# 4                             2252                     20416      N529NK
#
#    OriginAirportID  OriginCityMarketID Origin OriginState  DestAirportID  \
# 0            12889               32211    LAS          NV          11057
# 1            12889               32211    LAS          NV          11057
# 2            12889               32211    LAS          NV          11057
# 3            12889               32211    LAS          NV          11057
# 4            12889               32211    LAS          NV          11057
#
#    DestCityMarketID Dest DestState  DepDelay  DepDel15  DepartureDelayGroups  \
# 0             31057  CLT        NC       NaN       NaN                   NaN
# 1             31057  CLT        NC      76.0       1.0                   5.0
# 2             31057  CLT        NC     -11.0       0.0                  -1.0
# 3             31057  CLT        NC      -8.0       0.0                  -1.0
# 4             31057  CLT        NC       4.0       0.0                   0.0
#
#    TaxiOut  TaxiIn  ArrDelay  ArrDel15  ArrivalDelayGroups  Cancelled  \
# 0      NaN     NaN       NaN       NaN                 NaN          1
# 1     19.0     9.0      69.0       1.0                 4.0          0
# 2     14.0    10.0     -13.0       0.0                -1.0          0
# 3     12.0     7.0     -30.0       0.0                -2.0          0
# 4     18.0     6.0      -4.0       0.0                -1.0          0
#
#    Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  Distance  \
# 0         0           263.0                NaN      NaN    1916.0
# 1         0           263.0              256.0    228.0    1916.0
# 2         0           258.0              256.0    232.0    1916.0
# 3         0           258.0              236.0    217.0    1916.0
# 4         0           258.0              250.0    226.0    1916.0
#
#    DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0              8           NaN           NaN       NaN            NaN
# 1              8           3.0           0.0       1.0            0.0
# 2              8           NaN           NaN       NaN            NaN
# 3              8           NaN           NaN       NaN            NaN
# 4              8           NaN           NaN       NaN            NaN
#
#    LateAircraftDelay  DivAirportLandings  Code_Share_Flight Origin_City  \
# 0                NaN                 0.0                  0   Las Vegas
# 1               65.0                 0.0                  0   Las Vegas
# 2                NaN                 0.0                  0   Las Vegas
# 3                NaN                 0.0                  0   Las Vegas
# 4                NaN                 0.0                  0   Las Vegas
#
#   Destination_City scheduled_departure_datetime scheduled_arrival_datetime  \
# 0        Charlotte          2023-08-06 23:59:00        2023-08-07 07:22:00
# 1        Charlotte          2023-08-07 23:59:00        2023-08-08 07:22:00
# 2        Charlotte          2023-08-09 23:10:00        2023-08-10 06:28:00
# 3        Charlotte          2023-08-10 23:10:00        2023-08-11 06:28:00
# 4        Charlotte          2023-08-12 23:10:00        2023-08-13 06:28:00
#
#   actual_departure_datetime actual_arrival_datetime  Overnight_Depature  \
# 0                       NaT                     NaT                   0
# 1       2023-08-08 01:15:00     2023-08-08 08:31:00                   0
# 2       2023-08-09 22:59:00     2023-08-10 06:15:00                   0
# 3       2023-08-10 23:02:00     2023-08-11 05:58:00                   0
# 4       2023-08-12 23:14:00     2023-08-13 06:24:00                   0
#
#    Overnight_Arrival       Airline_Mkt       Airline_Ops
# 0                  0  Spirit Air Lines  Spirit Air Lines
# 1                  0  Spirit Air Lines  Spirit Air Lines
# 2                  0  Spirit Air Lines  Spirit Air Lines
# 3                  0  Spirit Air Lines  Spirit Air Lines
# 4                  0  Spirit Air Lines  Spirit Air Lines

# %% [markdown]
# # Import geographical data for airports
#
# https://www.transtats.bts.gov/DL_SelectFields.aspx?gnoyr_VQ=FLL&QO_fu146_anzr=N8vn6v10%20f722146%20gnoyr5

# %%
df_airports = pd.read_csv(DATA_PATH + '/raw/T_MASTER_CORD.csv')

# %%
df_airports.head()
# Out:
#    AIRPORT_SEQ_ID  AIRPORT_ID AIRPORT     DISPLAY_AIRPORT_NAME  \
# 0         1000101       10001     01A     Afognak Lake Airport
# 1         1000301       10003     03A  Bear Creek Mining Strip
# 2         1000401       10004     04A          Lik Mining Camp
# 3         1000501       10005     05A     Little Squaw Airport
# 4         1000601       10006     06A             Kizhuyak Bay
#
#   DISPLAY_AIRPORT_CITY_NAME_FULL  AIRPORT_WAC AIRPORT_COUNTRY_NAME  \
# 0               Afognak Lake, AK            1        United States
# 1           Granite Mountain, AK            1        United States
# 2                        Lik, AK            1        United States
# 3               Little Squaw, AK            1        United States
# 4                   Kizhuyak, AK            1        United States
#
#   AIRPORT_COUNTRY_CODE_ISO AIRPORT_STATE_NAME AIRPORT_STATE_CODE  \
# 0                       US             Alaska                 AK
# 1                       US             Alaska                 AK
# 2                       US             Alaska                 AK
# 3                       US             Alaska                 AK
# 4                       US             Alaska                 AK
#
#    AIRPORT_STATE_FIPS  CITY_MARKET_ID DISPLAY_CITY_MARKET_NAME_FULL  \
# 0                 2.0           30001              Afognak Lake, AK
# 1                 2.0           30003          Granite Mountain, AK
# 2                 2.0           30004                       Lik, AK
# 3                 2.0           30005              Little Squaw, AK
# 4                 2.0           30006                  Kizhuyak, AK
#
#    CITY_MARKET_WAC  LAT_DEGREES LAT_HEMISPHERE  LAT_MINUTES  LAT_SECONDS  \
# 0                1         58.0              N          6.0         34.0
# 1                1         65.0              N         32.0         53.0
# 2                1         68.0              N          5.0          0.0
# 3                1         67.0              N         34.0         12.0
# 4                1         57.0              N         44.0         43.0
#
#     LATITUDE  LON_DEGREES LON_HEMISPHERE  LON_MINUTES  LON_SECONDS  \
# 0  58.109444        152.0              W         54.0         24.0
# 1  65.548056        161.0              W          4.0         18.0
# 2  68.083333        163.0              W         10.0          0.0
# 3  67.570000        148.0              W         11.0          2.0
# 4  57.745278        152.0              W         52.0         58.0
#
#     LONGITUDE     AIRPORT_START_DATE AIRPORT_THRU_DATE  AIRPORT_IS_CLOSED  \
# 0 -152.906667   7/1/2007 12:00:00 AM               NaN                  0
# 1 -161.071667   7/1/2007 12:00:00 AM               NaN                  0
# 2 -163.166667   7/1/2007 12:00:00 AM               NaN                  0
# 3 -148.183889   8/1/2007 12:00:00 AM               NaN                  0
# 4 -152.882778  10/1/2007 12:00:00 AM               NaN                  0
#
#    AIRPORT_IS_LATEST
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1

# %%
df_airports['AIRPORT_COUNTRY_NAME'].value_counts()
# Out:
# AIRPORT_COUNTRY_NAME
# United States     7293
# Canada             935
# Australia          581
# Brazil             458
# France             449
#                   ...
# Carriacou            1
# Wake Island          1
# Kyrgyzstan           1
# Norfolk Island       1
# Macau                1
# Name: count, Length: 256, dtype: int64

# %%
df_airports.shape
# Out:
# (19197, 28)

# %% [markdown]
# We only need US airports for the purpose of this project. I will drop all rows for international airports.

# %%
df_airports = df_airports[df_airports['AIRPORT_COUNTRY_NAME'] == 'United States']

# %%
df_airports.columns
# Out:
# Index(['AIRPORT_SEQ_ID', 'AIRPORT_ID', 'AIRPORT', 'DISPLAY_AIRPORT_NAME',
#        'DISPLAY_AIRPORT_CITY_NAME_FULL', 'AIRPORT_WAC', 'AIRPORT_COUNTRY_NAME',
#        'AIRPORT_COUNTRY_CODE_ISO', 'AIRPORT_STATE_NAME', 'AIRPORT_STATE_CODE',
#        'AIRPORT_STATE_FIPS', 'CITY_MARKET_ID', 'DISPLAY_CITY_MARKET_NAME_FULL',
#        'CITY_MARKET_WAC', 'LAT_DEGREES', 'LAT_HEMISPHERE', 'LAT_MINUTES',
#        'LAT_SECONDS', 'LATITUDE', 'LON_DEGREES', 'LON_HEMISPHERE',
#        'LON_MINUTES', 'LON_SECONDS', 'LONGITUDE', 'AIRPORT_START_DATE',
#        'AIRPORT_THRU_DATE', 'AIRPORT_IS_CLOSED', 'AIRPORT_IS_LATEST'],
#       dtype='object')

# %%
df_airports.drop(columns=[
    'AIRPORT_COUNTRY_NAME', 
    'AIRPORT_COUNTRY_CODE_ISO', 
    'LAT_DEGREES', 
    'LAT_HEMISPHERE', 
    'LAT_MINUTES',
    'LAT_SECONDS', 
    'LON_DEGREES', 
    'LON_HEMISPHERE',
    'LON_MINUTES', 
    'LON_SECONDS'
],
inplace=True)

# %%
df_airports.head()
# Out:
#    AIRPORT_SEQ_ID  AIRPORT_ID AIRPORT     DISPLAY_AIRPORT_NAME  \
# 0         1000101       10001     01A     Afognak Lake Airport
# 1         1000301       10003     03A  Bear Creek Mining Strip
# 2         1000401       10004     04A          Lik Mining Camp
# 3         1000501       10005     05A     Little Squaw Airport
# 4         1000601       10006     06A             Kizhuyak Bay
#
#   DISPLAY_AIRPORT_CITY_NAME_FULL  AIRPORT_WAC AIRPORT_STATE_NAME  \
# 0               Afognak Lake, AK            1             Alaska
# 1           Granite Mountain, AK            1             Alaska
# 2                        Lik, AK            1             Alaska
# 3               Little Squaw, AK            1             Alaska
# 4                   Kizhuyak, AK            1             Alaska
#
#   AIRPORT_STATE_CODE  AIRPORT_STATE_FIPS  CITY_MARKET_ID  \
# 0                 AK                 2.0           30001
# 1                 AK                 2.0           30003
# 2                 AK                 2.0           30004
# 3                 AK                 2.0           30005
# 4                 AK                 2.0           30006
#
#   DISPLAY_CITY_MARKET_NAME_FULL  CITY_MARKET_WAC   LATITUDE   LONGITUDE  \
# 0              Afognak Lake, AK                1  58.109444 -152.906667
# 1          Granite Mountain, AK                1  65.548056 -161.071667
# 2                       Lik, AK                1  68.083333 -163.166667
# 3              Little Squaw, AK                1  67.570000 -148.183889
# 4                  Kizhuyak, AK                1  57.745278 -152.882778
#
#       AIRPORT_START_DATE AIRPORT_THRU_DATE  AIRPORT_IS_CLOSED  \
# 0   7/1/2007 12:00:00 AM               NaN                  0
# 1   7/1/2007 12:00:00 AM               NaN                  0
# 2   7/1/2007 12:00:00 AM               NaN                  0
# 3   8/1/2007 12:00:00 AM               NaN                  0
# 4  10/1/2007 12:00:00 AM               NaN                  0
#
#    AIRPORT_IS_LATEST
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1

# %%
df_airports['AIRPORT'].nunique()
# Out:
# 2964

# %%
len(df_airports['AIRPORT'])
# Out:
# 7293

# %%
df_airports.sort_values('AIRPORT', ascending=False).head(20)
# Out:
#        AIRPORT_SEQ_ID  AIRPORT_ID AIRPORT     DISPLAY_AIRPORT_NAME  \
# 19196         9999901       99999     ZZZ  Unknown Point in Alaska
# 18104         1636101       16361     ZZV     Zanesville Municipal
# 18108         1636105       16361     ZZV     Zanesville Municipal
# 18107         1636104       16361     ZZV     Zanesville Municipal
# 18106         1636103       16361     ZZV     Zanesville Municipal
# 18105         1636102       16361     ZZV     Zanesville Municipal
# 18109         1636106       16361     ZZV     Zanesville Municipal
# 18097         1635802       16358     ZXZ       Waterville Airport
# 18096         1635801       16358     ZXZ       Waterville Airport
# 18095         1635703       16357     ZXY              Blake Field
# 18094         1635702       16357     ZXY              Blake Field
# 18093         1635701       16357     ZXY              Blake Field
# 18092         1635602       16356     ZXX              Vista Field
# 18091         1635601       16356     ZXX              Vista Field
# 18090         1635502       16355     ZXW         Paradise Skypark
# 18089         1635501       16355     ZXW                  Skypark
# 18086         1635401       16354     ZXV       Nappanee Municipal
# 18087         1635402       16354     ZXV       Nappanee Municipal
# 18088         1635403       16354     ZXV       Nappanee Municipal
# 18085         1635301       16353     ZXU            Quonset State
#
#       DISPLAY_AIRPORT_CITY_NAME_FULL  AIRPORT_WAC AIRPORT_STATE_NAME  \
# 19196        Unknown Point in Alaska            1             Alaska
# 18104                 Zanesville, OH           44               Ohio
# 18108                 Zanesville, OH           44               Ohio
# 18107                 Zanesville, OH           44               Ohio
# 18106                 Zanesville, OH           44               Ohio
# 18105                 Zanesville, OH           44               Ohio
# 18109                 Zanesville, OH           44               Ohio
# 18097                 Waterville, WA           93         Washington
# 18096                 Waterville, WA           93         Washington
# 18095                      Delta, CO           82           Colorado
# 18094                      Delta, CO           82           Colorado
# 18093                      Delta, CO           82           Colorado
# 18092                  Kennewick, WA           93         Washington
# 18091                  Kennewick, WA           93         Washington
# 18090                   Paradise, CA           91         California
# 18089                   Paradise, CA           91         California
# 18086                   Nappanee, IN           42            Indiana
# 18087                   Nappanee, IN           42            Indiana
# 18088                   Nappanee, IN           42            Indiana
# 18085            North Kingstown, RI           15       Rhode Island
#
#       AIRPORT_STATE_CODE  AIRPORT_STATE_FIPS  CITY_MARKET_ID  \
# 19196                 AK                 2.0           99999
# 18104                 OH                39.0           36361
# 18108                 OH                39.0           36361
# 18107                 OH                39.0           36361
# 18106                 OH                39.0           36361
# 18105                 OH                39.0           36361
# 18109                 OH                39.0           36361
# 18097                 WA                53.0           36358
# 18096                 WA                53.0           36358
# 18095                 CO                 8.0           36357
# 18094                 CO                 8.0           36357
# 18093                 CO                 8.0           36357
# 18092                 WA                53.0           36356
# 18091                 WA                53.0           36356
# 18090                 CA                 6.0           36355
# 18089                 CA                 6.0           36355
# 18086                 IN                18.0           36354
# 18087                 IN                18.0           36354
# 18088                 IN                18.0           36354
# 18085                 RI                44.0           36353
#
#       DISPLAY_CITY_MARKET_NAME_FULL  CITY_MARKET_WAC   LATITUDE   LONGITUDE  \
# 19196       Unknown Point in Alaska                1        NaN         NaN
# 18104                Zanesville, OH               44  39.942778  -81.892500
# 18108                Zanesville, OH               44  39.944444  -81.891944
# 18107                Zanesville, OH               44  39.944444  -81.892222
# 18106                Zanesville, OH               44  39.944444  -81.891944
# 18105                Zanesville, OH               44  39.944444  -81.892222
# 18109                Zanesville, OH               44  39.944444  -81.892222
# 18097                Waterville, WA               93  47.656111 -120.056389
# 18096                Waterville, WA               93  47.654167 -120.054167
# 18095                     Delta, CO               82  38.785556 -108.061944
# 18094                     Delta, CO               82  38.786389 -108.063611
# 18093                     Delta, CO               82  38.783333 -108.065278
# 18092                 Kennewick, WA               93  46.218611 -119.210000
# 18091                 Kennewick, WA               93  46.218333 -119.209444
# 18090                  Paradise, CA               91  39.710556 -121.616389
# 18089                  Paradise, CA               91  39.709722 -121.615278
# 18086                  Nappanee, IN               42  41.446111  -85.934722
# 18087                  Nappanee, IN               42  41.446111  -85.934722
# 18088                  Nappanee, IN               42  41.446111  -85.936111
# 18085           North Kingstown, RI               15  41.597222  -71.412222
#
#           AIRPORT_START_DATE       AIRPORT_THRU_DATE  AIRPORT_IS_CLOSED  \
# 19196   1/1/1950 12:00:00 AM                     NaN                  0
# 18104   1/1/1950 12:00:00 AM   6/30/2011 12:00:00 AM                  0
# 18108  12/1/2017 12:00:00 AM   9/30/2022 12:00:00 AM                  0
# 18107  11/1/2017 12:00:00 AM  11/30/2017 12:00:00 AM                  0
# 18106  10/1/2017 12:00:00 AM  10/31/2017 12:00:00 AM                  0
# 18105   7/1/2011 12:00:00 AM   9/30/2017 12:00:00 AM                  0
# 18109  10/1/2022 12:00:00 AM                     NaN                  0
# 18097   7/1/2011 12:00:00 AM                     NaN                  0
# 18096   3/1/1990 12:00:00 AM   6/30/2011 12:00:00 AM                  0
# 18095   7/1/2019 12:00:00 AM                     NaN                  0
# 18094   7/1/2011 12:00:00 AM   6/30/2019 12:00:00 AM                  0
# 18093   3/1/1990 12:00:00 AM   6/30/2011 12:00:00 AM                  0
# 18092   7/1/2011 12:00:00 AM                     NaN                  0
# 18091   3/1/1990 12:00:00 AM   6/30/2011 12:00:00 AM                  0
# 18090   7/1/2011 12:00:00 AM                     NaN                  0
# 18089   3/1/1990 12:00:00 AM   6/30/2011 12:00:00 AM                  0
# 18086   3/1/1990 12:00:00 AM  12/31/2005 12:00:00 AM                  0
# 18087   1/1/2006 12:00:00 AM   6/30/2011 12:00:00 AM                  0
# 18088   7/1/2011 12:00:00 AM                     NaN                  0
# 18085   1/1/1950 12:00:00 AM                     NaN                  0
#
#        AIRPORT_IS_LATEST
# 19196                  1
# 18104                  0
# 18108                  0
# 18107                  0
# 18106                  0
# 18105                  0
# 18109                  1
# 18097                  1
# 18096                  0
# 18095                  1
# 18094                  0
# 18093                  0
# 18092                  1
# 18091                  0
# 18090                  1
# 18089                  0
# 18086                  0
# 18087                  0
# 18088                  1
# 18085                  1

# %% [markdown]
# An airport can have several records based on slight changes such as their registered longitude and latitude. I only want to keep active airports and their latest location. All other airport records will not be necesary at this time.

# %%
current_airports = (df_airports['AIRPORT_IS_LATEST'] == 1) & (df_airports['AIRPORT_IS_CLOSED'] == 0)
df_airports[current_airports]['AIRPORT'].nunique()
# Out:
# 2804

# %%
airports_clean = df_airports[current_airports].dropna(subset=['LATITUDE', 'LONGITUDE'])

# %% [markdown]
# ### Adding timezone information for each airport

# %%
from timezonefinder import TimezoneFinder

# %%
def assign_timezones(df, lon_col, lat_col):
    ''''''
    tf = TimezoneFinder()

    df['TIMEZONE'] = df.apply(lambda row: tf.timezone_at(lng=row[lon_col], lat=row[lat_col]), axis=1)
    return df

# %%
airports = assign_timezones(airports_clean, 'LONGITUDE', 'LATITUDE')

# %%
airports.head()
# Out:
#    AIRPORT_SEQ_ID  AIRPORT_ID AIRPORT     DISPLAY_AIRPORT_NAME  \
# 0         1000101       10001     01A     Afognak Lake Airport
# 1         1000301       10003     03A  Bear Creek Mining Strip
# 2         1000401       10004     04A          Lik Mining Camp
# 3         1000501       10005     05A     Little Squaw Airport
# 4         1000601       10006     06A             Kizhuyak Bay
#
#   DISPLAY_AIRPORT_CITY_NAME_FULL  AIRPORT_WAC AIRPORT_STATE_NAME  \
# 0               Afognak Lake, AK            1             Alaska
# 1           Granite Mountain, AK            1             Alaska
# 2                        Lik, AK            1             Alaska
# 3               Little Squaw, AK            1             Alaska
# 4                   Kizhuyak, AK            1             Alaska
#
#   AIRPORT_STATE_CODE  AIRPORT_STATE_FIPS  CITY_MARKET_ID  \
# 0                 AK                 2.0           30001
# 1                 AK                 2.0           30003
# 2                 AK                 2.0           30004
# 3                 AK                 2.0           30005
# 4                 AK                 2.0           30006
#
#   DISPLAY_CITY_MARKET_NAME_FULL  CITY_MARKET_WAC   LATITUDE   LONGITUDE  \
# 0              Afognak Lake, AK                1  58.109444 -152.906667
# 1          Granite Mountain, AK                1  65.548056 -161.071667
# 2                       Lik, AK                1  68.083333 -163.166667
# 3              Little Squaw, AK                1  67.570000 -148.183889
# 4                  Kizhuyak, AK                1  57.745278 -152.882778
#
#       AIRPORT_START_DATE AIRPORT_THRU_DATE  AIRPORT_IS_CLOSED  \
# 0   7/1/2007 12:00:00 AM               NaN                  0
# 1   7/1/2007 12:00:00 AM               NaN                  0
# 2   7/1/2007 12:00:00 AM               NaN                  0
# 3   8/1/2007 12:00:00 AM               NaN                  0
# 4  10/1/2007 12:00:00 AM               NaN                  0
#
#    AIRPORT_IS_LATEST           TIMEZONE
# 0                  1  America/Anchorage
# 1                  1  America/Anchorage
# 2                  1       America/Nome
# 3                  1  America/Anchorage
# 4                  1  America/Anchorage

# %%
airports['TIMEZONE'].value_counts()
# Out:
# TIMEZONE
# America/New_York                  703
# America/Chicago                   675
# America/Anchorage                 412
# America/Los_Angeles               345
# America/Denver                    203
# America/Nome                      100
# America/Sitka                      86
# America/Phoenix                    59
# America/Detroit                    53
# America/Juneau                     38
# America/Indiana/Indianapolis       29
# America/Boise                      28
# Pacific/Honolulu                   21
# America/Puerto_Rico                14
# America/Adak                        5
# America/St_Thomas                   5
# Pacific/Pago_Pago                   4
# Pacific/Guam                        3
# America/Menominee                   3
# America/Kentucky/Louisville         3
# Pacific/Saipan                      3
# America/Metlakatla                  2
# America/Yakutat                     2
# America/Indiana/Vincennes           2
# Pacific/Wake                        1
# Etc/GMT+10                          1
# Pacific/Midway                      1
# America/Vancouver                   1
# America/North_Dakota/New_Salem      1
# Name: count, dtype: int64

# %%
airports.to_csv(DATA_PATH + '/interim/airports.csv', index=False)

# %%
airports_sub = airports[['AIRPORT_ID', 'AIRPORT', 'TIMEZONE']]
airports_sub.head()
# Out:
#    AIRPORT_ID AIRPORT           TIMEZONE
# 0       10001     01A  America/Anchorage
# 1       10003     03A  America/Anchorage
# 2       10004     04A       America/Nome
# 3       10005     05A  America/Anchorage
# 4       10006     06A  America/Anchorage

# %% [markdown]
# #### Save updated flights df that has timezone corrections and UTC conversion

# %%
flights_iata_clean.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  DOT_ID_Marketing_Airline  \
# 0  2023        3      8           6          7                     20416
# 1  2023        3      8           7          1                     20416
# 2  2023        3      8           9          3                     20416
# 3  2023        3      8          10          4                     20416
# 4  2023        3      8          12          6                     20416
#
#    Flight_Number_Marketing_Airline  DOT_ID_Operating_Airline Tail_Number  \
# 0                             2252                     20416      N978NK
# 1                             2252                     20416      N974NK
# 2                             2252                     20416      N519NK
# 3                             2252                     20416      N532NK
# 4                             2252                     20416      N529NK
#
#    OriginAirportID  OriginCityMarketID Origin OriginState  DestAirportID  \
# 0            12889               32211    LAS          NV          11057
# 1            12889               32211    LAS          NV          11057
# 2            12889               32211    LAS          NV          11057
# 3            12889               32211    LAS          NV          11057
# 4            12889               32211    LAS          NV          11057
#
#    DestCityMarketID Dest DestState  DepDelay  DepDel15  DepartureDelayGroups  \
# 0             31057  CLT        NC       NaN       NaN                   NaN
# 1             31057  CLT        NC      76.0       1.0                   5.0
# 2             31057  CLT        NC     -11.0       0.0                  -1.0
# 3             31057  CLT        NC      -8.0       0.0                  -1.0
# 4             31057  CLT        NC       4.0       0.0                   0.0
#
#    TaxiOut  TaxiIn  ArrDelay  ArrDel15  ArrivalDelayGroups  Cancelled  \
# 0      NaN     NaN       NaN       NaN                 NaN          1
# 1     19.0     9.0      69.0       1.0                 4.0          0
# 2     14.0    10.0     -13.0       0.0                -1.0          0
# 3     12.0     7.0     -30.0       0.0                -2.0          0
# 4     18.0     6.0      -4.0       0.0                -1.0          0
#
#    Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  Distance  \
# 0         0           263.0                NaN      NaN    1916.0
# 1         0           263.0              256.0    228.0    1916.0
# 2         0           258.0              256.0    232.0    1916.0
# 3         0           258.0              236.0    217.0    1916.0
# 4         0           258.0              250.0    226.0    1916.0
#
#    DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0              8           NaN           NaN       NaN            NaN
# 1              8           3.0           0.0       1.0            0.0
# 2              8           NaN           NaN       NaN            NaN
# 3              8           NaN           NaN       NaN            NaN
# 4              8           NaN           NaN       NaN            NaN
#
#    LateAircraftDelay  DivAirportLandings  Code_Share_Flight Origin_City  \
# 0                NaN                 0.0                  0   Las Vegas
# 1               65.0                 0.0                  0   Las Vegas
# 2                NaN                 0.0                  0   Las Vegas
# 3                NaN                 0.0                  0   Las Vegas
# 4                NaN                 0.0                  0   Las Vegas
#
#   Destination_City scheduled_departure_datetime scheduled_arrival_datetime  \
# 0        Charlotte          2023-08-06 23:59:00        2023-08-07 07:22:00
# 1        Charlotte          2023-08-07 23:59:00        2023-08-08 07:22:00
# 2        Charlotte          2023-08-09 23:10:00        2023-08-10 06:28:00
# 3        Charlotte          2023-08-10 23:10:00        2023-08-11 06:28:00
# 4        Charlotte          2023-08-12 23:10:00        2023-08-13 06:28:00
#
#   actual_departure_datetime actual_arrival_datetime  Overnight_Depature  \
# 0                       NaT                     NaT                   0
# 1       2023-08-08 01:15:00     2023-08-08 08:31:00                   0
# 2       2023-08-09 22:59:00     2023-08-10 06:15:00                   0
# 3       2023-08-10 23:02:00     2023-08-11 05:58:00                   0
# 4       2023-08-12 23:14:00     2023-08-13 06:24:00                   0
#
#    Overnight_Arrival       Airline_Mkt       Airline_Ops
# 0                  0  Spirit Air Lines  Spirit Air Lines
# 1                  0  Spirit Air Lines  Spirit Air Lines
# 2                  0  Spirit Air Lines  Spirit Air Lines
# 3                  0  Spirit Air Lines  Spirit Air Lines
# 4                  0  Spirit Air Lines  Spirit Air Lines

# %%
def add_timezones(flights_df, airports_df):

    origin_merge = pd.merge(flights_df, airports_df, how='left', left_on=['OriginAirportID', 'Origin'], right_on=['AIRPORT_ID', 'AIRPORT'])
    origin_merge.rename(columns={'TIMEZONE':'Origin_Timezone'}, inplace=True)
    origin_merge = origin_merge.drop(columns=['AIRPORT_ID', 'AIRPORT'])
    destination_merge = pd.merge(origin_merge, airports_df, how='left', left_on=['DestAirportID', 'Dest'], right_on=['AIRPORT_ID', 'AIRPORT'])
    destination_merge.rename(columns={'TIMEZONE':'Destination_Timezone'}, inplace=True)
    flights_local_time = destination_merge.drop(columns=['AIRPORT_ID', 'AIRPORT'])

    return flights_local_time

# %%
flights_local_time = add_timezones(flights_iata_clean, airports_sub)

# %%
flights_local_time[(flights_local_time['OriginState'] == 'WA') & (flights_local_time['DestState'] == 'MN')].head()
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  DOT_ID_Marketing_Airline  \
# 171429  2023        3      8           1          2                     19790
# 171430  2023        3      8           2          3                     19790
# 171431  2023        3      8           3          4                     19790
# 171432  2023        3      8           4          5                     19790
# 171433  2023        3      8           5          6                     19790
#
#         Flight_Number_Marketing_Airline  DOT_ID_Operating_Airline Tail_Number  \
# 171429                              360                     19790      N921DU
# 171430                              360                     19790      N853DN
# 171431                              360                     19790      N806DN
# 171432                              360                     19790      N848DN
# 171433                              360                     19790      N868DN
#
#         OriginAirportID  OriginCityMarketID Origin OriginState  DestAirportID  \
# 171429            14747               30559    SEA          WA          13487
# 171430            14747               30559    SEA          WA          13487
# 171431            14747               30559    SEA          WA          13487
# 171432            14747               30559    SEA          WA          13487
# 171433            14747               30559    SEA          WA          13487
#
#         DestCityMarketID Dest DestState  DepDelay  DepDel15  \
# 171429             31650  MSP        MN      -1.0       0.0
# 171430             31650  MSP        MN      -8.0       0.0
# 171431             31650  MSP        MN     825.0       1.0
# 171432             31650  MSP        MN      -3.0       0.0
# 171433             31650  MSP        MN      -4.0       0.0
#
#         DepartureDelayGroups  TaxiOut  TaxiIn  ArrDelay  ArrDel15  \
# 171429                  -1.0     36.0     6.0     -14.0       0.0
# 171430                  -1.0     18.0    16.0     -27.0       0.0
# 171431                  12.0     30.0    12.0     822.0       1.0
# 171432                  -1.0     28.0     8.0     -10.0       0.0
# 171433                  -1.0     19.0     4.0     -15.0       0.0
#
#         ArrivalDelayGroups  Cancelled  Diverted  CRSElapsedTime  \
# 171429                -1.0          0         0           212.0
# 171430                -2.0          0         0           212.0
# 171431                12.0          0         0           212.0
# 171432                -1.0          0         0           212.0
# 171433                -1.0          0         0           212.0
#
#         ActualElapsedTime  AirTime  Distance  DistanceGroup  CarrierDelay  \
# 171429              199.0    157.0    1399.0              6           NaN
# 171430              193.0    159.0    1399.0              6           NaN
# 171431              209.0    167.0    1399.0              6         822.0
# 171432              205.0    169.0    1399.0              6           NaN
# 171433              201.0    178.0    1399.0              6           NaN
#
#         WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay  \
# 171429           NaN       NaN            NaN                NaN
# 171430           NaN       NaN            NaN                NaN
# 171431           0.0       0.0            0.0                0.0
# 171432           NaN       NaN            NaN                NaN
# 171433           NaN       NaN            NaN                NaN
#
#         DivAirportLandings  Code_Share_Flight Origin_City Destination_City  \
# 171429                 0.0                  0     Seattle      Minneapolis
# 171430                 0.0                  0     Seattle      Minneapolis
# 171431                 0.0                  0     Seattle      Minneapolis
# 171432                 0.0                  0     Seattle      Minneapolis
# 171433                 0.0                  0     Seattle      Minneapolis
#
#        scheduled_departure_datetime scheduled_arrival_datetime  \
# 171429          2023-08-01 08:11:00        2023-08-01 13:43:00
# 171430          2023-08-02 08:11:00        2023-08-02 13:43:00
# 171431          2023-08-03 08:11:00        2023-08-03 13:43:00
# 171432          2023-08-04 08:11:00        2023-08-04 13:43:00
# 171433          2023-08-05 08:11:00        2023-08-05 13:43:00
#
#        actual_departure_datetime actual_arrival_datetime  Overnight_Depature  \
# 171429       2023-08-01 08:10:00     2023-08-01 13:29:00                   0
# 171430       2023-08-02 08:03:00     2023-08-02 13:16:00                   0
# 171431       2023-08-03 21:56:00     2023-08-04 03:25:00                   0
# 171432       2023-08-04 08:08:00     2023-08-04 13:33:00                   0
# 171433       2023-08-05 08:07:00     2023-08-05 13:28:00                   0
#
#         Overnight_Arrival           Airline_Mkt           Airline_Ops  \
# 171429                  0  Delta Air Lines Inc.  Delta Air Lines Inc.
# 171430                  0  Delta Air Lines Inc.  Delta Air Lines Inc.
# 171431                  0  Delta Air Lines Inc.  Delta Air Lines Inc.
# 171432                  0  Delta Air Lines Inc.  Delta Air Lines Inc.
# 171433                  0  Delta Air Lines Inc.  Delta Air Lines Inc.
#
#             Origin_Timezone Destination_Timezone
# 171429  America/Los_Angeles      America/Chicago
# 171430  America/Los_Angeles      America/Chicago
# 171431  America/Los_Angeles      America/Chicago
# 171432  America/Los_Angeles      America/Chicago
# 171433  America/Los_Angeles      America/Chicago

# %%
flights_local_time[['scheduled_departure_datetime', 'scheduled_arrival_datetime', 'actual_departure_datetime', 'actual_arrival_datetime']].dtypes
# Out:
# scheduled_departure_datetime    datetime64[ns]
# scheduled_arrival_datetime      datetime64[ns]
# actual_departure_datetime       datetime64[ns]
# actual_arrival_datetime         datetime64[ns]
# dtype: object

# %%
def convert_flight_times_to_utc(df):
    """
    Converts flight scheduled and actual departure/arrival times to UTC and rounds 
    the scheduled times to the nearest hour for weather data joining.

    The function handles timezone conversions for both departure and arrival times 
    based on the airport timezones (Origin_Timezone and Destination_Timezone). It 
    also addresses ambiguous and nonexistent times during daylight savings transitions.

    Parameters:
    -----------
    df : pandas.DataFrame
        DataFrame containing the following columns:
        - 'scheduled_departure_datetime': datetime column for the scheduled departure time.
        - 'actual_departure_datetime': datetime column for the actual departure time.
        - 'scheduled_arrival_datetime': datetime column for the scheduled arrival time.
        - 'actual_arrival_datetime': datetime column for the actual arrival time.
        - 'Origin_Timezone': column containing the timezone of the origin airport.
        - 'Destination_Timezone': column containing the timezone of the destination airport.

    Returns:
    --------
    df : pandas.DataFrame
        The original DataFrame with the following additional columns:
        - 'scheduled_departure_datetime_utc': converted and rounded scheduled departure time in UTC.
        - 'actual_departure_datetime_utc': converted actual departure time in UTC.
        - 'scheduled_arrival_datetime_utc': converted and rounded scheduled arrival time in UTC.
        - 'actual_arrival_datetime_utc': converted actual arrival time in UTC.

    Notes:
    ------
    - The 'ambiguous' parameter is set to True, which assumes the earlier time for ambiguous DST transitions.
    - The 'nonexistent' parameter is set to 'shift_forward' to handle nonexistent times during the DST jump forward.
    - The scheduled times are rounded to the nearest hour after conversion to UTC for easier alignment with external data (e.g., weather data).
    """
    
    # Localize scheduled depature based on Origin_Timezone
    df['scheduled_departure_datetime'] = df['scheduled_departure_datetime'].dt.tz_localize(None)
    # Convert scheduled departure to UTC
    df['scheduled_departure_datetime_utc'] = df.groupby('Origin_Timezone')['scheduled_departure_datetime'].transform(
        lambda x: x.dt.tz_localize(x.name, ambiguous=True, nonexistent='shift_forward').dt.tz_convert('UTC')
    )
    # Round scheduled departure time to nearest hour for joining with weather data
    df['scheduled_departure_datetime_utc'] = df['scheduled_departure_datetime_utc'].round('h')
    
    # Localize actual depature based on Origin_Timezone
    df['actual_departure_datetime'] = df['actual_departure_datetime'].dt.tz_localize(None)
    # Convert actual departure to UTC
    df['actual_departure_datetime_utc'] = df.groupby('Origin_Timezone')['actual_departure_datetime'].transform(
        lambda x: x.dt.tz_localize(x.name, ambiguous=True, nonexistent='shift_forward').dt.tz_convert('UTC')
    )

    # Localize scheduled arrival based on Destination_Timezone
    df['scheduled_arrival_datetime'] = df['scheduled_arrival_datetime'].dt.tz_localize(None)
    # Convert scheduled arrival to UTC
    df['scheduled_arrival_datetime_utc'] = df.groupby('Destination_Timezone')['scheduled_arrival_datetime'].transform(
        lambda x: x.dt.tz_localize(x.name, ambiguous=True, nonexistent='shift_forward').dt.tz_convert('UTC')
    )
    # Round scheduled arrival time to nearest hour for joining with weather data
    df['scheduled_arrival_datetime_utc'] = df['scheduled_arrival_datetime_utc'].round('h')
    
    # Localize actual arrival based on Destination_Timezone
    df['actual_arrival_datetime'] = df['actual_arrival_datetime'].dt.tz_localize(None)
    # Convert actual arrival to UTC
    df['actual_arrival_datetime_utc'] = df.groupby('Destination_Timezone')['actual_arrival_datetime'].transform(
        lambda x: x.dt.tz_localize(x.name, ambiguous=True, nonexistent='shift_forward').dt.tz_convert('UTC')
    )
    
    return df

# %%
flights_utc = convert_flight_times_to_utc(flights_local_time)

# %%
flights_utc.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  DOT_ID_Marketing_Airline  \
# 0  2023        3      8           6          7                     20416
# 1  2023        3      8           7          1                     20416
# 2  2023        3      8           9          3                     20416
# 3  2023        3      8          10          4                     20416
# 4  2023        3      8          12          6                     20416
#
#    Flight_Number_Marketing_Airline  DOT_ID_Operating_Airline Tail_Number  \
# 0                             2252                     20416      N978NK
# 1                             2252                     20416      N974NK
# 2                             2252                     20416      N519NK
# 3                             2252                     20416      N532NK
# 4                             2252                     20416      N529NK
#
#    OriginAirportID  OriginCityMarketID Origin OriginState  DestAirportID  \
# 0            12889               32211    LAS          NV          11057
# 1            12889               32211    LAS          NV          11057
# 2            12889               32211    LAS          NV          11057
# 3            12889               32211    LAS          NV          11057
# 4            12889               32211    LAS          NV          11057
#
#    DestCityMarketID Dest DestState  DepDelay  DepDel15  DepartureDelayGroups  \
# 0             31057  CLT        NC       NaN       NaN                   NaN
# 1             31057  CLT        NC      76.0       1.0                   5.0
# 2             31057  CLT        NC     -11.0       0.0                  -1.0
# 3             31057  CLT        NC      -8.0       0.0                  -1.0
# 4             31057  CLT        NC       4.0       0.0                   0.0
#
#    TaxiOut  TaxiIn  ArrDelay  ArrDel15  ArrivalDelayGroups  Cancelled  \
# 0      NaN     NaN       NaN       NaN                 NaN          1
# 1     19.0     9.0      69.0       1.0                 4.0          0
# 2     14.0    10.0     -13.0       0.0                -1.0          0
# 3     12.0     7.0     -30.0       0.0                -2.0          0
# 4     18.0     6.0      -4.0       0.0                -1.0          0
#
#    Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  Distance  \
# 0         0           263.0                NaN      NaN    1916.0
# 1         0           263.0              256.0    228.0    1916.0
# 2         0           258.0              256.0    232.0    1916.0
# 3         0           258.0              236.0    217.0    1916.0
# 4         0           258.0              250.0    226.0    1916.0
#
#    DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0              8           NaN           NaN       NaN            NaN
# 1              8           3.0           0.0       1.0            0.0
# 2              8           NaN           NaN       NaN            NaN
# 3              8           NaN           NaN       NaN            NaN
# 4              8           NaN           NaN       NaN            NaN
#
#    LateAircraftDelay  DivAirportLandings  Code_Share_Flight Origin_City  \
# 0                NaN                 0.0                  0   Las Vegas
# 1               65.0                 0.0                  0   Las Vegas
# 2                NaN                 0.0                  0   Las Vegas
# 3                NaN                 0.0                  0   Las Vegas
# 4                NaN                 0.0                  0   Las Vegas
#
#   Destination_City scheduled_departure_datetime scheduled_arrival_datetime  \
# 0        Charlotte          2023-08-06 23:59:00        2023-08-07 07:22:00
# 1        Charlotte          2023-08-07 23:59:00        2023-08-08 07:22:00
# 2        Charlotte          2023-08-09 23:10:00        2023-08-10 06:28:00
# 3        Charlotte          2023-08-10 23:10:00        2023-08-11 06:28:00
# 4        Charlotte          2023-08-12 23:10:00        2023-08-13 06:28:00
#
#   actual_departure_datetime actual_arrival_datetime  Overnight_Depature  \
# 0                       NaT                     NaT                   0
# 1       2023-08-08 01:15:00     2023-08-08 08:31:00                   0
# 2       2023-08-09 22:59:00     2023-08-10 06:15:00                   0
# 3       2023-08-10 23:02:00     2023-08-11 05:58:00                   0
# 4       2023-08-12 23:14:00     2023-08-13 06:24:00                   0
#
#    Overnight_Arrival       Airline_Mkt       Airline_Ops      Origin_Timezone  \
# 0                  0  Spirit Air Lines  Spirit Air Lines  America/Los_Angeles
# 1                  0  Spirit Air Lines  Spirit Air Lines  America/Los_Angeles
# 2                  0  Spirit Air Lines  Spirit Air Lines  America/Los_Angeles
# 3                  0  Spirit Air Lines  Spirit Air Lines  America/Los_Angeles
# 4                  0  Spirit Air Lines  Spirit Air Lines  America/Los_Angeles
#
#   Destination_Timezone scheduled_departure_datetime_utc  \
# 0     America/New_York        2023-08-07 07:00:00+00:00
# 1     America/New_York        2023-08-08 07:00:00+00:00
# 2     America/New_York        2023-08-10 06:00:00+00:00
# 3     America/New_York        2023-08-11 06:00:00+00:00
# 4     America/New_York        2023-08-13 06:00:00+00:00
#
#   actual_departure_datetime_utc scheduled_arrival_datetime_utc  \
# 0                           NaT      2023-08-07 11:00:00+00:00
# 1     2023-08-08 08:15:00+00:00      2023-08-08 11:00:00+00:00
# 2     2023-08-10 05:59:00+00:00      2023-08-10 10:00:00+00:00
# 3     2023-08-11 06:02:00+00:00      2023-08-11 10:00:00+00:00
# 4     2023-08-13 06:14:00+00:00      2023-08-13 10:00:00+00:00
#
#   actual_arrival_datetime_utc
# 0                         NaT
# 1   2023-08-08 12:31:00+00:00
# 2   2023-08-10 10:15:00+00:00
# 3   2023-08-11 09:58:00+00:00
# 4   2023-08-13 10:24:00+00:00

# %%
def add_holidays(df, date_col):
    """
    Adds a new column 'is_holiday' to the DataFrame, indicating whether the given date
    in the specified column is a US holiday.

    This function iterates over the specified date column and checks if each date is
    a recognized holiday in the United States, as defined by the `holidays.US()` library.
    If the date is a holiday, the corresponding value in the new 'is_holiday' column
    will be 1, otherwise it will be 0.

    Parameters:
    -----------
    df : pandas.DataFrame
        The DataFrame containing a date column.
    date_col : str
        The column name in the DataFrame that contains the dates to check.

    Returns:
    --------
    df : pandas.DataFrame
        The original DataFrame with an additional 'is_holiday' column, where
        1 indicates a holiday and 0 indicates a non-holiday.

    """
    
    us_holidays = holidays.US()

    df['is_holiday'] = [1 if date in us_holidays else 0 for date in df[date_col]]

    return df

# %%
flights_transformed = add_holidays(flights_utc, 'scheduled_departure_datetime')
flights_transformed['is_holiday'].value_counts()
# Out:
# is_holiday
# 0    7015530
# 1     245411
# Name: count, dtype: int64

# %%
flights_transformed.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  DOT_ID_Marketing_Airline  \
# 0  2023        3      8           6          7                     20416
# 1  2023        3      8           7          1                     20416
# 2  2023        3      8           9          3                     20416
# 3  2023        3      8          10          4                     20416
# 4  2023        3      8          12          6                     20416
#
#    Flight_Number_Marketing_Airline  DOT_ID_Operating_Airline Tail_Number  \
# 0                             2252                     20416      N978NK
# 1                             2252                     20416      N974NK
# 2                             2252                     20416      N519NK
# 3                             2252                     20416      N532NK
# 4                             2252                     20416      N529NK
#
#    OriginAirportID  OriginCityMarketID Origin OriginState  DestAirportID  \
# 0            12889               32211    LAS          NV          11057
# 1            12889               32211    LAS          NV          11057
# 2            12889               32211    LAS          NV          11057
# 3            12889               32211    LAS          NV          11057
# 4            12889               32211    LAS          NV          11057
#
#    DestCityMarketID Dest DestState  DepDelay  DepDel15  DepartureDelayGroups  \
# 0             31057  CLT        NC       NaN       NaN                   NaN
# 1             31057  CLT        NC      76.0       1.0                   5.0
# 2             31057  CLT        NC     -11.0       0.0                  -1.0
# 3             31057  CLT        NC      -8.0       0.0                  -1.0
# 4             31057  CLT        NC       4.0       0.0                   0.0
#
#    TaxiOut  TaxiIn  ArrDelay  ArrDel15  ArrivalDelayGroups  Cancelled  \
# 0      NaN     NaN       NaN       NaN                 NaN          1
# 1     19.0     9.0      69.0       1.0                 4.0          0
# 2     14.0    10.0     -13.0       0.0                -1.0          0
# 3     12.0     7.0     -30.0       0.0                -2.0          0
# 4     18.0     6.0      -4.0       0.0                -1.0          0
#
#    Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  Distance  \
# 0         0           263.0                NaN      NaN    1916.0
# 1         0           263.0              256.0    228.0    1916.0
# 2         0           258.0              256.0    232.0    1916.0
# 3         0           258.0              236.0    217.0    1916.0
# 4         0           258.0              250.0    226.0    1916.0
#
#    DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0              8           NaN           NaN       NaN            NaN
# 1              8           3.0           0.0       1.0            0.0
# 2              8           NaN           NaN       NaN            NaN
# 3              8           NaN           NaN       NaN            NaN
# 4              8           NaN           NaN       NaN            NaN
#
#    LateAircraftDelay  DivAirportLandings  Code_Share_Flight Origin_City  \
# 0                NaN                 0.0                  0   Las Vegas
# 1               65.0                 0.0                  0   Las Vegas
# 2                NaN                 0.0                  0   Las Vegas
# 3                NaN                 0.0                  0   Las Vegas
# 4                NaN                 0.0                  0   Las Vegas
#
#   Destination_City scheduled_departure_datetime scheduled_arrival_datetime  \
# 0        Charlotte          2023-08-06 23:59:00        2023-08-07 07:22:00
# 1        Charlotte          2023-08-07 23:59:00        2023-08-08 07:22:00
# 2        Charlotte          2023-08-09 23:10:00        2023-08-10 06:28:00
# 3        Charlotte          2023-08-10 23:10:00        2023-08-11 06:28:00
# 4        Charlotte          2023-08-12 23:10:00        2023-08-13 06:28:00
#
#   actual_departure_datetime actual_arrival_datetime  Overnight_Depature  \
# 0                       NaT                     NaT                   0
# 1       2023-08-08 01:15:00     2023-08-08 08:31:00                   0
# 2       2023-08-09 22:59:00     2023-08-10 06:15:00                   0
# 3       2023-08-10 23:02:00     2023-08-11 05:58:00                   0
# 4       2023-08-12 23:14:00     2023-08-13 06:24:00                   0
#
#    Overnight_Arrival       Airline_Mkt       Airline_Ops      Origin_Timezone  \
# 0                  0  Spirit Air Lines  Spirit Air Lines  America/Los_Angeles
# 1                  0  Spirit Air Lines  Spirit Air Lines  America/Los_Angeles
# 2                  0  Spirit Air Lines  Spirit Air Lines  America/Los_Angeles
# 3                  0  Spirit Air Lines  Spirit Air Lines  America/Los_Angeles
# 4                  0  Spirit Air Lines  Spirit Air Lines  America/Los_Angeles
#
#   Destination_Timezone scheduled_departure_datetime_utc  \
# 0     America/New_York        2023-08-07 07:00:00+00:00
# 1     America/New_York        2023-08-08 07:00:00+00:00
# 2     America/New_York        2023-08-10 06:00:00+00:00
# 3     America/New_York        2023-08-11 06:00:00+00:00
# 4     America/New_York        2023-08-13 06:00:00+00:00
#
#   actual_departure_datetime_utc scheduled_arrival_datetime_utc  \
# 0                           NaT      2023-08-07 11:00:00+00:00
# 1     2023-08-08 08:15:00+00:00      2023-08-08 11:00:00+00:00
# 2     2023-08-10 05:59:00+00:00      2023-08-10 10:00:00+00:00
# 3     2023-08-11 06:02:00+00:00      2023-08-11 10:00:00+00:00
# 4     2023-08-13 06:14:00+00:00      2023-08-13 10:00:00+00:00
#
#   actual_arrival_datetime_utc  is_holiday
# 0                         NaT           0
# 1   2023-08-08 12:31:00+00:00           0
# 2   2023-08-10 10:15:00+00:00           0
# 3   2023-08-11 09:58:00+00:00           0
# 4   2023-08-13 10:24:00+00:00           0

# %%
def rename_flights_columns(df):
    """
    Renames specific columns in the DataFrame and applies two renaming patterns to other columns.

    This function first explicitly renames certain columns with predefined names, then applies the following transformations:
    
    1. Columns that are in camelCase or PascalCase (e.g., 'DayOfWeek') are converted to snake_case (e.g., 'day_of_week').
       
    2. Columns that contain underscores but are in mixed case (e.g., 'Overnight_Departure') are converted to lowercase (e.g., 'overnight_departure').
    
    All other columns are left unchanged.

    Parameters:
    -----------
    df : pandas.DataFrame
        The DataFrame containing the columns to be renamed.
    
    Returns:
    --------
    pandas.DataFrame
        The DataFrame with renamed columns.
    """

    df.rename(columns={
        'DayofMonth': 'day_of_month',
        'NASDelay': 'nas_delay',
        'DOT_ID_Marketing_Airline': 'marketing_airline_id',
        'DOT_ID_Operating_Airline': 'operating_airline_id',
        'CRSElapsedTime': 'scheduled_elapsed_time' 
    }, inplace=True)

    def convert_to_snake_case(name):
        # Convert 'DayOfWeek' to 'day_of_week'
        snake_case = re.sub(r'(?<!^)(?=[A-Z])', '_', name).lower()
        snake_case = snake_case.replace('_i_d', '_id')
        return snake_case

    new_columns = []
    
    for col in df.columns:
        # First pattern: Capitalized words followed by another capitalized word without spaces
        if re.match(r'^[A-Z][a-z]+[A-Z]', col):
            new_columns.append(convert_to_snake_case(col))
        # Second pattern: Columns with underscores and mixed case
        elif '_' in col and not col.islower():
            new_columns.append(col.lower())
        else:
            # Leave other columns unchanged
            new_columns.append(col.lower())

    # Rename the columns in the DataFrame
    df.columns = new_columns
    return df

# %%
flights_clean = rename_flights_columns(flights_transformed)

# %%
flights_clean.columns
# Out:
# Index(['year', 'quarter', 'month', 'day_of_month', 'day_of_week',
#        'marketing_airline_id', 'flight_number_marketing_airline',
#        'operating_airline_id', 'tail_number', 'origin_airport_id',
#        'origin_city_market_id', 'origin', 'origin_state', 'dest_airport_id',
#        'dest_city_market_id', 'dest', 'dest_state', 'dep_delay', 'dep_del15',
#        'departure_delay_groups', 'taxi_out', 'taxi_in', 'arr_delay',
#        'arr_del15', 'arrival_delay_groups', 'cancelled', 'diverted',
#        'scheduled_elapsed_time', 'actual_elapsed_time', 'air_time', 'distance',
#        'distance_group', 'carrier_delay', 'weather_delay', 'nas_delay',
#        'security_delay', 'late_aircraft_delay', 'div_airport_landings',
#        'code_share_flight', 'origin_city', 'destination_city',
#        'scheduled_departure_datetime', 'scheduled_arrival_datetime',
#        'actual_departure_datetime', 'actual_arrival_datetime',
#        'overnight_depature', 'overnight_arrival', 'airline_mkt', 'airline_ops',
#        'origin_timezone', 'destination_timezone',
#        'scheduled_departure_datetime_utc', 'actual_departure_datetime_utc',
#        'scheduled_arrival_datetime_utc', 'actual_arrival_datetime_utc',
#        'is_holiday'],
#       dtype='object')

# %%
flights_clean.to_csv(DATA_PATH + '/interim/2023-performance-data-clean.csv', index=False)
flights_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7260941 entries, 0 to 7260940
# Data columns (total 56 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   year                              int64
#  1   quarter                           int64
#  2   month                             int64
#  3   day_of_month                      int64
#  4   day_of_week                       int64
#  5   marketing_airline_id              int64
#  6   flight_number_marketing_airline   int64
#  7   operating_airline_id              int64
#  8   tail_number                       object
#  9   origin_airport_id                 int64
#  10  origin_city_market_id             int64
#  11  origin                            object
#  12  origin_state                      object
#  13  dest_airport_id                   int64
#  14  dest_city_market_id               int64
#  15  dest                              object
#  16  dest_state                        object
#  17  dep_delay                         float64
#  18  dep_del15                         float64
#  19  departure_delay_groups            float64
#  20  taxi_out                          float64
#  21  taxi_in                           float64
#  22  arr_delay                         float64
#  23  arr_del15                         float64
#  24  arrival_delay_groups              float64
#  25  cancelled                         int64
#  26  diverted                          int64
#  27  scheduled_elapsed_time            float64
#  28  actual_elapsed_time               float64
#  29  air_time                          float64
#  30  distance                          float64
#  31  distance_group                    int64
#  32  carrier_delay                     float64
#  33  weather_delay                     float64
#  34  nas_delay                         float64
#  35  security_delay                    float64
#  36  late_aircraft_delay               float64
#  37  div_airport_landings              float64
#  38  code_share_flight                 int64
#  39  origin_city                       object
#  40  destination_city                  object
#  41  scheduled_departure_datetime      datetime64[ns]
#  42  scheduled_arrival_datetime        datetime64[ns]
#  43  actual_departure_datetime         datetime64[ns]
#  44  actual_arrival_datetime           datetime64[ns]
#  45  overnight_depature                int64
#  46  overnight_arrival                 int64
#  47  airline_mkt                       object
#  48  airline_ops                       object
#  49  origin_timezone                   object
#  50  destination_timezone              object
#  51  scheduled_departure_datetime_utc  datetime64[ns, UTC]
#  52  actual_departure_datetime_utc     datetime64[ns, UTC]
#  53  scheduled_arrival_datetime_utc    datetime64[ns, UTC]
#  54  actual_arrival_datetime_utc       datetime64[ns, UTC]
#  55  is_holiday                        int64
# dtypes: datetime64[ns, UTC](4), datetime64[ns](4), float64(18), int64(19), object(11)
# memory usage: 3.0+ GB

# %% [markdown]
# # Import Aircraft Registration Data
#
# https://www.faa.gov/licenses_certificates/aircraft_certification/aircraft_registry/releasable_aircraft_download

# %%
aircraft_registration = pd.read_csv(DATA_PATH + '/raw/ReleasableAircraft-2023/MASTER.txt')
# Out:
# /var/folders/b2/nkpmrw0s42q_zm32rwshljyr0000gn/T/ipykernel_37407/2070737829.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   aircraft_registration = pd.read_csv(DATA_PATH + '/raw/ReleasableAircraft-2023/MASTER.txt')

# %%
aircraft_ref = pd.read_csv(DATA_PATH + '/raw/ReleasableAircraft-2023/ACFTREF.txt')

# %%
engine_ref = pd.read_csv(DATA_PATH + '/raw/ReleasableAircraft-2023/ENGINE.txt')

# %%
aircraft_registration.head()
# Out:
#   N-NUMBER                   SERIAL NUMBER MFR MDL CODE ENG MFR MDL YEAR MFR  \
# 0    1      680-0519                            2076811       52041     2014
# 1    100    5334                                7100510       17003     1940
# 2    10001  A28                                 9601202       67007     1928
# 3    10004  T18208245                           2072738
# 4    10006  BG-72                               1152020       17026     1955
#
#   TYPE REGISTRANT                                               NAME  \
# 0               7  TENAX AEROSPACE LLC                           ...
# 1               1  BENE MARY D                                   ...
# 2               1  STOOS ROBERT A                                ...
# 3               7  ETOS AIR LLC                                  ...
# 4               1  COUTCHES ROBERT HERCULES DBA                  ...
#
#                               STREET                            STREET2  \
# 0  400 W PARKWAY PL STE 201
# 1  PO BOX 329
# 2  PO BOX 1056
# 3  PO BOX 288
# 4  550 AIRWAY BLVD
#
#                  CITY STATE    ZIP CODE REGION COUNTY COUNTRY  \
# 0  RIDGELAND             MS  391576005       2    089      US
# 1  KETCHUM               OK  743490329       2    097      US
# 2  LAKELAND              FL  338021056       7    105      US
# 3  NEW LONDON            TX  756820288       2    401      US
# 4  LIVERMORE             CA  945519533       4    001      US
#
#    LAST ACTION DATE CERT ISSUE DATE CERTIFICATION TYPE AIRCRAFT  TYPE ENGINE  \
# 0          20230823        20211130    1T                     5            5
# 1          20230122        20050506    1                      4            1
# 2          20230718        20190227    1                      4            1
# 3          20230722        20130312                           4            1
# 4          20230421        19980826    1U                     4            1
#
#   STATUS CODE  MODE S CODE FRACT OWNER AIR WORTH DATE  \
# 0          V      50000001                   20140325
# 1          V      50002263                   19540430
# 2          V      50003446
# 3          V      50003451
# 4          V      50003453                   19710909
#
#                                       OTHER NAMES(1)  \
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4  AERO FLIGHT AVIATION                          ...
#
#                                       OTHER NAMES(2)  \
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
#                                       OTHER NAMES(3)  \
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
#                                       OTHER NAMES(4)  \
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
#                                       OTHER NAMES(5) EXPIRATION DATE  \
# 0                                                ...        20281130
# 1                                                ...        20270430
# 2                                                ...        20290228
# 3                                                ...        20290331
# 4                                                ...        20280229
#
#    UNIQUE ID                         KIT MFR             KIT MODEL  \
# 0    1141371
# 1     600060
# 2     432072
# 3     102879
# 4     480110
#
#   MODE S CODE HEX  Unnamed: 34
# 0      A00001              NaN
# 1      A004B3              NaN
# 2      A00726              NaN
# 3      A00729              NaN
# 4      A0072B              NaN

# %%
aircraft_registration.shape
# Out:
# (293465, 35)

# %%
aircraft_registration.columns
# Out:
# Index(['N-NUMBER', 'SERIAL NUMBER', 'MFR MDL CODE', 'ENG MFR MDL', 'YEAR MFR',
#        'TYPE REGISTRANT', 'NAME', 'STREET', 'STREET2', 'CITY', 'STATE',
#        'ZIP CODE', 'REGION', 'COUNTY', 'COUNTRY', 'LAST ACTION DATE',
#        'CERT ISSUE DATE', 'CERTIFICATION', 'TYPE AIRCRAFT', 'TYPE ENGINE',
#        'STATUS CODE', 'MODE S CODE', 'FRACT OWNER', 'AIR WORTH DATE',
#        'OTHER NAMES(1)', 'OTHER NAMES(2)', 'OTHER NAMES(3)', 'OTHER NAMES(4)',
#        'OTHER NAMES(5)', 'EXPIRATION DATE', 'UNIQUE ID', 'KIT MFR',
#        ' KIT MODEL', 'MODE S CODE HEX', 'Unnamed: 34'],
#       dtype='object')

# %%
aircraft_registration.drop(columns=[
    'FRACT OWNER',
    'OTHER NAMES(1)', 
    'OTHER NAMES(2)', 
    'OTHER NAMES(3)', 
    'OTHER NAMES(4)',
    'OTHER NAMES(5)',
    'KIT MFR',
    ' KIT MODEL',
    'Unnamed: 34'], 
    inplace=True)

# %% [markdown]
# I'll filter the aircraft registration file for tail numbers in the monthly performance data since we don't need data about any other aircrafts from the FAA.

# %%
# check for number of aircrafts on FAA list for commercial flights
df_merged.Tail_Number.nunique()
# Out:
# 6326

# %%
df_merged.Tail_Number.head()
# Out:
# 0    N978NK
# 1    N974NK
# 2    N519NK
# 3    N532NK
# 4    N529NK
# Name: Tail_Number, dtype: object

# %%
df_merged.Tail_Number.isna().sum()
# Out:
# 19648

# %% [markdown]
# Just over 19,000 flights are missing Tail Numbers.

# %%
# remove 'N' from Tail Number to compare to aircraft registrations
df_merged['Tail_Number'] = df['Tail_Number'].apply(lambda x: x[1:] if isinstance(x, str) and x.startswith('N') else x)
df_merged.Tail_Number.head()
# Out:
# 0    978NK
# 1    974NK
# 2    519NK
# 3    532NK
# 4    529NK
# Name: Tail_Number, dtype: object

# %%
tail_numbers = df_merged.Tail_Number

# %%
aircraft_registration = aircraft_registration[aircraft_registration['N-NUMBER'].isin(tail_numbers)]

# %%
aircraft_registration.shape
# Out:
# (6273, 26)

# %%
6326-6273
# Out:
# 53

# %% [markdown]
# The 2023 aircraft registration is missing registrations for 53 planes. These might be in older registrations. I will download the 2022 data to compare.

# %%
aircraft_registration.head()
# Out:
#     N-NUMBER                   SERIAL NUMBER MFR MDL CODE ENG MFR MDL  \
# 645    10156  145786                              3260214       54582
# 807    101DQ  9409                                3940005       13101
# 810    101DU  50020                               1400012       52315
# 866    101HQ  17000156                            3260121       30061
# 938    101NN  5834                                3930402       34601
#
#     YEAR MFR TYPE REGISTRANT  \
# 645     2004               3
# 807     2020               3
# 810     2018               3
# 866     2007               3
# 938     2013               3
#
#                                                   NAME  \
# 645  UNITED AIRLINES INC                           ...
# 807  DELTA AIR LINES INC                           ...
# 810  BANK OF UTAH TRUSTEE                          ...
# 866  REPUBLIC AIRWAYS INC                          ...
# 938  WILMINGTON TRUST CO TRUSTEE                   ...
#
#                                 STREET                            STREET2  \
# 645  233 S WACKER DR
# 807  1775 M H JACKSON SERVICE RD        DEPT 595 AIRCRAFT REGISTRATIONS
# 810  50 S 200 E STE 110
# 866  8909 PURDUE RD STE 300
# 938  1100 N MARKET ST
#
#                    CITY STATE    ZIP CODE REGION COUNTY COUNTRY  \
# 645  CHICAGO               IL  606067147       C    031      US
# 807  ATLANTA               GA  30354           7    121      US
# 810  SALT LAKE CITY        UT  841111617       S    035      US
# 866  INDIANAPOLIS          IN  462683152       C    097      US
# 938  WILMINGTON            DE  198901605       1    003      US
#
#      LAST ACTION DATE CERT ISSUE DATE CERTIFICATION TYPE AIRCRAFT  \
# 645          20230804        20190531    1T                     5
# 807          20231007        20200213    1T                     5
# 810          20230906        20200808    1T                     5
# 866          20230818        20070227    1T                     5
# 938          20230421        20210222    1T                     5
#
#      TYPE ENGINE STATUS CODE  MODE S CODE AIR WORTH DATE EXPIRATION DATE  \
# 645            5          V      50005621       20040215        20290531
# 807            5          V      50004305       20200213        20300228
# 810            5          V      50004311       20181025        20270831
# 866            5          V      50004451       20070228        20290731
# 938            5          V      50004644       20131122        20280229
#
#      UNIQUE ID MODE S CODE HEX
# 645      90729      A00B91
# 807    1312557      A008C5
# 810    1285810      A008C9
# 866     328579      A00929
# 938    1119973      A009A4

# %%
mask = df_merged['Tail_Number'].isin(aircraft_registration['N-NUMBER'])
missing_registration = df_merged[~mask]

# %%
missing_registration.head()
# Out:
#        Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate  \
# 11878  2023        3      8          30          3 2023-08-30
# 12397  2023        3      8           8          2 2023-08-08
# 12898  2023        3      8          31          4 2023-08-31
# 12953  2023        3      8          31          4 2023-08-31
# 13344  2023        3      8          30          3 2023-08-30
#
#        DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 11878                     19805                          AA
# 12397                     19805                          AA
# 12898                     19805                          AA
# 12953                     19805                          AA
# 13344                     19805                          AA
#
#        Flight_Number_Marketing_Airline  DOT_ID_Operating_Airline  \
# 11878                             5016                     20397
# 12397                             5036                     20397
# 12898                             5047                     20397
# 12953                             5049                     20397
# 13344                             5059                     20397
#
#       IATA_Code_Operating_Airline Tail_Number  OriginAirportID  \
# 11878                          OH         NaN            12451
# 12397                          OH         NaN            13931
# 12898                          OH         NaN            14685
# 12953                          OH         NaN            14685
# 13344                          OH         NaN            14100
#
#        OriginCityMarketID Origin OriginState  DestAirportID  DestCityMarketID  \
# 11878               31136    JAX          FL          11278             30852
# 12397               33667    ORF          VA          11057             31057
# 12898               34685    SAV          GA          11298             30194
# 12953               34685    SAV          GA          11057             31057
# 13344               34100    PHL          PA          12451             31136
#
#       Dest DestState  CRSDepTime  DepTime  DepDelay  DepDel15  \
# 11878  DCA        VA        1202      NaN       NaN       NaN
# 12397  CLT        NC         635      NaN       NaN       NaN
# 12898  DFW        TX         726      NaN       NaN       NaN
# 12953  CLT        NC         741      NaN       NaN       NaN
# 13344  JAX        FL         907      NaN       NaN       NaN
#
#        DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  WheelsOn  TaxiIn  \
# 11878                   NaN  1200-1259      NaN        NaN       NaN     NaN
# 12397                   NaN  0600-0659      NaN        NaN       NaN     NaN
# 12898                   NaN  0700-0759      NaN        NaN       NaN     NaN
# 12953                   NaN  0700-0759      NaN        NaN       NaN     NaN
# 13344                   NaN  0900-0959      NaN        NaN       NaN     NaN
#
#        CRSArrTime  ArrTime  ArrDelay  ArrDel15  ArrivalDelayGroups ArrTimeBlk  \
# 11878        1358      NaN       NaN       NaN                 NaN  1300-1359
# 12397         802      NaN       NaN       NaN                 NaN  0800-0859
# 12898         921      NaN       NaN       NaN                 NaN  0900-0959
# 12953         904      NaN       NaN       NaN                 NaN  0900-0959
# 13344        1128      NaN       NaN       NaN                 NaN  1100-1159
#
#        Cancelled  Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  \
# 11878          1         0           116.0                NaN      NaN
# 12397          1         0            87.0                NaN      NaN
# 12898          1         0           175.0                NaN      NaN
# 12953          1         0            83.0                NaN      NaN
# 13344          1         0           141.0                NaN      NaN
#
#        Flights  Distance  DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  \
# 11878      1.0     634.0              3           NaN           NaN       NaN
# 12397      1.0     290.0              2           NaN           NaN       NaN
# 12898      1.0     925.0              4           NaN           NaN       NaN
# 12953      1.0     213.0              1           NaN           NaN       NaN
# 13344      1.0     742.0              3           NaN           NaN       NaN
#
#        SecurityDelay  LateAircraftDelay  DivAirportLandings Duplicate  \
# 11878            NaN                NaN                 0.0         N
# 12397            NaN                NaN                 0.0         N
# 12898            NaN                NaN                 0.0         N
# 12953            NaN                NaN                 0.0         N
# 13344            NaN                NaN                 0.0         N
#
#        Code_Share_Flight   Origin_City   Destination_City  \
# 11878                  1  Jacksonville     Washington, DC
# 12397                  1       Norfolk          Charlotte
# 12898                  1      Savannah  Dallas/Fort Worth
# 12953                  1      Savannah          Charlotte
# 13344                  1  Philadelphia       Jacksonville
#
#       scheduled_departure_datetime scheduled_arrival_datetime  \
# 11878          2023-08-30 12:02:00        2023-08-30 13:58:00
# 12397          2023-08-08 06:35:00        2023-08-08 08:02:00
# 12898          2023-08-31 07:26:00        2023-08-31 09:21:00
# 12953          2023-08-31 07:41:00        2023-08-31 09:04:00
# 13344          2023-08-30 09:07:00        2023-08-30 11:28:00
#
#       actual_departure_datetime actual_arrival_datetime  DeptTimeBlk_Start  \
# 11878                       NaT                     NaT               1200
# 12397                       NaT                     NaT                600
# 12898                       NaT                     NaT                700
# 12953                       NaT                     NaT                700
# 13344                       NaT                     NaT                900
#
#        DeptTimeBlk_End  ArrTimeBlk_Start  ArrTimeBlk_End  ArrivalBlock_Total  \
# 11878             1259              1300            1359                  59
# 12397              659               800             859                  59
# 12898              759               900             959                  59
# 12953              759               900             959                  59
# 13344              959              1100            1159                  59
#
#        DepartureBlock_Total  Overnight_Depature  Overnight_Arrival
# 11878                    59                   0                  0
# 12397                    59                   0                  0
# 12898                    59                   0                  0
# 12953                    59                   0                  0
# 13344                    59                   0                  0

# %%
df_ac_reg_2022 = pd.read_csv(DATA_PATH + '/raw/ReleasableAircraft-2022/MASTER.txt')
# Out:
# /var/folders/b2/nkpmrw0s42q_zm32rwshljyr0000gn/T/ipykernel_37407/938479805.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ac_reg_2022 = pd.read_csv(DATA_PATH + '/raw/ReleasableAircraft-2022/MASTER.txt')

# %%
aircraft_registration_2022 = df_ac_reg_2022[df_ac_reg_2022['N-NUMBER'].isin(missing_registration['Tail_Number'])]
aircraft_registration_2022.shape
# Out:
# (22, 35)

# %%
df_ac_reg_2021 = pd.read_csv(DATA_PATH + '/raw/ReleasableAircraft-2021/MASTER.txt')
# Out:
# /var/folders/b2/nkpmrw0s42q_zm32rwshljyr0000gn/T/ipykernel_37407/1670319963.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ac_reg_2021 = pd.read_csv(DATA_PATH + '/raw/ReleasableAircraft-2021/MASTER.txt')

# %%
aircraft_registration_2021 = df_ac_reg_2021[df_ac_reg_2021['N-NUMBER'].isin(missing_registration['Tail_Number'])]
aircraft_registration_2021.shape
# Out:
# (22, 35)

# %%
aircraft_registration_2021.merge(aircraft_registration_2022, on='N-NUMBER').shape
# Out:
# (22, 69)

# %% [markdown]
# 2021 and 2022 aircraft registrations contain the same aircrafts that are missing from the 2023 df. I will add these.

# %%
aircraft_registration_2022.drop(columns=[
    'FRACT OWNER',
    'OTHER NAMES(1)', 
    'OTHER NAMES(2)', 
    'OTHER NAMES(3)', 
    'OTHER NAMES(4)',
    'OTHER NAMES(5)',
    'KIT MFR',
    ' KIT MODEL',
    'Unnamed: 34'], 
    inplace=True)
# Out:
# /var/folders/b2/nkpmrw0s42q_zm32rwshljyr0000gn/T/ipykernel_37407/1062023511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aircraft_registration_2022.drop(columns=[

# %%
aircraft_registration = pd.concat([aircraft_registration, aircraft_registration_2022], axis=0)

# %%
aircraft_registration.shape
# Out:
# (6295, 26)

# %%
aircraft_registration.head(2)
# Out:
#     N-NUMBER                   SERIAL NUMBER MFR MDL CODE ENG MFR MDL  \
# 645    10156  145786                              3260214       54582
# 807    101DQ  9409                                3940005       13101
#
#     YEAR MFR TYPE REGISTRANT  \
# 645     2004               3
# 807     2020               3
#
#                                                   NAME  \
# 645  UNITED AIRLINES INC                           ...
# 807  DELTA AIR LINES INC                           ...
#
#                                 STREET                            STREET2  \
# 645  233 S WACKER DR
# 807  1775 M H JACKSON SERVICE RD        DEPT 595 AIRCRAFT REGISTRATIONS
#
#                    CITY STATE    ZIP CODE REGION COUNTY COUNTRY  \
# 645  CHICAGO               IL  606067147       C    031      US
# 807  ATLANTA               GA  30354           7    121      US
#
#      LAST ACTION DATE CERT ISSUE DATE CERTIFICATION TYPE AIRCRAFT  \
# 645          20230804        20190531    1T                     5
# 807          20231007        20200213    1T                     5
#
#      TYPE ENGINE STATUS CODE  MODE S CODE AIR WORTH DATE EXPIRATION DATE  \
# 645            5          V      50005621       20040215        20290531
# 807            5          V      50004305       20200213        20300228
#
#      UNIQUE ID MODE S CODE HEX
# 645      90729      A00B91
# 807    1312557      A008C5

# %%
aircraft_ref.head()
# Out:
#       CODE                             MFR                 MODEL TYPE-ACFT  \
# 0  0020901  AAR AIRLIFT GROUP INC           UH-60A                       6
# 1  0030109  EXLINE ACE-C                    ACE-C                        4
# 2  003010D  DELEBAUGH                       P                            4
# 3  003010H  DAL PORTO                       BABY ACE D                   4
# 4  003010P  DUNN                            BABY ACE                     4
#
#    TYPE-ENG  AC-CAT  BUILD-CERT-IND  NO-ENG  NO-SEATS AC-WEIGHT  SPEED  \
# 0         3       1               0       2        15   CLASS 3      0
# 1         1       1               1       1         1   CLASS 1     82
# 2         1       1               1       1         1   CLASS 1     82
# 3         1       1               1       1         1   CLASS 1     82
# 4         1       1               1       1         1   CLASS 1     82
#
#      TC-DATA-SHEET                                     TC-DATA-HOLDER  \
# 0                                                                 ...
# 1                                                                 ...
# 2                                                                 ...
# 3                                                                 ...
# 4                                                                 ...
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
aircraft_ref.drop(columns=['TC-DATA-SHEET', 'TC-DATA-HOLDER', 'Unnamed: 13'], inplace=True)

# %%
engine_ref.head()
# Out:
#    CODE         MFR          MODEL TYPE  HORSEPOWER  THRUST  Unnamed: 6
# 0     0  NONE        NONE            0            0       0         NaN
# 1   401  A.C.E.      HIDR MARK III   1           95       0         NaN
# 2   402  A.C.E.      UPRI MARK III   1          100       0         NaN
# 3   450  AEROMOMENT  AM13 SERIES     8          100       0         NaN
# 4   452  AEROMOMENT  AM15 SERIES     8          117       0         NaN

# %%
engine_ref.drop(columns='Unnamed: 6', inplace=True)

# %%
aircraft_registration_merged = aircraft_registration.merge(aircraft_ref, left_on='MFR MDL CODE', right_on='CODE', how='left')

# %%
aircraft_registration_merged['ENG MFR MDL'] = aircraft_registration_merged['ENG MFR MDL'].replace('     ', 0).astype(int)
aircraft_registration_merged = aircraft_registration_merged.merge(engine_ref, left_on='ENG MFR MDL', right_on='CODE', how='left', suffixes=['_aircraft', '_engine'])

# %%
aircraft_registration_merged.head()
# Out:
#   N-NUMBER                   SERIAL NUMBER MFR MDL CODE  ENG MFR MDL YEAR MFR  \
# 0    10156  145786                              3260214        54582     2004
# 1    101DQ  9409                                3940005        13101     2020
# 2    101DU  50020                               1400012        52315     2018
# 3    101HQ  17000156                            3260121        30061     2007
# 4    101NN  5834                                3930402        34601     2013
#
#   TYPE REGISTRANT                                               NAME  \
# 0               3  UNITED AIRLINES INC                           ...
# 1               3  DELTA AIR LINES INC                           ...
# 2               3  BANK OF UTAH TRUSTEE                          ...
# 3               3  REPUBLIC AIRWAYS INC                          ...
# 4               3  WILMINGTON TRUST CO TRUSTEE                   ...
#
#                               STREET                            STREET2  \
# 0  233 S WACKER DR
# 1  1775 M H JACKSON SERVICE RD        DEPT 595 AIRCRAFT REGISTRATIONS
# 2  50 S 200 E STE 110
# 3  8909 PURDUE RD STE 300
# 4  1100 N MARKET ST
#
#                  CITY STATE    ZIP CODE REGION COUNTY COUNTRY  \
# 0  CHICAGO               IL  606067147       C    031      US
# 1  ATLANTA               GA  30354           7    121      US
# 2  SALT LAKE CITY        UT  841111617       S    035      US
# 3  INDIANAPOLIS          IN  462683152       C    097      US
# 4  WILMINGTON            DE  198901605       1    003      US
#
#    LAST ACTION DATE CERT ISSUE DATE CERTIFICATION TYPE AIRCRAFT  TYPE ENGINE  \
# 0          20230804        20190531    1T                     5            5
# 1          20231007        20200213    1T                     5            5
# 2          20230906        20200808    1T                     5            5
# 3          20230818        20070227    1T                     5            5
# 4          20230421        20210222    1T                     5            5
#
#   STATUS CODE  MODE S CODE AIR WORTH DATE EXPIRATION DATE  UNIQUE ID  \
# 0          V      50005621       20040215        20290531      90729
# 1          V      50004305       20200213        20300228    1312557
# 2          V      50004311       20181025        20270831    1285810
# 3          V      50004451       20070228        20290731     328579
# 4          V      50004644       20131122        20280229    1119973
#
#   MODE S CODE HEX CODE_aircraft                    MFR_aircraft  \
# 0      A00B91           3260214  EMBRAER
# 1      A008C5           3940005  AIRBUS
# 2      A008C9           1400012  C SERIES AIRCRAFT LTD PTNRSP
# 3      A00929           3260121  EMBRAER-EMPRESA BRASILEIRA DE
# 4      A009A4           3930402  AIRBUS INDUSTRIE
#
#          MODEL_aircraft TYPE-ACFT  TYPE-ENG  AC-CAT  BUILD-CERT-IND  NO-ENG  \
# 0  EMB-145XR                    5         5       1               0       2
# 1  A321-211                     5         5       1               0       2
# 2  BD-500-1A10                  5         5       1               0       2
# 3  ERJ 170-200 LR               5         5       1               0       2
# 4  A321-231                     5         5       1               0       2
#
#    NO-SEATS AC-WEIGHT  SPEED  CODE_engine  MFR_engine   MODEL_engine TYPE  \
# 0        55   CLASS 2      0        54582  ROLLS-ROYC  AE3007 SER      5
# 1       199   CLASS 3      0        13101  CFM INTL    CFM56-5B3/3     5
# 2       133   CLASS 3      0        52315  P & W       PW1519G         5
# 3        80   CLASS 3      0        30061  GE          CF34-8E5        5
# 4       379   CLASS 3      0        34601  IAE         V2500SERIES     4
#
#    HORSEPOWER  THRUST
# 0           0    6442
# 1           0   32000
# 2           0   19775
# 3           0   14510
# 4           0   25000

# %%
aircraft_registration_merged.to_csv(DATA_PATH + '/interim/aircraft_registration.csv', index=False)
